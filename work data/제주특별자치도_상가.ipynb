# %%
# google drive 마운트
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
  
part2 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/음식/제주특별자치도상가(상권)정보.csv', encoding='cp949')

# %% [markdown]
# # part2 = 제주특별자치도상가(상권)정보

# %%
# part2 = 제주특별자치도상가(상권)정보

print(part2.shape)
print(list(part2.columns))
part2.head()
# Out:
# (45028, 16)
# ['상호명', '상권업종대분류명', '상권업종중분류명', '상권업종소분류명', '표준산업분류명', '시도명', '시군구명', '행정동명', '법정동명', '행정동코드', '법정동코드', '지번주소', '도로명주소', '신우편번호', '경도', '위도']
#              상호명 상권업종대분류명    상권업종중분류명   상권업종소분류명       표준산업분류명      시도명  시군구명  \
# 0  에프케이알레그리아호텔제주       숙박       호텔/콘도      호텔/콘도           NaN  제주특별자치도  서귀포시
# 1          동경부동산      부동산       부동산중개      부동산중개  부동산 자문 및 중개업  제주특별자치도  서귀포시
# 2          금실홈패션       소매  가정/주방/인테리어        홈패션  가정용 직물제품 소매업  제주특별자치도   제주시
# 3         숙성1퍼센트       음식          한식  한식/백반/한정식       한식 음식점업  제주특별자치도   제주시
# 4       아빠가닭튀기는집       음식        유흥주점      호프/맥주        기타 주점업  제주특별자치도   제주시
#
#    행정동명  법정동명       행정동코드       법정동코드                        지번주소  \
# 0   천지동   서귀동  5013054000  5013010100      제주특별자치도 서귀포시 서귀동 319-2
# 1   중앙동   서귀동  5013053000  5013010100      제주특별자치도 서귀포시 서귀동 290-5
# 2  용담1동  용담일동  5011057000  5011010800      제주특별자치도 제주시 용담일동 135-9
# 3   노형동   노형동  5011066000  5011012200      제주특별자치도 제주시 노형동 3785-3
# ...

# %%
# 컬럼별로 중복데이터 여부 확인

part2['상권업종대분류명'].value_counts()
# Out:
# 음식          19901
# 소매          12179
# 생활서비스        5695
# 숙박           2933
# 학문/교육        2604
# 부동산           842
# 관광/여가/오락      781
# 스포츠            93
# Name: 상권업종대분류명, dtype: int64

# %%
# '영업상태명' 컬럼에 있는 '음식'이 들어있는 행 추출

part2 = part2[part2.상권업종대분류명 == '음식']
part2.head()
# Out:
#          상호명 상권업종대분류명 상권업종중분류명   상권업종소분류명      표준산업분류명      시도명 시군구명  행정동명  \
# 3     숙성1퍼센트       음식       한식  한식/백반/한정식      한식 음식점업  제주특별자치도  제주시   노형동
# 4   아빠가닭튀기는집       음식     유흥주점      호프/맥주       기타 주점업  제주특별자치도  제주시   한림읍
# 7      죠스떡볶이       음식       분식      떡볶이전문  분식 및 김밥 전문점  제주특별자치도  제주시   건입동
# 11     가르텐비어       음식     유흥주점      호프/맥주       기타 주점업  제주특별자치도  제주시   노형동
# 14     광어탐나도       음식   일식/수산물         횟집      한식 음식점업  제주특별자치도  제주시  이도2동
#
#     법정동명       행정동코드       법정동코드                        지번주소  \
# 3    노형동  5011066000  5011012200      제주특별자치도 제주시 노형동 3785-3
# 4    한림읍  5011025000  5011025024  제주특별자치도 제주시 한림읍 한림리 1199-3
# 7    건입동  5011059000  5011010700        제주특별자치도 제주시 건입동 1442
# 11   노형동  5011066000  5011012200      제주특별자치도 제주시 노형동 1054-3
# 14  이도이동  5011054000  5011010400      제주특별자치도 제주시 이도이동 76-15
#
#                        도로명주소    신우편번호          경도         위도
# 3       제주특별자치도 제주시 노형10길 25  63083.0  126.479894  33.483335
# ...

# %%
# 컬럼 삭제

part2 = part2.drop(['상권업종대분류명', '상권업종소분류명', '시도명', '행정동명', '법정동명', '행정동코드', '법정동코드', '지번주소', '신우편번호'], axis=1)
part2.head()
# Out:
#          상호명 상권업종중분류명      표준산업분류명 시군구명                     도로명주소          경도  \
# 3     숙성1퍼센트       한식      한식 음식점업  제주시      제주특별자치도 제주시 노형10길 25  126.479894
# 4   아빠가닭튀기는집     유흥주점       기타 주점업  제주시  제주특별자치도 제주시 한림읍 한림중앙로 26  126.264860
# 7      죠스떡볶이       분식  분식 및 김밥 전문점  제주시        제주특별자치도 제주시 임항로 17  126.526797
# 11     가르텐비어     유흥주점       기타 주점업  제주시      제주특별자치도 제주시 월랑로10길 2  126.476631
# 14     광어탐나도   일식/수산물      한식 음식점업  제주시      제주특별자치도 제주시 연신로 87-6  126.549875
#
#            위도
# 3   33.483335
# 4   33.412363
# 7   33.516737
# 11  33.489020
# 14  33.494109

# %%
# 컬럼명 변경

part2.rename(columns = {'상호명':'업소명', '상권업종중분류명':'업태', '표준산업분류명':'업종', 
                        '시군구명':'행정시'},inplace=True)
part2.head()
# Out:
#          업소명      업태           업종  행정시                     도로명주소          경도  \
# 3     숙성1퍼센트      한식      한식 음식점업  제주시      제주특별자치도 제주시 노형10길 25  126.479894
# 4   아빠가닭튀기는집    유흥주점       기타 주점업  제주시  제주특별자치도 제주시 한림읍 한림중앙로 26  126.264860
# 7      죠스떡볶이      분식  분식 및 김밥 전문점  제주시        제주특별자치도 제주시 임항로 17  126.526797
# 11     가르텐비어    유흥주점       기타 주점업  제주시      제주특별자치도 제주시 월랑로10길 2  126.476631
# 14     광어탐나도  일식/수산물      한식 음식점업  제주시      제주특별자치도 제주시 연신로 87-6  126.549875
#
#            위도
# 3   33.483335
# 4   33.412363
# 7   33.516737
# 11  33.489020
# 14  33.494109

# %%
# 컬럼 추가

part2['전화번호'] = np.nan
part2.head()
# Out:
#          업소명      업태           업종  행정시                     도로명주소          경도  \
# 3     숙성1퍼센트      한식      한식 음식점업  제주시      제주특별자치도 제주시 노형10길 25  126.479894
# 4   아빠가닭튀기는집    유흥주점       기타 주점업  제주시  제주특별자치도 제주시 한림읍 한림중앙로 26  126.264860
# 7      죠스떡볶이      분식  분식 및 김밥 전문점  제주시        제주특별자치도 제주시 임항로 17  126.526797
# 11     가르텐비어    유흥주점       기타 주점업  제주시      제주특별자치도 제주시 월랑로10길 2  126.476631
# 14     광어탐나도  일식/수산물      한식 음식점업  제주시      제주특별자치도 제주시 연신로 87-6  126.549875
#
#            위도  전화번호
# 3   33.483335   NaN
# 4   33.412363   NaN
# 7   33.516737   NaN
# 11  33.489020   NaN
# 14  33.494109   NaN

# %%
# 컬럼명 순서변경

part2 = part2[['업소명', '업종', '업태', '행정시', '도로명주소', '전화번호', '위도', '경도']]
part2.head()
# Out:
#          업소명           업종      업태  행정시                     도로명주소  전화번호  \
# 3     숙성1퍼센트      한식 음식점업      한식  제주시      제주특별자치도 제주시 노형10길 25   NaN
# 4   아빠가닭튀기는집       기타 주점업    유흥주점  제주시  제주특별자치도 제주시 한림읍 한림중앙로 26   NaN
# 7      죠스떡볶이  분식 및 김밥 전문점      분식  제주시        제주특별자치도 제주시 임항로 17   NaN
# 11     가르텐비어       기타 주점업    유흥주점  제주시      제주특별자치도 제주시 월랑로10길 2   NaN
# 14     광어탐나도      한식 음식점업  일식/수산물  제주시      제주특별자치도 제주시 연신로 87-6   NaN
#
#            위도          경도
# 3   33.483335  126.479894
# 4   33.412363  126.264860
# 7   33.516737  126.526797
# 11  33.489020  126.476631
# 14  33.494109  126.549875

# %%
# 누락 데이터 확인

part2.count()
# Out:
# 업소명      19901
# 업종       19823
# 업태       19901
# 행정시      19901
# 도로명주소    19901
# 전화번호         0
# 위도       19901
# 경도       19901
# dtype: int64

# %%
# 누락 데이터 확인

part2.isnull().sum()
# Out:
# 업소명          0
# 업종          78
# 업태           0
# 행정시          0
# 도로명주소        0
# 전화번호     19901
# 위도           0
# 경도           0
# dtype: int64

# %%
# 완전히 동일한 중복데이터 여부 확인

part2.duplicated(['업소명', '도로명주소']).sum()
# Out:
# 5

# %%
# '업소명', '소재지' 컬럼인 중복된 행 삭제

part2.drop_duplicates(['업소명', '도로명주소'])
# Out:
#                   업소명           업종       업태  행정시                      도로명주소  \
# 3              숙성1퍼센트      한식 음식점업       한식  제주시       제주특별자치도 제주시 노형10길 25
# 4            아빠가닭튀기는집       기타 주점업     유흥주점  제주시   제주특별자치도 제주시 한림읍 한림중앙로 26
# 7               죠스떡볶이  분식 및 김밥 전문점       분식  제주시         제주특별자치도 제주시 임항로 17
# 11              가르텐비어       기타 주점업     유흥주점  제주시       제주특별자치도 제주시 월랑로10길 2
# 14              광어탐나도      한식 음식점업   일식/수산물  제주시       제주특별자치도 제주시 연신로 87-6
# ...               ...          ...      ...  ...                        ...
# 45021            탐앤탐스     비알콜 음료점업   커피점/카페  제주시         제주특별자치도 제주시 신형로 14
# 45022              참돈      한식 음식점업       한식  제주시         제주특별자치도 제주시 월랑로 56
# 45024             제주달      일식 음식점업   일식/수산물  제주시  제주특별자치도 제주시 애월읍 가문동길 27-8
# 45026  24시얼큰시원생고기김치찌개      한식 음식점업       한식  제주시         제주특별자치도 제주시 우정로 85
# 45027            명당양과         제과점업  제과제빵떡케익  제주시       제주특별자치도 제주시 구남동2길 29
#
#        전화번호         위도          경도
# ...

# %%
# csv 파일 저장

part2.to_csv('제주특별자치도_상가.csv', encoding='cp949')
