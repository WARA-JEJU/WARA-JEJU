# %%
# google drive 마운트
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
  
part1 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/음식/제주특별자치도음식점목록(통합).csv', encoding='cp949')
part2 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/음식/제주특별자치도_모범음식점현황_20210412.csv', encoding='cp949')
part3 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/음식/제주특별자치도_착한가격업소현황_20210615.csv', encoding='cp949')

# %%
# part1 = 제주특별자치도음식점목록(통합)

print(part1.shape)
print(list(part1.columns))
part1.head()
# Out:
# (42602, 16)
# ['사업장명', '업종구분대분류', '업종구분소분류', '인허가일자', '인허가취소일자', '영업상태명', '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자', '재개업일자', '소재지면적', '소재지전체주소', '도로명전체주소', '도로명우편번호', '데이터갱신일자']
#           사업장명 업종구분대분류   업종구분소분류     인허가일자  인허가취소일자  영업상태명 상세영업상태명  폐업일자  \
# 0         카페송키   일반음식점        기타  20181129      NaN  영업/정상      영업   NaN
# 1  그림책방앤카페노란우산   일반음식점        기타  20181227      NaN  영업/정상      영업   NaN
# 2     에릭스에스프레소   일반음식점        기타  20181102      NaN  영업/정상      영업   NaN
# 3     일품순두부한림점   일반음식점        한식  20190107      NaN  영업/정상      영업   NaN
# 4     팔도실비집아라점   일반음식점  식육(숯불구이)  20190107      NaN  영업/정상      영업   NaN
#
#    휴업시작일자  휴업종료일자  재개업일자   소재지면적                            소재지전체주소  \
# 0     NaN     NaN    NaN   80.14         제주특별자치도 제주시 삼도이동 1120-2번지
# 1     NaN     NaN    NaN  104.25  제주특별자치도 제주시 애월읍 광령리 2981-1번지 자연숲
# 2     NaN     NaN    NaN      27      제주특별자치도 제주시 구좌읍 세화리 1397-6번지
# 3     NaN     NaN    NaN     152      제주특별자치도 제주시 한림읍 대림리 1845-2번지
# ...

# %%
# 컬럼 삭제

part1 = part1.drop(['인허가일자', '인허가취소일자', '영업상태명', '폐업일자', 
                    '휴업시작일자', '휴업종료일자', '재개업일자', '소재지면적', '소재지전체주소', '도로명우편번호', '데이터갱신일자'], axis=1)
part1.head()
# Out:
#           사업장명 업종구분대분류   업종구분소분류 상세영업상태명  \
# 0         카페송키   일반음식점        기타      영업
# 1  그림책방앤카페노란우산   일반음식점        기타      영업
# 2     에릭스에스프레소   일반음식점        기타      영업
# 3     일품순두부한림점   일반음식점        한식      영업
# 4     팔도실비집아라점   일반음식점  식육(숯불구이)      영업
#
#                                     도로명전체주소
# 0           제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)
# 1  제주특별자치도 제주시 애월읍 하광로 515, 104동 102호 (자연숲)
# 2                제주특별자치도 제주시 구좌읍 구좌로 77, 1층
# 3              제주특별자치도 제주시 한림읍 한림상로 237, 1층
# 4        제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)

# %%
# 컬럼명 변경

part1.rename(columns = {'사업장명':'업소명', '업종구분대분류':'업종', '업종구분소분류':'업태', 
                        '도로명전체주소':'도로명주소'},inplace=True)
part1.head()
# Out:
#            업소명     업종        업태 상세영업상태명  \
# 0         카페송키  일반음식점        기타      영업
# 1  그림책방앤카페노란우산  일반음식점        기타      영업
# 2     에릭스에스프레소  일반음식점        기타      영업
# 3     일품순두부한림점  일반음식점        한식      영업
# 4     팔도실비집아라점  일반음식점  식육(숯불구이)      영업
#
#                                       도로명주소
# 0           제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)
# 1  제주특별자치도 제주시 애월읍 하광로 515, 104동 102호 (자연숲)
# 2                제주특별자치도 제주시 구좌읍 구좌로 77, 1층
# 3              제주특별자치도 제주시 한림읍 한림상로 237, 1층
# 4        제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)

# %%
# 컬럼별로 중복데이터 여부 확인

part1['상세영업상태명'].value_counts()
# Out:
# 폐업    23445
# 영업    19157
# Name: 상세영업상태명, dtype: int64

# %%
# '상세영업상태명' 컬럼에 있는 '폐업'이 들어가 행을 삭제

part1 = part1[part1.상세영업상태명 != '폐업']
part1
# Out:
#                업소명     업종        업태 상세영업상태명  \
# 0             카페송키  일반음식점        기타      영업
# 1      그림책방앤카페노란우산  일반음식점        기타      영업
# 2         에릭스에스프레소  일반음식점        기타      영업
# 3         일품순두부한림점  일반음식점        한식      영업
# 4         팔도실비집아라점  일반음식점  식육(숯불구이)      영업
# ...            ...    ...       ...     ...
# 41277          쏭카롱  휴게음식점  기타 휴게음식점      영업
# 41278    주식회사 애니멀고  휴게음식점       커피숍      영업
# 41279       한옥마루카페  휴게음식점       커피숍      영업
# 41280  쎄븐일레븐서귀포법환점  휴게음식점       편의점      영업
# 41281         신신카페  휴게음식점       커피숍      영업
#
#                                                    도로명주소
# 0                        제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)
# 1               제주특별자치도 제주시 애월읍 하광로 515, 104동 102호 (자연숲)
# 2                             제주특별자치도 제주시 구좌읍 구좌로 77, 1층
# 3                           제주특별자치도 제주시 한림읍 한림상로 237, 1층
# 4                     제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)
# ...                                                  ...
# ...

# %%
# '소재지(지번)' 컬럼 삭제

part1 = part1.drop(['상세영업상태명'], axis=1)
part1.head()
# Out:
#            업소명     업종        업태                                     도로명주소
# 0         카페송키  일반음식점        기타           제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)
# 1  그림책방앤카페노란우산  일반음식점        기타  제주특별자치도 제주시 애월읍 하광로 515, 104동 102호 (자연숲)
# 2     에릭스에스프레소  일반음식점        기타                제주특별자치도 제주시 구좌읍 구좌로 77, 1층
# 3     일품순두부한림점  일반음식점        한식              제주특별자치도 제주시 한림읍 한림상로 237, 1층
# 4     팔도실비집아라점  일반음식점  식육(숯불구이)        제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)

# %%
# 누락 데이터 확인

part1.count()
# Out:
# 업소명      19157
# 업종       19157
# 업태       19155
# 도로명주소    18925
# dtype: int64

# %%
# 누락 데이터 확인

part1.isnull().sum()
# Out:
# 업소명        0
# 업종         0
# 업태         2
# 도로명주소    232
# dtype: int64

# %%
# 컬럼별로 중복데이터 여부 확인

part1['업소명'].value_counts()
# Out:
# 에피소드              3
# 화수분               3
# 스타트하우스            3
# 다소니               3
# 봉봉                3
#                  ..
# 농협목우촌또래오래치킨한화점    1
# 쿠주소셜카페이호점         1
# 영평우도횃바리           1
# 평대성게국수            1
# 신신카페              1
# Name: 업소명, Length: 18844, dtype: int64

# %%
# 중복 발생

part1[part1.업소명 == '에피소드']
# Out:
#         업소명     업종   업태                          도로명주소
# 5880   에피소드  일반음식점   한식     제주특별자치도 제주시 한경면 고조로 62, 1층
# 24668  에피소드  일반음식점   한식      제주특별자치도 서귀포시 명동로 53 (서귀동)
# 33892  에피소드  휴게음식점  커피숍  제주특별자치도 제주시 애월읍 하귀동남1길 19, 1층

# %%
# 중복 발생

part1[part1.업소명 == '화수분']
# Out:
#        업소명     업종     업태                            도로명주소
# 4645   화수분  일반음식점     한식        제주특별자치도 제주시 연수중길 3 (일도이동)
# 5376   화수분  일반음식점  호프/통닭         제주특별자치도 제주시 동화로 7 (화북일동)
# 27638  화수분  일반음식점     한식  제주특별자치도 서귀포시 중정로91번길 39-1 (서귀동)

# %%
# 중복 발생

part1[part1.업소명 == '스타트하우스']
# Out:
#           업소명     업종  업태                            도로명주소
# 3358   스타트하우스  일반음식점  기타  제주특별자치도 제주시 애월읍 화전길 201, 타미우스CC
# 4991   스타트하우스  일반음식점  한식                              NaN
# 26782  스타트하우스  일반음식점  한식        제주특별자치도 서귀포시 안덕면 산록남로 863

# %%
# 중복 발생

part1[part1.업소명 == '다소니']
# Out:
#        업소명     업종      업태                           도로명주소
# 9037   다소니  일반음식점     중국식    제주특별자치도 제주시 고전길 2, 1층 (이도일동)
# 25313  다소니  일반음식점   호프/통닭  제주특별자치도 서귀포시 중문상로 40, 2층 (중문동)
# 33952  다소니  휴게음식점  일반조리판매     제주특별자치도 제주시 오남로6길 24 (오라일동)

# %%
# 중복 발생

part1[part1.업소명 == '봉봉']
# Out:
#       업소명     업종  업태                            도로명주소
# 2831   봉봉  일반음식점  까페        제주특별자치도 제주시 우도면 우도해안길 630
# 5277   봉봉  일반음식점  한식  제주특별자치도 제주시 신성로 91, 1층 6호 (도남동)
# 26214  봉봉  일반음식점  기타       제주특별자치도 서귀포시 남원읍 남태해안로 101

# %%
# 컬럼별로 중복데이터 여부 확인

part1['업종'].value_counts()
# Out:
# 일반음식점    14734
# 휴게음식점     4423
# Name: 업종, dtype: int64

# %%
# 컬럼별로 중복데이터 여부 확인

part1['업태'].value_counts()
# Out:
# 한식                 6566
# 기타                 2828
# 커피숍                1430
# 기타 휴게음식점           1336
# 호프/통닭              1227
# 식육(숯불구이)            722
# 경양식                 703
# 편의점                 699
# 일반조리판매              583
# 분식                  374
# 중국식                 350
# 일식                  347
# 까페                  345
# 통닭(치킨)              339
# 회집                  197
# 패스트푸드               173
# 횟집                  164
# 정종/대포집/소주방          138
# 뷔페식                 128
# 다방                  114
# 외국음식전문점(인도,태국등)      79
# 패밀리레스트랑              61
# 탕류(보신용)              49
# 푸드트럭                 42
# 전통찻집                 28
# 키즈카페                 24
# 아이스크림                19
# 김밥(도시락)              19
# 복어취급                 14
# 과자점                  14
# 라이브카페                 9
# 출장조리                  8
# 떡카페                   6
# 공항                    6
# 감성주점                  4
# 냉면집                   3
# 유원지                   2
# 관광호텔                  2
# ...

# %%
# 컬럼별로 중복데이터 여부 확인

part1['도로명주소'].value_counts()
# Out:
# 제주특별자치도 서귀포시 안덕면 신화역사로304번길 38, 지하1층       14
# 제주특별자치도 제주시 은수길 69, 수목원 테마파크 관광지 내 (연동)    12
# 제주특별자치도 서귀포시 표선면 민속해안로 537                 10
# 제주특별자치도 제주시 동광로1길 32 (이도일동)                 9
# 제주특별자치도 서귀포시 중문관광로72번길 75 (색달동)             9
#                                            ..
# 제주특별자치도 제주시 설촌로12길 24 (삼양이동,(감수6로51))       1
# 제주특별자치도 제주시 탑동로 43 (삼도이동,(탑동로53))           1
# 제주특별자치도 제주시 연문2길 18 (연동)                    1
# 제주특별자치도 제주시 원노형8길 26 (노형동,(정동산1로36))        1
# 제주특별자치도 서귀포시 중앙로 14, 1층 104호 (서귀동)          1
# Name: 도로명주소, Length: 17160, dtype: int64

# %%
part1.head()
# Out:
#            업소명     업종        업태                                     도로명주소
# 0         카페송키  일반음식점        기타           제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)
# 1  그림책방앤카페노란우산  일반음식점        기타  제주특별자치도 제주시 애월읍 하광로 515, 104동 102호 (자연숲)
# 2     에릭스에스프레소  일반음식점        기타                제주특별자치도 제주시 구좌읍 구좌로 77, 1층
# 3     일품순두부한림점  일반음식점        한식              제주특별자치도 제주시 한림읍 한림상로 237, 1층
# 4     팔도실비집아라점  일반음식점  식육(숯불구이)        제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)

# %%
# part2 = 제주특별자치도_모범음식점현황

print(part2.shape)
print(list(part2.columns))
part2.head()
# Out:
# (276, 6)
# ['업소명', '소재지', '동명', '전화번호', '업태', '데이터기준일자']
#    업소명                    소재지   동명          전화번호  업태     데이터기준일자
# 0   금보    제주특별자치도 제주시 서부두길 14  건입동  064-726-1777  일식  2021-04-12
# 1   대진    제주특별자치도 제주시 서부두길 16  건입동  064-758-0522  일식  2021-04-12
# 2  돈향기  제주특별자치도 제주시 관덕로15길 30  건입동  064-724-0228  한식  2021-04-12
# 3   만옥    제주특별자치도 제주시 중앙로2길 1  건입동  064-751-1443  한식  2021-04-12
# 4  서부두   제주특별자치도 제주시 임항로 37-2  건입동  064-756-0506  한식  2021-04-12

# %%
# 컬럼명 변경

part2.rename(columns = {'소재지':'도로명주소'},inplace=True)
part2.head()
# Out:
#    업소명                  도로명주소   동명          전화번호  업태     데이터기준일자
# 0   금보    제주특별자치도 제주시 서부두길 14  건입동  064-726-1777  일식  2021-04-12
# 1   대진    제주특별자치도 제주시 서부두길 16  건입동  064-758-0522  일식  2021-04-12
# 2  돈향기  제주특별자치도 제주시 관덕로15길 30  건입동  064-724-0228  한식  2021-04-12
# 3   만옥    제주특별자치도 제주시 중앙로2길 1  건입동  064-751-1443  한식  2021-04-12
# 4  서부두   제주특별자치도 제주시 임항로 37-2  건입동  064-756-0506  한식  2021-04-12

# %%
# '동명', '데이터기준일자' 컬럼 삭제

part2 = part2.drop(['동명', '데이터기준일자'], axis=1)
part2.head()
# Out:
#    업소명                  도로명주소          전화번호  업태
# 0   금보    제주특별자치도 제주시 서부두길 14  064-726-1777  일식
# 1   대진    제주특별자치도 제주시 서부두길 16  064-758-0522  일식
# 2  돈향기  제주특별자치도 제주시 관덕로15길 30  064-724-0228  한식
# 3   만옥    제주특별자치도 제주시 중앙로2길 1  064-751-1443  한식
# 4  서부두   제주특별자치도 제주시 임항로 37-2  064-756-0506  한식

# %%
# 컬럼명 순서변경

part2 = part2[['업소명', '업태', '도로명주소', '전화번호']]
part2
# Out:
#         업소명  업태                     도로명주소          전화번호
# 0        금보  일식       제주특별자치도 제주시 서부두길 14  064-726-1777
# 1        대진  일식       제주특별자치도 제주시 서부두길 16  064-758-0522
# 2       돈향기  한식     제주특별자치도 제주시 관덕로15길 30  064-724-0228
# 3        만옥  한식       제주특별자치도 제주시 중앙로2길 1  064-751-1443
# 4       서부두  한식      제주특별자치도 제주시 임항로 37-2  064-756-0506
# ..      ...  ..                       ...           ...
# 271      군족  한식       제주특별자치도 제주시 동화로 74   064-721-8977
# 272  꽃마름삼화점  한식        제주특별자치도 제주시 화삼로 21  064-757-0505
# 273   맛있는소리  한식        제주특별자치도 제주시 진동로 6   064-758-9298
# 274     삼다향  한식     제주특별자치도 제주시 일주동로 242   064-721-5659
# 275    새미언덕  한식  제주특별자치도 제주시 중산간동로 188-6   064-752-8200
#
# [276 rows x 4 columns]

# %%
# 누락 데이터 확인

part2.count()
# Out:
# 업소명      276
# 업태       276
# 도로명주소    276
# 전화번호     275
# dtype: int64

# %%
# 누락 데이터 확인

part2.isnull().sum()
# Out:
# 업소명      0
# 업태       0
# 도로명주소    0
# 전화번호     1
# dtype: int64

# %%
# 컬럼별로 중복데이터 여부 확인

part2['업소명'].value_counts()
# Out:
# 금보             1
# 길림성            1
# 해원             1
# 해연             1
# 제주향토골          1
#               ..
# 육갑봉            1
# 제주축산농협한우플라자    1
# 주식회사도다모        1
# 징기스이도점         1
# 새미언덕           1
# Name: 업소명, Length: 276, dtype: int64

# %%
# 컬럼별로 중복데이터 여부 확인

part2['도로명주소'].value_counts()
# Out:
# 제주특별자치도 제주시 서부두길 16         2
# 제주특별자치도 제주시 승천로 73          2
# 제주특별자치도 제주시 진군남4길 7-8       2
# 제주특별자치도 제주시 남성로 75          1
# 제주특별자치도 제주시 서해안로 687-6      1
#                            ..
# 제주특별자치도 제주시 신설로11길 5        1
# 제주특별자치도 제주시 승천로 68          1
# 제주특별자치도 제주시 연북로 631         1
# 제주특별자치도 제주시 중앙로 501         1
# 제주특별자치도 제주시 중산간동로 188-6     1
# Name: 도로명주소, Length: 273, dtype: int64

# %%
# 컬럼별로 중복데이터 여부 확인

part2['전화번호'].value_counts()
# Out:
# 064-748-4343    2
# 064-711-9233    2
# 064-726-1777    1
# 064-751-5530    1
# 064-711-2552    1
#                ..
# 064-726-4111    1
# 064-726-5672    1
# 064-752-5525    1
# 064-722-6155    1
# 064-752-8200    1
# Name: 전화번호, Length: 273, dtype: int64

# %% [markdown]
# # Part1 + part2 병합

# %%
new_part = pd.concat([part1, part2])

# %%
print(new_part.shape)
print(list(new_part.columns))
new_part.head()
# Out:
# (19433, 5)
# ['업소명', '업종', '업태', '도로명주소', '전화번호']
#            업소명     업종        업태                                     도로명주소 전화번호
# 0         카페송키  일반음식점        기타           제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)  NaN
# 1  그림책방앤카페노란우산  일반음식점        기타  제주특별자치도 제주시 애월읍 하광로 515, 104동 102호 (자연숲)  NaN
# 2     에릭스에스프레소  일반음식점        기타                제주특별자치도 제주시 구좌읍 구좌로 77, 1층  NaN
# 3     일품순두부한림점  일반음식점        한식              제주특별자치도 제주시 한림읍 한림상로 237, 1층  NaN
# 4     팔도실비집아라점  일반음식점  식육(숯불구이)        제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)  NaN

# %%
# 완전히 동일한 중복데이터 여부 확인

new_part.duplicated(['업소명', '도로명주소']).sum()
# Out:
# 15

# %%
# '업소명', '소재지' 컬럼인 중복된 행 삭제

new_part.drop_duplicates(['업소명', '도로명주소'])
# Out:
#              업소명     업종        업태                                     도로명주소  \
# 0           카페송키  일반음식점        기타           제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)
# 1    그림책방앤카페노란우산  일반음식점        기타  제주특별자치도 제주시 애월읍 하광로 515, 104동 102호 (자연숲)
# 2       에릭스에스프레소  일반음식점        기타                제주특별자치도 제주시 구좌읍 구좌로 77, 1층
# 3       일품순두부한림점  일반음식점        한식              제주특별자치도 제주시 한림읍 한림상로 237, 1층
# 4       팔도실비집아라점  일반음식점  식육(숯불구이)        제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)
# ..           ...    ...       ...                                       ...
# 271           군족    NaN        한식                       제주특별자치도 제주시 동화로 74
# 272       꽃마름삼화점    NaN        한식                        제주특별자치도 제주시 화삼로 21
# 273        맛있는소리    NaN        한식                        제주특별자치도 제주시 진동로 6
# 274          삼다향    NaN        한식                     제주특별자치도 제주시 일주동로 242
# 275         새미언덕    NaN        한식                  제주특별자치도 제주시 중산간동로 188-6
#
#              전화번호
# 0             NaN
# 1             NaN
# ...

# %%
# 컬럼 추가

new_part['행정시'] = np.nan
new_part.head()
# Out:
#            업소명     업종        업태                                     도로명주소  \
# 0         카페송키  일반음식점        기타           제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)
# 1  그림책방앤카페노란우산  일반음식점        기타  제주특별자치도 제주시 애월읍 하광로 515, 104동 102호 (자연숲)
# 2     에릭스에스프레소  일반음식점        기타                제주특별자치도 제주시 구좌읍 구좌로 77, 1층
# 3     일품순두부한림점  일반음식점        한식              제주특별자치도 제주시 한림읍 한림상로 237, 1층
# 4     팔도실비집아라점  일반음식점  식육(숯불구이)        제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)
#
#   전화번호  행정시
# 0  NaN  NaN
# 1  NaN  NaN
# 2  NaN  NaN
# 3  NaN  NaN
# 4  NaN  NaN

# %%
# 컬럼 추가

new_part['위도'] = np.nan
new_part.head()
# Out:
#            업소명     업종        업태                                     도로명주소  \
# 0         카페송키  일반음식점        기타           제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)
# 1  그림책방앤카페노란우산  일반음식점        기타  제주특별자치도 제주시 애월읍 하광로 515, 104동 102호 (자연숲)
# 2     에릭스에스프레소  일반음식점        기타                제주특별자치도 제주시 구좌읍 구좌로 77, 1층
# 3     일품순두부한림점  일반음식점        한식              제주특별자치도 제주시 한림읍 한림상로 237, 1층
# 4     팔도실비집아라점  일반음식점  식육(숯불구이)        제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)
#
#   전화번호  행정시  위도
# 0  NaN  NaN NaN
# 1  NaN  NaN NaN
# 2  NaN  NaN NaN
# 3  NaN  NaN NaN
# 4  NaN  NaN NaN

# %%
# 컬럼 추가

new_part['경도'] = np.nan
new_part.head()
# Out:
#            업소명     업종        업태                                     도로명주소  \
# 0         카페송키  일반음식점        기타           제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)
# 1  그림책방앤카페노란우산  일반음식점        기타  제주특별자치도 제주시 애월읍 하광로 515, 104동 102호 (자연숲)
# 2     에릭스에스프레소  일반음식점        기타                제주특별자치도 제주시 구좌읍 구좌로 77, 1층
# 3     일품순두부한림점  일반음식점        한식              제주특별자치도 제주시 한림읍 한림상로 237, 1층
# 4     팔도실비집아라점  일반음식점  식육(숯불구이)        제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)
#
#   전화번호  행정시  위도  경도
# 0  NaN  NaN NaN NaN
# 1  NaN  NaN NaN NaN
# 2  NaN  NaN NaN NaN
# 3  NaN  NaN NaN NaN
# 4  NaN  NaN NaN NaN

# %%
# 컬럼명 순서변경

new_part= new_part[['업소명', '업종', '업태', '행정시', '도로명주소', '전화번호', '위도', '경도']]
new_part.head()
# Out:
#            업소명     업종        업태  행정시  \
# 0         카페송키  일반음식점        기타  NaN
# 1  그림책방앤카페노란우산  일반음식점        기타  NaN
# 2     에릭스에스프레소  일반음식점        기타  NaN
# 3     일품순두부한림점  일반음식점        한식  NaN
# 4     팔도실비집아라점  일반음식점  식육(숯불구이)  NaN
#
#                                       도로명주소 전화번호  위도  경도
# 0           제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)  NaN NaN NaN
# 1  제주특별자치도 제주시 애월읍 하광로 515, 104동 102호 (자연숲)  NaN NaN NaN
# 2                제주특별자치도 제주시 구좌읍 구좌로 77, 1층  NaN NaN NaN
# 3              제주특별자치도 제주시 한림읍 한림상로 237, 1층  NaN NaN NaN
# 4        제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)  NaN NaN NaN

# %%
# csv 파일 저장

new_part.to_csv('제주특별자치도_음식점목록_병합.csv', encoding='cp949')
