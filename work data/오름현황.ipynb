# %%
# google drive 마운트
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
  
part1 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/지리/제주특별자치도_오름현황_20210707.csv', encoding='cp949')
part2 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/지리/제주특별자치도 서귀포시_이용가능오름현황_20210510.csv', encoding='cp949')

# %%
# 제주특별자치도_오름현황

print(part1.shape)
print(list(part1.columns))
part1.head()
# Out:
# (368, 8)
# ['오름명', '행정시', '소재지', '비고', '표고', '면적', '형태', '데이터기준일자']
#      오름명   행정시                          소재지   비고     표고      면적        형태  \
# 0   가마오름   제주시     제주특별자치도 제주시 한경면 청수리 1202   51  140.5  154486  말굽형(북동향)
# 1   가메오름   제주시     제주특별자치도 제주시 애월읍 봉성리 산124   17  372.2   28371       복합형
# 2    가메옥   제주시     제주특별자치도 제주시 구좌읍 송당리 1712   28  368.0   22764       복합형
# 3    가메창   제주시     제주특별자치도 제주시 한경면 저지리 1496    6  145.8   17037        원형
# 4  가문이오름  서귀포시  제주특별자치도 서귀포시 표선면 가시리 산158-2  106  496.2  116176  말굽형(남서향)
#
#       데이터기준일자
# 0  2021-07-07
# 1  2021-07-07
# 2  2021-07-07
# 3  2021-07-07
# 4  2021-07-07

# %%
# 컬럼명 변경

part1.rename(columns = {'소재지':'도로명주소'},inplace=True)
part1.head()
# Out:
#      오름명   행정시                        도로명주소   비고     표고      면적        형태  \
# 0   가마오름   제주시     제주특별자치도 제주시 한경면 청수리 1202   51  140.5  154486  말굽형(북동향)
# 1   가메오름   제주시     제주특별자치도 제주시 애월읍 봉성리 산124   17  372.2   28371       복합형
# 2    가메옥   제주시     제주특별자치도 제주시 구좌읍 송당리 1712   28  368.0   22764       복합형
# 3    가메창   제주시     제주특별자치도 제주시 한경면 저지리 1496    6  145.8   17037        원형
# 4  가문이오름  서귀포시  제주특별자치도 서귀포시 표선면 가시리 산158-2  106  496.2  116176  말굽형(남서향)
#
#       데이터기준일자
# 0  2021-07-07
# 1  2021-07-07
# 2  2021-07-07
# 3  2021-07-07
# 4  2021-07-07

# %%
# 컬럼 추가

part1['위도'] = np.nan
part1['경도'] = np.nan
part1['이용가능 여부'] = np.nan

# %%
# 컬럼명 순서변경 및 '데이터기준일자' 컬럼 삭제

part1= part1[['행정시', '오름명', '도로명주소', '위도', '경도', '비고', '표고', '면적', '형태', '이용가능 여부']]
part1.head()
# Out:
#     행정시    오름명                        도로명주소  위도  경도   비고     표고      면적  \
# 0   제주시   가마오름     제주특별자치도 제주시 한경면 청수리 1202 NaN NaN   51  140.5  154486
# 1   제주시   가메오름     제주특별자치도 제주시 애월읍 봉성리 산124 NaN NaN   17  372.2   28371
# 2   제주시    가메옥     제주특별자치도 제주시 구좌읍 송당리 1712 NaN NaN   28  368.0   22764
# 3   제주시    가메창     제주특별자치도 제주시 한경면 저지리 1496 NaN NaN    6  145.8   17037
# 4  서귀포시  가문이오름  제주특별자치도 서귀포시 표선면 가시리 산158-2 NaN NaN  106  496.2  116176
#
#          형태  이용가능 여부
# 0  말굽형(북동향)      NaN
# 1       복합형      NaN
# 2       복합형      NaN
# 3        원형      NaN
# 4  말굽형(남서향)      NaN

# %%
# 제주특별자치도 서귀포시_이용가능오름현황

print(part2.shape)
print(list(part2.columns))
part2.head()
# Out:
# (68, 9)
# ['읍면동', '오름명', '소재지', '위도', '경도', '주차장', '화장실', '표고(m)', '데이터기준일자']
#    읍면동       오름명                         소재지         위도          경도 주차장 화장실  \
# 0  대정읍  송악산(절울이)    제주특별자치도 서귀포시 대정읍 상모리 산 2  33.199409  126.290780   Y   Y
# 1  대정읍      섯알오름   제주특별자치도 서귀포시 대정읍 상모리 1618  33.204254  126.281676   Y   Y
# 2  대정읍     가시오름    제주특별자치도 서귀포시 대정읍 동일리 1209  33.253363  126.249055   N   N
# 3  대정읍       녹남봉   제주특별자치도 서귀포시 대정읍 신도리 1304  33.279815  126.195483   N   N
# 4  남원읍      물영아리  제주특별자치도 서귀포시 남원읍 수망리 산 189  33.370809  126.693520   Y   N
#
#    표고(m)     데이터기준일자
# 0  104.0  2021-05-10
# 1   40.7  2021-05-10
# 2  106.5  2021-05-10
# 3  100.4  2021-05-10
# 4  508.0  2021-05-10

# %%
# 컬럼명 변경

part2.rename(columns = {'소재지':'도로명주소'},inplace=True)
part2.head()
# Out:
#    읍면동       오름명                       도로명주소         위도          경도 주차장 화장실  \
# 0  대정읍  송악산(절울이)    제주특별자치도 서귀포시 대정읍 상모리 산 2  33.199409  126.290780   Y   Y
# 1  대정읍      섯알오름   제주특별자치도 서귀포시 대정읍 상모리 1618  33.204254  126.281676   Y   Y
# 2  대정읍     가시오름    제주특별자치도 서귀포시 대정읍 동일리 1209  33.253363  126.249055   N   N
# 3  대정읍       녹남봉   제주특별자치도 서귀포시 대정읍 신도리 1304  33.279815  126.195483   N   N
# 4  남원읍      물영아리  제주특별자치도 서귀포시 남원읍 수망리 산 189  33.370809  126.693520   Y   N
#
#    표고(m)     데이터기준일자
# 0  104.0  2021-05-10
# 1   40.7  2021-05-10
# 2  106.5  2021-05-10
# 3  100.4  2021-05-10
# 4  508.0  2021-05-10

# %%
# 컬럼 추가

part2['행정시'] = np.nan
part2['비고'] = np.nan
part2['면적'] = np.nan
part2['표고'] = np.nan
part2['형태'] = np.nan

# %%
# '이용가능 여부' 컬럼을 추가하고 'Y' 값을 추가

part2.insert(9,'이용가능 여부','Y')

# %%
# 컬럼명 순서변경 및 '데이터기준일자' 컬럼 삭제

part2= part2[['행정시', '오름명', '도로명주소', '위도', '경도', '비고', '표고', '면적', '형태', '이용가능 여부']]
part2.head()
# Out:
#    행정시       오름명                       도로명주소         위도          경도  비고  표고  \
# 0  NaN  송악산(절울이)    제주특별자치도 서귀포시 대정읍 상모리 산 2  33.199409  126.290780 NaN NaN
# 1  NaN      섯알오름   제주특별자치도 서귀포시 대정읍 상모리 1618  33.204254  126.281676 NaN NaN
# 2  NaN     가시오름    제주특별자치도 서귀포시 대정읍 동일리 1209  33.253363  126.249055 NaN NaN
# 3  NaN       녹남봉   제주특별자치도 서귀포시 대정읍 신도리 1304  33.279815  126.195483 NaN NaN
# 4  NaN      물영아리  제주특별자치도 서귀포시 남원읍 수망리 산 189  33.370809  126.693520 NaN NaN
#
#    면적  형태 이용가능 여부
# 0 NaN NaN       Y
# 1 NaN NaN       Y
# 2 NaN NaN       Y
# 3 NaN NaN       Y
# 4 NaN NaN       Y

# %% [markdown]
# # part1 + par2 병합

# %%
new_part = pd.concat([part1, part2])
print(new_part.shape)
print(list(new_part.columns))
new_part.head()
# Out:
# (436, 10)
# ['행정시', '오름명', '도로명주소', '위도', '경도', '비고', '표고', '면적', '형태', '이용가능 여부']
#     행정시    오름명                        도로명주소  위도  경도     비고     표고        면적  \
# 0   제주시   가마오름     제주특별자치도 제주시 한경면 청수리 1202 NaN NaN   51.0  140.5  154486.0
# 1   제주시   가메오름     제주특별자치도 제주시 애월읍 봉성리 산124 NaN NaN   17.0  372.2   28371.0
# 2   제주시    가메옥     제주특별자치도 제주시 구좌읍 송당리 1712 NaN NaN   28.0  368.0   22764.0
# 3   제주시    가메창     제주특별자치도 제주시 한경면 저지리 1496 NaN NaN    6.0  145.8   17037.0
# 4  서귀포시  가문이오름  제주특별자치도 서귀포시 표선면 가시리 산158-2 NaN NaN  106.0  496.2  116176.0
#
#          형태 이용가능 여부
# 0  말굽형(북동향)     NaN
# 1       복합형     NaN
# 2       복합형     NaN
# 3        원형     NaN
# 4  말굽형(남서향)     NaN

# %%
# 컬럼별로 중복데이터 여부 확인

new_part['오름명'].value_counts()
# Out:
# 민오름      5
# 붉은오름     4
# 밝은오름     4
# 알오름      3
# 논오름      3
#         ..
# 물장오리     1
# 물오름      1
# 물메       1
# 문석이오름    1
# 베릿내오름    1
# Name: 오름명, Length: 370, dtype: int64

# %%
# 중복 발생

new_part[new_part.오름명 == '민오름']
# Out:
#       행정시  오름명                      도로명주소         위도          경도     비고  \
# 152  서귀포시  민오름  제주특별자치도 서귀포시 남원읍 수망리 158         NaN         NaN   97.0
# 153   제주시  민오름  제주특별자치도 제주시 구좌읍 송당리 산156         NaN         NaN  102.0
# 154   제주시  민오름       제주특별자치도 제주시 오라이동 산28        NaN         NaN  117.0
# 155   제주시  민오름   제주특별자치도 제주시 조천읍 선흘리 산141        NaN         NaN  118.0
# 8     NaN  민오름   제주특별자치도 서귀포시 남원읍 수망리 158  33.350883  126.698013    NaN
#
#         표고        면적        형태 이용가능 여부
# 152  446.8  371170.0   말굽형(동향)     NaN
# 153  362.0  412245.0  말굽형(북동향)     NaN
# 154  251.7  474001.0  말굽형(북동향)     NaN
# 155  518.3  400724.0       복합형     NaN
# 8      NaN       NaN       NaN       Y

# %%
# 오름명, 도로명주소가 같으면 위도, 경도, 이용가능 여부 추가?
