# %%
# google drive 마운트
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
  
part1 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/숙박/제주특별자치도_숙박업현황_01_02_2020.csv', encoding='cp949')
part2 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1차 병합본/숙박/제주특별자치도_관광숙박업현황_병합.csv', encoding='cp949')
part3 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1차 병합본/숙박/제주특별자치도_서귀포시_호텔업+휴양펜션업_병합.csv', encoding='cp949')

# %%
print(part1.shape)
print(list(part1.columns))
part1.head()
# Out:
# (1335, 5)
# ['행정시', '업소명', '소재지', '전화번호', '데이터기준일자']
#     행정시       업소명                        소재지           전화번호     데이터기준일자
# 0  서귀포시   위(WE)호텔  제주특별자치도 서귀포시 1100로 453-95   064-730-1200  2020-01-02
# 1  서귀포시  이에스제주리조트     제주특별자치도 서귀포시 1100로 501  070-4548-0285  2020-01-02
# 2  서귀포시   천백 휴양펜션       제주특별자치도 서귀포시 1100로 6   064-738-3234  2020-01-02
# 3  서귀포시     모이라펜션      제주특별자치도 서귀포시 516로 296   064-732-0005  2020-01-02
# 4  서귀포시  빅토르힐 리조트  제주특별자치도 서귀포시 516로277번길 45   064-780-6300  2020-01-02

# %%
print(part2.shape)
print(list(part2.columns))
part2.head()
# Out:
# (631, 9)
# ['Unnamed: 0', '상호명', '구분', '행정시', '도로명주소', '전화번호', '위도', '경도', '객실수']
#    Unnamed: 0                  상호명     구분  행정시                도로명주소  \
# 0           0  글래드호텔앤리조트(주)메종글래드제주  관광호텔업  NaN   제주특별자치도 제주시 노연로 80
# 1           1             제주오리엔탈호텔  관광호텔업  NaN   제주특별자치도 제주시 탑동로 47
# 2           2              제주KAL호텔  관광호텔업  NaN  제주특별자치도 제주시 중앙로 151
# 3           3                제주썬호텔  관광호텔업  NaN   제주특별자치도 제주시 삼무로 67
# 4           4              제주퍼시픽호텔  관광호텔업  NaN   제주특별자치도 제주시 서사로 20
#
#            전화번호  위도  경도  객실수
# 0  064-747-5000 NaN NaN  513
# 1  064-752-8222 NaN NaN  321
# 2  064-724-2001 NaN NaN  282
# 3  064-741-8000 NaN NaN  203
# 4  064-758-2500 NaN NaN  177

# %%
print(part3.shape)
print(list(part3.columns))
part3.head()
# Out:
# (152, 9)
# ['Unnamed: 0', '상호명', '구분', '행정시', '도로명주소', '전화번호', '위도', '경도', '객실수']
#    Unnamed: 0         상호명     구분  행정시                         도로명주소  \
# 0           0    그랑빌 가족호텔  가족호텔업  NaN         제주특별자치도 서귀포시 중문관광로 17
# 1           1  중문빌리지 가족호텔  가족호텔업  NaN          제주특별자치도 서귀포시 예래로 270
# 2           2       송악리조트  가족호텔업  NaN  제주특별자치도 서귀포시 대정읍 형제해안로 256-5
# 3           3         담앤루  가족호텔업  NaN     제주특별자치도 서귀포시 이어도로343번길 63
# 4           4      뷰티플리조트  가족호텔업  NaN      제주특별자치도 서귀포시 이어도로253번길 2
#
#            전화번호         위도          경도  객실수
# 0  064-739-9994  33.256391  126.415264   42
# 1  064-738-3151  33.242725  126.385131   30
# 2  064-794-6307  33.211724  126.291503   30
# 3  064-739-6617  33.245852  126.451468   43
# 4  064-738-7407  33.243713  126.446666   32

# %% [markdown]
# # Part2 + part3 병합

# %%
print(part2.shape)
print(list(part2.columns))
part2.head()
# Out:
# (631, 9)
# ['Unnamed: 0', '상호명', '구분', '행정시', '도로명주소', '전화번호', '위도', '경도', '객실수']
#    Unnamed: 0                  상호명     구분  행정시                도로명주소  \
# 0           0  글래드호텔앤리조트(주)메종글래드제주  관광호텔업  NaN   제주특별자치도 제주시 노연로 80
# 1           1             제주오리엔탈호텔  관광호텔업  NaN   제주특별자치도 제주시 탑동로 47
# 2           2              제주KAL호텔  관광호텔업  NaN  제주특별자치도 제주시 중앙로 151
# 3           3                제주썬호텔  관광호텔업  NaN   제주특별자치도 제주시 삼무로 67
# 4           4              제주퍼시픽호텔  관광호텔업  NaN   제주특별자치도 제주시 서사로 20
#
#            전화번호  위도  경도  객실수
# 0  064-747-5000 NaN NaN  513
# 1  064-752-8222 NaN NaN  321
# 2  064-724-2001 NaN NaN  282
# 3  064-741-8000 NaN NaN  203
# 4  064-758-2500 NaN NaN  177

# %%
# 누락 데이터 확인

part2.count()
# Out:
# Unnamed: 0    631
# 상호명           631
# 구분            631
# 행정시             0
# 도로명주소         631
# 전화번호          624
# 위도              0
# 경도              0
# 객실수           631
# dtype: int64

# %%
# 누락 데이터 확인

part2.isnull().sum()
# Out:
# Unnamed: 0      0
# 상호명             0
# 구분              0
# 행정시           631
# 도로명주소           0
# 전화번호            7
# 위도            631
# 경도            631
# 객실수             0
# dtype: int64

# %%
print(part3.shape)
print(list(part3.columns))
part3.head()
# Out:
# (152, 9)
# ['Unnamed: 0', '상호명', '구분', '행정시', '도로명주소', '전화번호', '위도', '경도', '객실수']
#    Unnamed: 0         상호명     구분  행정시                         도로명주소  \
# 0           0    그랑빌 가족호텔  가족호텔업  NaN         제주특별자치도 서귀포시 중문관광로 17
# 1           1  중문빌리지 가족호텔  가족호텔업  NaN          제주특별자치도 서귀포시 예래로 270
# 2           2       송악리조트  가족호텔업  NaN  제주특별자치도 서귀포시 대정읍 형제해안로 256-5
# 3           3         담앤루  가족호텔업  NaN     제주특별자치도 서귀포시 이어도로343번길 63
# 4           4      뷰티플리조트  가족호텔업  NaN      제주특별자치도 서귀포시 이어도로253번길 2
#
#            전화번호         위도          경도  객실수
# 0  064-739-9994  33.256391  126.415264   42
# 1  064-738-3151  33.242725  126.385131   30
# 2  064-794-6307  33.211724  126.291503   30
# 3  064-739-6617  33.245852  126.451468   43
# 4  064-738-7407  33.243713  126.446666   32

# %%
# 누락 데이터 확인

part3.count()
# Out:
# Unnamed: 0    152
# 상호명           152
# 구분             76
# 행정시             0
# 도로명주소         152
# 전화번호          138
# 위도            152
# 경도            152
# 객실수           152
# dtype: int64

# %%
# 누락 데이터 확인

part3.isnull().sum()
# Out:
# Unnamed: 0      0
# 상호명             0
# 구분             76
# 행정시           152
# 도로명주소           0
# 전화번호           14
# 위도              0
# 경도              0
# 객실수             0
# dtype: int64

# %%
new_part = pd.concat([part2, part3])

# %%
print(new_part.shape)
print(list(new_part.columns))
new_part.head()
# Out:
# (783, 9)
# ['Unnamed: 0', '상호명', '구분', '행정시', '도로명주소', '전화번호', '위도', '경도', '객실수']
#    Unnamed: 0                  상호명     구분  행정시                도로명주소  \
# 0           0  글래드호텔앤리조트(주)메종글래드제주  관광호텔업  NaN   제주특별자치도 제주시 노연로 80
# 1           1             제주오리엔탈호텔  관광호텔업  NaN   제주특별자치도 제주시 탑동로 47
# 2           2              제주KAL호텔  관광호텔업  NaN  제주특별자치도 제주시 중앙로 151
# 3           3                제주썬호텔  관광호텔업  NaN   제주특별자치도 제주시 삼무로 67
# 4           4              제주퍼시픽호텔  관광호텔업  NaN   제주특별자치도 제주시 서사로 20
#
#            전화번호  위도  경도  객실수
# 0  064-747-5000 NaN NaN  513
# 1  064-752-8222 NaN NaN  321
# 2  064-724-2001 NaN NaN  282
# 3  064-741-8000 NaN NaN  203
# 4  064-758-2500 NaN NaN  177

# %%
# 'Unnamed: 0' 삭제

new_part = new_part.drop(['Unnamed: 0'], axis=1)
new_part
# Out:
#                      상호명     구분  행정시                            도로명주소  \
# 0    글래드호텔앤리조트(주)메종글래드제주  관광호텔업  NaN               제주특별자치도 제주시 노연로 80
# 1               제주오리엔탈호텔  관광호텔업  NaN               제주특별자치도 제주시 탑동로 47
# 2                제주KAL호텔  관광호텔업  NaN              제주특별자치도 제주시 중앙로 151
# 3                  제주썬호텔  관광호텔업  NaN               제주특별자치도 제주시 삼무로 67
# 4                제주퍼시픽호텔  관광호텔업  NaN               제주특별자치도 제주시 서사로 20
# ..                   ...    ...  ...                              ...
# 147         오션브릭풀빌라 휴양펜션    NaN  NaN        제주특별자치도 서귀포시 안덕면 산방로 75-3
# 148             하이재 휴양펜션    NaN  NaN     제주특별자치도 서귀포시 성산읍 신풍하동로19번길 5
# 149             더라온 휴양펜션    NaN  NaN     제주특별자치도 서귀포시 표선면 번영로 2587-43
# 150          제주 아이니 휴양펜션    NaN  NaN  제주특별자치도 서귀포시 남원읍 태위로894번길 20-30
# 151         C&p 리조트 휴양펜션    NaN  NaN   제주특별자치도 서귀포시 성산읍 중산간동로 4328-63
#
#              전화번호         위도          경도  객실수
# 0    064-747-5000        NaN         NaN  513
# ...

# %%
# 누락 데이터 확인

new_part.count()
# Out:
# 상호명      783
# 구분       707
# 행정시        0
# 도로명주소    783
# 전화번호     762
# 위도       152
# 경도       152
# 객실수      783
# dtype: int64

# %%
# 누락 데이터 확인

new_part.isnull().sum()
# Out:
# 상호명        0
# 구분        76
# 행정시      783
# 도로명주소      0
# 전화번호      21
# 위도       631
# 경도       631
# 객실수        0
# dtype: int64

# %%
new_part.duplicated(['상호명', '도로명주소', '객실수', '전화번호'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 147    False
# 148    False
# 149    False
# 150    False
# 151    False
# Length: 783, dtype: bool

# %%
# 완전히 동일한 중복데이터 여부 확인

new_part.duplicated(['상호명', '도로명주소', '객실수', '전화번호']).sum()
# Out:
# 231

# %%
# 중복 데이터 개수 파악

new_part[new_part.duplicated(['상호명', '도로명주소', '객실수', '전화번호'])==True]
# Out:
#                   상호명       구분  행정시                           도로명주소  \
# 425          제주오리엔탈호텔    관광호텔업  NaN              제주특별자치도 제주시 탑동로 47
# 431           제주선샤인호텔    관광호텔업  NaN       제주특별자치도 제주시 조천읍 신북로 481-9
# 433          제주서울관광호텔    관광호텔업  NaN               제주특별자치도 제주시 탑동로 5
# 434         제주팔레스관광호텔    관광호텔업  NaN               제주특별자치도 제주시 탑동로 9
# 440            금룡관광호텔    관광호텔업  NaN              제주특별자치도 제주시 삼무로 79
# ..                ...      ...  ...                             ...
# 71           HOTEL 52    소형호텔업  NaN     제주특별자치도 서귀포시 대정읍 신영로36번길 35
# 72             모슬포1호텔    소형호텔업  NaN  제주특별자치도 서귀포시 대정읍 최남단해안로30번길 11
# 73             모슬포2호텔    소형호텔업  NaN  제주특별자치도 서귀포시 대정읍 최남단해안로30번길 13
# 74             모슬포3호텔    소형호텔업  NaN  제주특별자치도 서귀포시 대정읍 최남단해안로30번길 15
# 75   씨에스개발㈜ 씨에스호텔앤리조트  한국전통호텔업  NaN          제주특별자치도 서귀포시 중문관광로 198
#
#              전화번호         위도          경도  객실수
# 425  064-752-8222        NaN         NaN  321
# 431  064-784-2525        NaN         NaN   72
# ...

# %%
# 중복된 데이터 삭제

new_part.drop_duplicates(['상호명', '도로명주소', '객실수', '전화번호'])
# Out:
#                      상호명     구분  행정시                            도로명주소  \
# 0    글래드호텔앤리조트(주)메종글래드제주  관광호텔업  NaN               제주특별자치도 제주시 노연로 80
# 1               제주오리엔탈호텔  관광호텔업  NaN               제주특별자치도 제주시 탑동로 47
# 2                제주KAL호텔  관광호텔업  NaN              제주특별자치도 제주시 중앙로 151
# 3                  제주썬호텔  관광호텔업  NaN               제주특별자치도 제주시 삼무로 67
# 4                제주퍼시픽호텔  관광호텔업  NaN               제주특별자치도 제주시 서사로 20
# ..                   ...    ...  ...                              ...
# 147         오션브릭풀빌라 휴양펜션    NaN  NaN        제주특별자치도 서귀포시 안덕면 산방로 75-3
# 148             하이재 휴양펜션    NaN  NaN     제주특별자치도 서귀포시 성산읍 신풍하동로19번길 5
# 149             더라온 휴양펜션    NaN  NaN     제주특별자치도 서귀포시 표선면 번영로 2587-43
# 150          제주 아이니 휴양펜션    NaN  NaN  제주특별자치도 서귀포시 남원읍 태위로894번길 20-30
# 151         C&p 리조트 휴양펜션    NaN  NaN   제주특별자치도 서귀포시 성산읍 중산간동로 4328-63
#
#              전화번호         위도          경도  객실수
# 0    064-747-5000        NaN         NaN  513
# ...

# %% [markdown]
# # part1 = 제주특별자치도_숙박업현황

# %%
print(part1.shape)
print(list(part1.columns))
part1.head()
# Out:
# (1335, 5)
# ['행정시', '업소명', '소재지', '전화번호', '데이터기준일자']
#     행정시       업소명                        소재지           전화번호     데이터기준일자
# 0  서귀포시   위(WE)호텔  제주특별자치도 서귀포시 1100로 453-95   064-730-1200  2020-01-02
# 1  서귀포시  이에스제주리조트     제주특별자치도 서귀포시 1100로 501  070-4548-0285  2020-01-02
# 2  서귀포시   천백 휴양펜션       제주특별자치도 서귀포시 1100로 6   064-738-3234  2020-01-02
# 3  서귀포시     모이라펜션      제주특별자치도 서귀포시 516로 296   064-732-0005  2020-01-02
# 4  서귀포시  빅토르힐 리조트  제주특별자치도 서귀포시 516로277번길 45   064-780-6300  2020-01-02

# %%
# 컬럼명 변경

part1.rename(columns = {'소재지':'도로명주소', '업소명':'상호명'},inplace=True)
part1.head()
# Out:
#     행정시       상호명                      도로명주소           전화번호     데이터기준일자
# 0  서귀포시   위(WE)호텔  제주특별자치도 서귀포시 1100로 453-95   064-730-1200  2020-01-02
# 1  서귀포시  이에스제주리조트     제주특별자치도 서귀포시 1100로 501  070-4548-0285  2020-01-02
# 2  서귀포시   천백 휴양펜션       제주특별자치도 서귀포시 1100로 6   064-738-3234  2020-01-02
# 3  서귀포시     모이라펜션      제주특별자치도 서귀포시 516로 296   064-732-0005  2020-01-02
# 4  서귀포시  빅토르힐 리조트  제주특별자치도 서귀포시 516로277번길 45   064-780-6300  2020-01-02

# %%
# '데이터기준일자' 제거

part1 = part1.drop(['데이터기준일자'], axis=1)
part1
# Out:
#        행정시       상호명                      도로명주소           전화번호
# 0     서귀포시   위(WE)호텔  제주특별자치도 서귀포시 1100로 453-95   064-730-1200
# 1     서귀포시  이에스제주리조트     제주특별자치도 서귀포시 1100로 501  070-4548-0285
# 2     서귀포시   천백 휴양펜션       제주특별자치도 서귀포시 1100로 6   064-738-3234
# 3     서귀포시     모이라펜션      제주특별자치도 서귀포시 516로 296   064-732-0005
# 4     서귀포시  빅토르힐 리조트  제주특별자치도 서귀포시 516로277번길 45   064-780-6300
# ...    ...       ...                        ...            ...
# 1330   제주시   레드월 호스텔         제주특별자치도 제주시 현사길 33   064-743-6444
# 1331   제주시    에바다호스텔         제주특별자치도 제주시 현사길 45   064-744-1398
# 1332   제주시        오름        제주특별자치도 제주시 홍랑길 4-4   064-757-4690
# 1333   제주시     힐링하우스        제주특별자치도 제주시 홍랑길 4-6   064-745-0600
# 1334   제주시        용연       제주특별자치도 제주시 흥운길 63-6   064-711-2661
#
# [1335 rows x 4 columns]

# %%
# 누락 데이터 확인

part1.count()
# Out:
# 행정시      1335
# 상호명      1335
# 도로명주소    1335
# 전화번호     1201
# dtype: int64

# %%
# 누락 데이터 확인

part1.isnull().sum()
# Out:
# 행정시        0
# 상호명        0
# 도로명주소      0
# 전화번호     134
# dtype: int64

# %%
# 완전히 동일한 중복데이터 여부 확인

part1.duplicated().sum()
# Out:
# 0

# %%
# 컬럼별로 중복데이터 여부 확인

part1['행정시'].value_counts()
# Out:
# 제주시     810
# 서귀포시    525
# Name: 행정시, dtype: int64

# %%
# 컬럼별로 중복데이터 여부 확인

part1['상호명'].value_counts()
# Out:
# 태흥여관         2
# 한성           2
# 제주스테이        2
# 제주토비스콘도      2
# (주)호텔알리앙스    2
#             ..
# 더루케테호텔       1
# 피노호텔         1
# 마이모텔         1
# 테마모텔         1
# 용연           1
# Name: 상호명, Length: 1324, dtype: int64

# %%
# 중복 발생
# 한 상호명에 여러 업을 운영할 수도 있다고 판단해서 중복 삭제 안함

part1[part1.상호명 == '태흥여관']
# Out:
#        행정시   상호명                    도로명주소          전화번호
# 419   서귀포시  태흥여관  제주특별자치도 서귀포시 중정로91번길 54  064-762-0110
# 1230   제주시  태흥여관   제주특별자치도 제주시 추자면 추자로 34  064-712-5600

# %%
# 중복 발생
# 한 상호명에 여러 업을 운영할 수도 있다고 판단해서 중복 삭제 안함

part1[part1.상호명 == '한성']
# Out:
#       행정시 상호명                 도로명주소          전화번호
# 786   제주시  한성  제주특별자치도 제주시 서광로24길 2  064-758-0667
# 1210  제주시  한성  제주특별자치도 제주시 중앙로22길 3  064-722-0519

# %%
# 중복 발생
# 한 상호명에 여러 업을 운영할 수도 있다고 판단해서 중복 삭제 안함

part1[part1.상호명 == '제주스테이']
# Out:
#       행정시    상호명                    도로명주소          전화번호
# 189  서귀포시  제주스테이  제주특별자치도 서귀포시 성산읍 신고로 11  064-783-8877
# 713   제주시  제주스테이     제주특별자치도 제주시 무근성7길 22  064-752-8870

# %%
# 중복 발생
# 한 상호명에 여러 업을 운영할 수도 있다고 판단해서 중복 삭제 안함

part1[part1.상호명 == '제주토비스콘도']
# Out:
#      행정시      상호명                    도로명주소          전화번호
# 967  제주시  제주토비스콘도  제주특별자치도 제주시 애월읍 애월로1길 8  064-799-4400
# 968  제주시  제주토비스콘도  제주특별자치도 제주시 애월읍 애월로1길 8  064-799-9905

# %%
# 중복 발생
# 한 상호명에 여러 업을 운영할 수도 있다고 판단해서 중복 삭제 안함

part1[part1.상호명 == '(주)호텔알리앙스']
# Out:
#      행정시        상호명                    도로명주소          전화번호
# 851  제주시  (주)호텔알리앙스     제주특별자치도 제주시 서해안로 380  064-712-3200
# 925  제주시  (주)호텔알리앙스  제주특별자치도 제주시 애월읍 곽지1길 23  064-799-2345

# %%
# 컬럼별로 중복데이터 여부 확인

part1['도로명주소'].value_counts()
# Out:
# 제주특별자치도 서귀포시 표선면 일주동로 6347-17    2
# 제주특별자치도 서귀포시 표선면 돈오름로 170        2
# 제주특별자치도 서귀포시 칠십리로 61-1           2
# 제주특별자치도 제주시 애월읍 애월로1길 8          2
# 제주특별자치도 제주시 한림읍 금능남로 127         2
#                                 ..
# 제주특별자치도 서귀포시 최영로 20-5            1
# 제주특별자치도 서귀포시 천지연로29번길 8          1
# 제주특별자치도 서귀포시 천지연로29번길 5          1
# 제주특별자치도 서귀포시 천지연로29번길 12         1
# 제주특별자치도 제주시 흥운길 63-6             1
# Name: 도로명주소, Length: 1319, dtype: int64

# %%
# 중복 발생
# 한 도로명주소에 여러 업소가 있을 수 있다고 판단해서 중복 삭제 안함

part1[part1.도로명주소 == '제주특별자치도 서귀포시 표선면 일주동로 6347-17']
# Out:
#       행정시         상호명                          도로명주소          전화번호
# 505  서귀포시    대명샤인빌리조트  제주특별자치도 서귀포시 표선면 일주동로 6347-17  064-780-7000
# 506  서귀포시  대명샤인빌리조트2차  제주특별자치도 서귀포시 표선면 일주동로 6347-17  064-780-7000

# %%
# 중복 발생
# 한 도로명주소에 여러 업소가 있을 수 있다고 판단해서 중복 삭제 안함

part1[part1.도로명주소 == '제주특별자치도 서귀포시 표선면 돈오름로 170']
# Out:
#       행정시     상호명                      도로명주소          전화번호
# 490  서귀포시   인간과허브  제주특별자치도 서귀포시 표선면 돈오름로 170  064-787-7364
# 491  서귀포시  제주허브동산  제주특별자치도 서귀포시 표선면 돈오름로 170  064-787-7364

# %%
# 중복 발생
# 한 도로명주소에 여러 업소가 있을 수 있다고 판단해서 중복 삭제 안함

part1[part1.도로명주소 == '제주특별자치도 서귀포시 칠십리로 61-1']
# Out:
#       행정시        상호명                   도로명주소          전화번호
# 451  서귀포시  서귀포섬이야기펜션  제주특별자치도 서귀포시 칠십리로 61-1           NaN
# 452  서귀포시    섬게스트하우스  제주특별자치도 서귀포시 칠십리로 61-1  064-732-1313

# %%
# 중복 발생
# 한 도로명주소에 여러 업소가 있을 수 있다고 판단해서 중복 삭제 안함

part1[part1.도로명주소 == '제주특별자치도 제주시 애월읍 애월로1길 8']
# Out:
#      행정시      상호명                    도로명주소          전화번호
# 967  제주시  제주토비스콘도  제주특별자치도 제주시 애월읍 애월로1길 8  064-799-4400
# 968  제주시  제주토비스콘도  제주특별자치도 제주시 애월읍 애월로1길 8  064-799-9905

# %%
# 중복 발생
# 한 도로명주소에 여러 업소가 있을 수 있다고 판단해서 중복 삭제 안함

part1[part1.도로명주소 == '제주특별자치도 제주시 한림읍 금능남로 127']
# Out:
#       행정시       상호명                     도로명주소          전화번호
# 1268  제주시  라온프라이빗타운  제주특별자치도 제주시 한림읍 금능남로 127  064-795-3000
# 1269  제주시    호텔라온제주  제주특별자치도 제주시 한림읍 금능남로 127  064-795-3000

# %%
# 컬럼별로 중복데이터 여부 확인

part1['전화번호'].value_counts()
# Out:
# 064-784-7337    4
# 064-745-5588    4
# 064-792-6678    3
# 064-717-7300    3
# 064-722-3070    2
#                ..
# 064-800-6000    1
# 064-732-7707    1
# 064-762-8914    1
# 064-762-3528    1
# 064-711-2661    1
# Name: 전화번호, Length: 1159, dtype: int64

# %%
# 중복 발생
# 여러 업소의 소재지가 매우 유사해서 동일한 전화번호로 운영하고 있을 수 있다고 판단해서 중복 삭제 안함

part1[part1.전화번호 == '064-784-7337']
# Out:
#       행정시     상호명                         도로명주소          전화번호
# 166  서귀포시   탐라리조트  제주특별자치도 서귀포시 성산읍 서성일로 726-31  064-784-7337
# 167  서귀포시  제주원리조트  제주특별자치도 서귀포시 성산읍 서성일로 726-33  064-784-7337
# 168  서귀포시   성산호스텔  제주특별자치도 서귀포시 성산읍 서성일로 726-35  064-784-7337
# 169  서귀포시   오라호스텔  제주특별자치도 서귀포시 성산읍 서성일로 726-37  064-784-7337

# %%
# 중복 발생
# 여러 업소의 소재지가 매우 유사해서 동일한 전화번호로 운영하고 있을 수 있다고 판단해서 중복 삭제 안함

part1[part1.전화번호 == '064-745-5588']
# Out:
#       행정시    상호명                  도로명주소          전화번호
# 1063  제주시   에코리사   제주특별자치도 제주시 원노형2길 34  064-745-5588
# 1076  제주시  에코드반트  제주특별자치도 제주시 원노형남1길 12  064-745-5588
# 1077  제주시   에코세잔   제주특별자치도 제주시 원노형남1길 4  064-745-5588
# 1128  제주시   에코퓨리     제주특별자치도 제주시 제원길 17  064-745-5588

# %%
# 중복 발생
# 여러 업소의 소재지가 매우 유사해서 동일한 전화번호로 운영하고 있을 수 있다고 판단해서 중복 삭제 안함

part1[part1.전화번호 == '064-792-6678']
# Out:
#       행정시      상호명                          도로명주소          전화번호
# 297  서귀포시      담모라  제주특별자치도 서귀포시 안덕면 일주서로 1975-11  064-792-6678
# 298  서귀포시  담모라휴양펜션  제주특별자치도 서귀포시 안덕면 일주서로 1975-17  064-792-6678
# 299  서귀포시    담모라호텔  제주특별자치도 서귀포시 안덕면 일주서로 1975-19  064-792-6678

# %%
# 중복 발생
# 여러 업소의 소재지가 매우 유사해서 동일한 전화번호로 운영하고 있을 수 있다고 판단해서 중복 삭제 안함

part1[part1.전화번호 == '064-717-7300']
# Out:
#       행정시      상호명                       도로명주소          전화번호
# 218  서귀포시     오션그린  제주특별자치도 서귀포시 성산읍 환해장성로 665  064-717-7300
# 219  서귀포시    오션스퀘어  제주특별자치도 서귀포시 성산읍 환해장성로 667  064-717-7300
# 220  서귀포시  온평오션스퀘어  제주특별자치도 서귀포시 성산읍 환해장성로 669  064-717-7300

# %%
# 중복 발생
# 여러 업소의 소재지가 매우 유사해서 동일한 전화번호로 운영하고 있을 수 있다고 판단해서 중복 삭제 안함

part1[part1.전화번호 == '064-722-3070']
# Out:
#       행정시   상호명                  도로명주소          전화번호
# 555   제주시  대동호텔   제주특별자치도 제주시 관덕로15길 6  064-722-3070
# 1236  제주시    우성  제주특별자치도 제주시 칠성로길 37-1  064-722-3070

# %%
# 연락처 결측값 찾기

part1.loc[part1['전화번호'].isna()]
# Out:
#        행정시         상호명                          도로명주소 전화번호
# 15    서귀포시         굿데이        제주특별자치도 서귀포시 남성로115번길 2  NaN
# 31    서귀포시        펜션정원     제주특별자치도 서귀포시 남원읍 일주동로 6523  NaN
# 32    서귀포시        별빛하늘    제주특별자치도 서귀포시 남원읍 중산간동로 6264  NaN
# 50    서귀포시     가파도하우스1  제주특별자치도 서귀포시 대정읍 가파로 271번길 14  NaN
# 51    서귀포시     가파도하우스2   제주특별자치도 서귀포시 대정읍 가파로67번길 9-4  NaN
# ...    ...         ...                            ...  ...
# 1271   제주시         포에마         제주특별자치도 제주시 한림읍 명월로 13  NaN
# 1285   제주시         수평선        제주특별자치도 제주시 한림읍 한림로 328  NaN
# 1287   제주시  블루스프링부띠끄호텔        제주특별자치도 제주시 한림읍 한림로 330  NaN
# 1288   제주시       르메인호텔        제주특별자치도 제주시 한림읍 한림로 392  NaN
# 1290   제주시        육칠오팔        제주특별자치도 제주시 한림읍 한림로 648  NaN
#
# [134 rows x 4 columns]

# %% [markdown]
# # part1 + new_part 병합

# %%
final_part = pd.concat([part1, new_part])

# %%
print(final_part.shape)
print(list(final_part.columns))
final_part.head()
# Out:
# (2118, 8)
# ['행정시', '상호명', '도로명주소', '전화번호', '구분', '위도', '경도', '객실수']
#     행정시       상호명                      도로명주소           전화번호   구분  위도  경도  객실수
# 0  서귀포시   위(WE)호텔  제주특별자치도 서귀포시 1100로 453-95   064-730-1200  NaN NaN NaN  NaN
# 1  서귀포시  이에스제주리조트     제주특별자치도 서귀포시 1100로 501  070-4548-0285  NaN NaN NaN  NaN
# 2  서귀포시   천백 휴양펜션       제주특별자치도 서귀포시 1100로 6   064-738-3234  NaN NaN NaN  NaN
# 3  서귀포시     모이라펜션      제주특별자치도 서귀포시 516로 296   064-732-0005  NaN NaN NaN  NaN
# 4  서귀포시  빅토르힐 리조트  제주특별자치도 서귀포시 516로277번길 45   064-780-6300  NaN NaN NaN  NaN

# %%
# 완전히 동일한 중복데이터 여부 확인

final_part.duplicated(['상호명', '도로명주소', '전화번호']).sum()
# Out:
# 375

# %%
# '상호명', '소재지', '연락처' 컬럼인 중복된 행 삭제

final_part14 = final_part.drop_duplicates(['상호명', '도로명주소', '전화번호'])

# %%
# 중복 데이터 개수 파악

final_part[final_part.duplicated(['상호명', '도로명주소', '전화번호'])==True]
# Out:
#      행정시                  상호명                       도로명주소          전화번호  \
# 0    NaN  글래드호텔앤리조트(주)메종글래드제주          제주특별자치도 제주시 노연로 80  064-747-5000
# 7    NaN              제주선샤인호텔   제주특별자치도 제주시 조천읍 신북로 481-9  064-784-2525
# 22   NaN                메이더호텔   제주특별자치도 제주시 구좌읍 일주동로 1626  064-766-8888
# 25   NaN             뉴맨하탄관광호텔          제주특별자치도 제주시 도령로 66  064-742-7991
# 33   NaN               올레관광호텔         제주특별자치도 제주시 서광로 254  064-723-2727
# ..   ...                  ...                         ...           ...
# 129  NaN              천백 휴양펜션        제주특별자치도 서귀포시 1100로 6  064-738-3234
# 134  NaN                 바라크라  제주특별자치도 서귀포시 칠십리로504번길 8-4  064-733-3136
# 136  NaN                남극노인성       제주특별자치도 서귀포시 하신상로 216  064-733-8869
# 137  NaN                모이라펜션       제주특별자치도 서귀포시 516로 296  064-732-0005
# 142  NaN                  굿데이     제주특별자치도 서귀포시 남성로115번길 2           NaN
#
#         구분         위도          경도    객실수
# 0    관광호텔업        NaN         NaN  513.0
# ...

# %%
# '상호명', '소재지', '연락처' 컬럼인 중복된 행 삭제

final_part = final_part.drop_duplicates(['상호명', '도로명주소', '전화번호'])

# %%
# 컬럼명 순서변경

final_part= final_part[['상호명', '구분', '행정시', '도로명주소', '전화번호', '위도', '경도', '객실수']]
final_part.head()
# Out:
#         상호명   구분   행정시                      도로명주소           전화번호  위도  경도  객실수
# 0   위(WE)호텔  NaN  서귀포시  제주특별자치도 서귀포시 1100로 453-95   064-730-1200 NaN NaN  NaN
# 1  이에스제주리조트  NaN  서귀포시     제주특별자치도 서귀포시 1100로 501  070-4548-0285 NaN NaN  NaN
# 2   천백 휴양펜션  NaN  서귀포시       제주특별자치도 서귀포시 1100로 6   064-738-3234 NaN NaN  NaN
# 3     모이라펜션  NaN  서귀포시      제주특별자치도 서귀포시 516로 296   064-732-0005 NaN NaN  NaN
# 4  빅토르힐 리조트  NaN  서귀포시  제주특별자치도 서귀포시 516로277번길 45   064-780-6300 NaN NaN  NaN

# %%
print(final_part.shape)
print(list(final_part.columns))
final_part.head()
# Out:
# (1743, 8)
# ['상호명', '구분', '행정시', '도로명주소', '전화번호', '위도', '경도', '객실수']
#         상호명   구분   행정시                      도로명주소           전화번호  위도  경도  객실수
# 0   위(WE)호텔  NaN  서귀포시  제주특별자치도 서귀포시 1100로 453-95   064-730-1200 NaN NaN  NaN
# 1  이에스제주리조트  NaN  서귀포시     제주특별자치도 서귀포시 1100로 501  070-4548-0285 NaN NaN  NaN
# 2   천백 휴양펜션  NaN  서귀포시       제주특별자치도 서귀포시 1100로 6   064-738-3234 NaN NaN  NaN
# 3     모이라펜션  NaN  서귀포시      제주특별자치도 서귀포시 516로 296   064-732-0005 NaN NaN  NaN
# 4  빅토르힐 리조트  NaN  서귀포시  제주특별자치도 서귀포시 516로277번길 45   064-780-6300 NaN NaN  NaN

# %%
# csv 파일 저장

final_part.to_csv('제주특별자치도_숙박_병합.csv', encoding='cp949')
