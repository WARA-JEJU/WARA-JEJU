# %%
# google drive 마운트
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
  
part1 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/지리/제주특별자치도_오름현황_20210707.csv', encoding='cp949')
part2 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/지리/제주특별자치도 서귀포시_이용가능오름현황_20210510.csv', encoding='cp949')

# %%
# 제주특별자치도_오름현황

print(part1.shape)
print(list(part1.columns))
part1.head()
# Out:
# (368, 8)
# ['오름명', '행정시', '소재지', '비고', '표고', '면적', '형태', '데이터기준일자']
#      오름명   행정시                          소재지   비고     표고      면적        형태  \
# 0   가마오름   제주시     제주특별자치도 제주시 한경면 청수리 1202   51  140.5  154486  말굽형(북동향)
# 1   가메오름   제주시     제주특별자치도 제주시 애월읍 봉성리 산124   17  372.2   28371       복합형
# 2    가메옥   제주시     제주특별자치도 제주시 구좌읍 송당리 1712   28  368.0   22764       복합형
# 3    가메창   제주시     제주특별자치도 제주시 한경면 저지리 1496    6  145.8   17037        원형
# 4  가문이오름  서귀포시  제주특별자치도 서귀포시 표선면 가시리 산158-2  106  496.2  116176  말굽형(남서향)
#
#       데이터기준일자
# 0  2021-07-07
# 1  2021-07-07
# 2  2021-07-07
# 3  2021-07-07
# 4  2021-07-07

# %%
# 컬럼명 변경

part1.rename(columns = {'오름명':'이름', '소재지':'도로명주소'},inplace=True)
part1.head()
# Out:
#       이름   행정시                        도로명주소   비고     표고      면적        형태  \
# 0   가마오름   제주시     제주특별자치도 제주시 한경면 청수리 1202   51  140.5  154486  말굽형(북동향)
# 1   가메오름   제주시     제주특별자치도 제주시 애월읍 봉성리 산124   17  372.2   28371       복합형
# 2    가메옥   제주시     제주특별자치도 제주시 구좌읍 송당리 1712   28  368.0   22764       복합형
# 3    가메창   제주시     제주특별자치도 제주시 한경면 저지리 1496    6  145.8   17037        원형
# 4  가문이오름  서귀포시  제주특별자치도 서귀포시 표선면 가시리 산158-2  106  496.2  116176  말굽형(남서향)
#
#       데이터기준일자
# 0  2021-07-07
# 1  2021-07-07
# 2  2021-07-07
# 3  2021-07-07
# 4  2021-07-07

# %%
# 컬럼 추가

part1['위도'] = np.nan
part1['경도'] = np.nan

# %%
# 컬럼명 순서변경 및 '데이터기준일자' 컬럼 삭제

part1= part1[['이름', '행정시','도로명주소', '위도', '경도']]
part1.head()
# Out:
#       이름   행정시                        도로명주소  위도  경도
# 0   가마오름   제주시     제주특별자치도 제주시 한경면 청수리 1202 NaN NaN
# 1   가메오름   제주시     제주특별자치도 제주시 애월읍 봉성리 산124 NaN NaN
# 2    가메옥   제주시     제주특별자치도 제주시 구좌읍 송당리 1712 NaN NaN
# 3    가메창   제주시     제주특별자치도 제주시 한경면 저지리 1496 NaN NaN
# 4  가문이오름  서귀포시  제주특별자치도 서귀포시 표선면 가시리 산158-2 NaN NaN

# %%
# 누락 데이터 확인

part1.count()
# Out:
# 이름       368
# 행정시      368
# 도로명주소    368
# 위도         0
# 경도         0
# dtype: int64

# %%
# 누락 데이터 확인

part1.isnull().sum()
# Out:
# 이름         0
# 행정시        0
# 도로명주소      0
# 위도       368
# 경도       368
# dtype: int64

# %%
# 컬럼별로 중복데이터 여부 확인

part1['이름'].value_counts()
# Out:
# 민오름      4
# 밝은오름     4
# 붉은오름     3
# 당오름      3
# 알오름      3
#         ..
# 만세동산     1
# 마중오름     1
# 마은이옆     1
# 마은이      1
# 흙붉은오름    1
# Name: 이름, Length: 339, dtype: int64

# %%
# csv 파일 저장

part1.to_csv('제주특별자치도_오름현황.csv', encoding='cp949')
