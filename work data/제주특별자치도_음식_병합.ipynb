# %%
# google drive 마운트
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
  
part1 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1차 병합본/음식/제주특별자치도_음식점목록_병합.csv', encoding='cp949')
part2 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1차 병합본/음식/제주특별자치도_서귀포 음식관련 업소_병합.csv', encoding='cp949')
part3 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1차 병합본/음식/제주특별자치도 상가 정보.csv', encoding='cp949')

# %%
# part1 = 제주특별자치도음식점목록_병합1

print(part1.shape)
print(list(part1.columns))
part1.head()
# Out:
# (19433, 9)
# ['Unnamed: 0', '업소명', '업종', '업태', '행정시', '도로명주소', '전화번호', '위도', '경도']
#    Unnamed: 0          업소명     업종        업태  행정시  \
# 0           0         카페송키  일반음식점        기타  NaN
# 1           1  그림책방앤카페노란우산  일반음식점        기타  NaN
# 2           2     에릭스에스프레소  일반음식점        기타  NaN
# 3           3     일품순두부한림점  일반음식점        한식  NaN
# 4           4     팔도실비집아라점  일반음식점  식육(숯불구이)  NaN
#
#                                       도로명주소 전화번호  위도  경도
# 0           제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)  NaN NaN NaN
# 1  제주특별자치도 제주시 애월읍 하광로 515, 104동 102호 (자연숲)  NaN NaN NaN
# 2                제주특별자치도 제주시 구좌읍 구좌로 77, 1층  NaN NaN NaN
# 3              제주특별자치도 제주시 한림읍 한림상로 237, 1층  NaN NaN NaN
# 4        제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)  NaN NaN NaN

# %%
# part2 = 제주특별자치도_서귀포 음식관련 업소_병합

print(part2.shape)
print(list(part2.columns))
part2.head()
# Out:
# (5999, 9)
# ['Unnamed: 0', '업소명', '업종', '업태', '행정시', '도로명주소', '전화번호', '위도', '경도']
#    Unnamed: 0    업소명     업종  업태  행정시                              도로명주소 전화번호  \
# 0           0   중앙다방  휴게음식점 NaN  NaN          제주특별자치도 서귀포시 대정읍 하모상가로 31  NaN
# 1           1    돌다방  휴게음식점 NaN  NaN          제주특별자치도 서귀포시 동문로 70 (서귀동)  NaN
# 2           2   우성다방  휴게음식점 NaN  NaN  제주특별자치도 서귀포시 중정로91번길 15, 2층 (서귀동)  NaN
# 3           3   수궁다방  휴게음식점 NaN  NaN          제주특별자치도 서귀포시 대정읍 하모항구로 78  NaN
# 4           4  해당화다방  휴게음식점 NaN  NaN      제주특별자치도 서귀포시 동문로 60, 2층 (서귀동)  NaN
#
#    위도  경도
# 0 NaN NaN
# 1 NaN NaN
# 2 NaN NaN
# 3 NaN NaN
# 4 NaN NaN

# %%
# part3 = 제주특별자치도 상가 정보

print(part3.shape)
print(list(part3.columns))
part3.head()
# Out:
# (19901, 9)
# ['Unnamed: 0', '행정시', '업소명', '업종', '업태', '도로명주소', '전화번호', '위도', '경도']
#    Unnamed: 0  행정시       업소명           업종      업태                     도로명주소  \
# 0           3  제주시    숙성1퍼센트      한식 음식점업      한식      제주특별자치도 제주시 노형10길 25
# 1           4  제주시  아빠가닭튀기는집       기타 주점업    유흥주점  제주특별자치도 제주시 한림읍 한림중앙로 26
# 2           7  제주시     죠스떡볶이  분식 및 김밥 전문점      분식        제주특별자치도 제주시 임항로 17
# 3          11  제주시     가르텐비어       기타 주점업    유흥주점      제주특별자치도 제주시 월랑로10길 2
# 4          14  제주시     광어탐나도      한식 음식점업  일식/수산물      제주특별자치도 제주시 연신로 87-6
#
#    전화번호         위도          경도
# 0   NaN  33.483335  126.479894
# 1   NaN  33.412363  126.264860
# 2   NaN  33.516737  126.526797
# 3   NaN  33.489020  126.476631
# 4   NaN  33.494109  126.549875

# %% [markdown]
# # Part1 + part2 병합

# %%
new_part = pd.concat([part1, part2])

print(new_part.shape)
print(list(new_part.columns))
new_part.head()
# Out:
# (25432, 9)
# ['Unnamed: 0', '업소명', '업종', '업태', '행정시', '도로명주소', '전화번호', '위도', '경도']
#    Unnamed: 0          업소명     업종        업태  행정시  \
# 0           0         카페송키  일반음식점        기타  NaN
# 1           1  그림책방앤카페노란우산  일반음식점        기타  NaN
# 2           2     에릭스에스프레소  일반음식점        기타  NaN
# 3           3     일품순두부한림점  일반음식점        한식  NaN
# 4           4     팔도실비집아라점  일반음식점  식육(숯불구이)  NaN
#
#                                       도로명주소 전화번호  위도  경도
# 0           제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)  NaN NaN NaN
# 1  제주특별자치도 제주시 애월읍 하광로 515, 104동 102호 (자연숲)  NaN NaN NaN
# 2                제주특별자치도 제주시 구좌읍 구좌로 77, 1층  NaN NaN NaN
# 3              제주특별자치도 제주시 한림읍 한림상로 237, 1층  NaN NaN NaN
# 4        제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)  NaN NaN NaN

# %% [markdown]
# # new_Part + part3 병합

# %%
final_part = pd.concat([new_part, part3])

print(final_part.shape)
print(list(final_part.columns))
final_part.head()
# Out:
# (45333, 9)
# ['Unnamed: 0', '업소명', '업종', '업태', '행정시', '도로명주소', '전화번호', '위도', '경도']
#    Unnamed: 0          업소명     업종        업태  행정시  \
# 0           0         카페송키  일반음식점        기타  NaN
# 1           1  그림책방앤카페노란우산  일반음식점        기타  NaN
# 2           2     에릭스에스프레소  일반음식점        기타  NaN
# 3           3     일품순두부한림점  일반음식점        한식  NaN
# 4           4     팔도실비집아라점  일반음식점  식육(숯불구이)  NaN
#
#                                       도로명주소 전화번호  위도  경도
# 0           제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)  NaN NaN NaN
# 1  제주특별자치도 제주시 애월읍 하광로 515, 104동 102호 (자연숲)  NaN NaN NaN
# 2                제주특별자치도 제주시 구좌읍 구좌로 77, 1층  NaN NaN NaN
# 3              제주특별자치도 제주시 한림읍 한림상로 237, 1층  NaN NaN NaN
# 4        제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)  NaN NaN NaN

# %%
# 'Unnamed: 0' 컬럼 삭제

final_part = final_part.drop(['Unnamed: 0'], axis=1)
final_part.head()
# Out:
#            업소명     업종        업태  행정시  \
# 0         카페송키  일반음식점        기타  NaN
# 1  그림책방앤카페노란우산  일반음식점        기타  NaN
# 2     에릭스에스프레소  일반음식점        기타  NaN
# 3     일품순두부한림점  일반음식점        한식  NaN
# 4     팔도실비집아라점  일반음식점  식육(숯불구이)  NaN
#
#                                       도로명주소 전화번호  위도  경도
# 0           제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)  NaN NaN NaN
# 1  제주특별자치도 제주시 애월읍 하광로 515, 104동 102호 (자연숲)  NaN NaN NaN
# 2                제주특별자치도 제주시 구좌읍 구좌로 77, 1층  NaN NaN NaN
# 3              제주특별자치도 제주시 한림읍 한림상로 237, 1층  NaN NaN NaN
# 4        제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)  NaN NaN NaN

# %%
# 누락 데이터 확인

final_part.count()
# Out:
# 업소명      45333
# 업종       44954
# 업태       39332
# 행정시      19901
# 도로명주소    45053
# 전화번호       299
# 위도       20071
# 경도       20071
# dtype: int64

# %%
# 누락 데이터 확인

final_part.isnull().sum()
# Out:
# 업소명          0
# 업종         379
# 업태        6001
# 행정시      25432
# 도로명주소      280
# 전화번호     45034
# 위도       25262
# 경도       25262
# dtype: int64

# %%
print(final_part.shape)
print(list(final_part.columns))
final_part.head()
# Out:
# (45333, 8)
# ['업소명', '업종', '업태', '행정시', '도로명주소', '전화번호', '위도', '경도']
#            업소명     업종        업태  행정시  \
# 0         카페송키  일반음식점        기타  NaN
# 1  그림책방앤카페노란우산  일반음식점        기타  NaN
# 2     에릭스에스프레소  일반음식점        기타  NaN
# 3     일품순두부한림점  일반음식점        한식  NaN
# 4     팔도실비집아라점  일반음식점  식육(숯불구이)  NaN
#
#                                       도로명주소 전화번호  위도  경도
# 0           제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)  NaN NaN NaN
# 1  제주특별자치도 제주시 애월읍 하광로 515, 104동 102호 (자연숲)  NaN NaN NaN
# 2                제주특별자치도 제주시 구좌읍 구좌로 77, 1층  NaN NaN NaN
# 3              제주특별자치도 제주시 한림읍 한림상로 237, 1층  NaN NaN NaN
# 4        제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)  NaN NaN NaN

# %%
# csv 파일 저장

final_part.to_csv('제주특별자치도_음식_병합.csv', encoding='cp949')
