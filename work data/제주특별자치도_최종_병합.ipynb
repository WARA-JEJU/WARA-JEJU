# %%
# google drive 마운트
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

part1 = pd.read_csv('/content/drive/MyDrive/제주도 추천시스템/병합 데이터/최종 병합/최종본/제주특별자치도_숙박_병합_네이버_이미지_변환_크롤링.csv', encoding='UTF-8')

part2 = pd.read_csv('/content/drive/MyDrive/제주도 추천시스템/병합 데이터/최종 병합/최종본/제주특별자치도_업체_병합_case1_네이버_이미지_변환_크롤링2.csv', encoding='UTF-8')
part3 = pd.read_csv('/content/drive/MyDrive/제주도 추천시스템/병합 데이터/최종 병합/최종본/제주특별자치도_업체_병햡_case2_네이버이미지_변환_크롤링.csv', encoding='UTF-8')

part4 = pd.read_csv('/content/drive/MyDrive/제주도 추천시스템/병합 데이터/최종 병합/최종본/제주특별자치도_음식_병합_case1_네이버_이미지_변환_크롤링.csv', encoding='UTF-8')
part5 = pd.read_csv('/content/drive/MyDrive/제주도 추천시스템/병합 데이터/최종 병합/최종본/제주특별자치도_음식_병합_case2_네이버_이미지_변환_크롤링.csv', encoding='UTF-8')

part6 = pd.read_csv('/content/drive/MyDrive/제주도 추천시스템/병합 데이터/최종 병합/최종본/제주특별자치도_지리_병합_네이버_이미지_변환_크롤링.csv', encoding='UTF-8')

# %%
# 숙박

print(part1.shape)
print(list(part1.columns))
part1.head()
# Out:
# (1743, 15)
# ['Unnamed: 0', '상호명', '구분', '행정시', 'address', '전화번호', 'y', 'x', '객실수', 'place_url', 'thumbnail', 'image_link', 'kakao_grade', 'kakao_review', 'kakao_img']
#    Unnamed: 0       상호명   구분   행정시                    address           전화번호  \
# 0           0   위(WE)호텔  NaN  서귀포시  제주특별자치도 서귀포시 1100로 453-95   064-730-1200
# 1           1  이에스제주리조트  NaN  서귀포시     제주특별자치도 서귀포시 1100로 501  070-4548-0285
# 2           2   천백 휴양펜션  NaN  서귀포시       제주특별자치도 서귀포시 1100로 6   064-738-3234
# 3           3     모이라펜션  NaN  서귀포시      제주특별자치도 서귀포시 516로 296   064-732-0005
# 4           4  빅토르힐 리조트  NaN  서귀포시  제주특별자치도 서귀포시 516로277번길 45   064-780-6300
#
#            y           x  객실수                              place_url  \
# 0  33.286197  126.444081  NaN     http://place.map.kakao.com/8619771
# 1  33.289533  126.456066  NaN  http://place.map.kakao.com/1134059644
# 2  33.251515  126.431988  NaN    http://place.map.kakao.com/26881888
# ...

# %%
# 컬럼명 변경

part1.rename(columns = {'구분':'업종'},inplace=True)

# %%
# 컬럼 추가

part1['road_address_name'] = np.nan
part1['category_group_name'] = np.nan
part1['category_group_code'] = np.nan
part1['category_name'] = np.nan
part1['기타'] = np.nan

# %%
# 컬럼명 순서변경

part1 = part1[['업종', '상호명', '행정시', 'address', 'road_address_name', '전화번호', 
                   'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade',
              'kakao_review', 'category_group_code', 'category_group_name', 'category_name', '기타']]

print(part1.shape)
print(list(part1.columns))
part1.head(5)
# Out:
# (1743, 17)
# ['업종', '상호명', '행정시', 'address', 'road_address_name', '전화번호', 'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade', 'kakao_review', 'category_group_code', 'category_group_name', 'category_name', '기타']
#     업종       상호명   행정시                    address  road_address_name  \
# 0  NaN   위(WE)호텔  서귀포시  제주특별자치도 서귀포시 1100로 453-95                NaN
# 1  NaN  이에스제주리조트  서귀포시     제주특별자치도 서귀포시 1100로 501                NaN
# 2  NaN   천백 휴양펜션  서귀포시       제주특별자치도 서귀포시 1100로 6                NaN
# 3  NaN     모이라펜션  서귀포시      제주특별자치도 서귀포시 516로 296                NaN
# 4  NaN  빅토르힐 리조트  서귀포시  제주특별자치도 서귀포시 516로277번길 45                NaN
#
#             전화번호          y           x  \
# 0   064-730-1200  33.286197  126.444081
# 1  070-4548-0285  33.289533  126.456066
# 2   064-738-3234  33.251515  126.431988
# 3   064-732-0005  33.279047  126.587183
# 4   064-780-6300        NaN         NaN
#
#                                place_url  \
# ...

# %%
# 누락 데이터 확인

part1.isnull().sum()
# Out:
# 업종                     1392
# 상호명                       0
# 행정시                     408
# address                   0
# road_address_name      1743
# 전화번호                    152
# y                       279
# x                       279
# place_url               354
# thumbnail               428
# image_link              428
# kakao_grade             364
# kakao_review            398
# category_group_code    1743
# category_group_name    1743
# category_name          1743
# 기타                     1743
# dtype: int64

# %%
# 컬럼별로 중복데이터 여부 확인

part1['행정시'].value_counts()
# Out:
# 제주시     810
# 서귀포시    525
# Name: 행정시, dtype: int64

# %%
# 누락 데이터 확인

part1.count()
# Out:
# 업종                      351
# 상호명                    1743
# 행정시                    1335
# address                1743
# road_address_name         0
# 전화번호                   1591
# y                      1464
# x                      1464
# place_url              1389
# thumbnail              1315
# image_link             1315
# kakao_grade            1379
# kakao_review           1345
# category_group_code       0
# category_group_name       0
# category_name             0
# 기타                        0
# dtype: int64

# %%
# 누락 데이터 확인

part1.isnull().sum()
# Out:
# 업종                     1392
# 상호명                       0
# 행정시                     408
# address                   0
# road_address_name      1743
# 전화번호                    152
# y                       279
# x                       279
# place_url               354
# thumbnail               428
# image_link              428
# kakao_grade             364
# kakao_review            398
# category_group_code    1743
# category_group_name    1743
# category_name          1743
# 기타                     1743
# dtype: int64

# %%
# 컬럼별로 중복데이터 여부 확인

part1['행정시'].value_counts()
# Out:
# 제주시     810
# 서귀포시    525
# Name: 행정시, dtype: int64

# %%
# 컬럼별로 중복데이터 여부 확인

part1['업종'].value_counts()
# Out:
# 호스텔업        119
# 관광호텔업       118
# 휴양콘도미니엄업     62
# 가족호텔업        47
# 소형호텔업         4
# 한국전통호텔업       1
# Name: 업종, dtype: int64

# %%
# 업체

print(part2.shape)
print(list(part2.columns))
part2.head()
# Out:
# (8061, 13)
# ['Unnamed: 0', '업종', '상호명', '행정시', 'address', '전화번호', 'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade', 'kakao_review']
#    Unnamed: 0          업종           상호명  행정시                 address  \
# 0           0  운송장비용 주유소업    (주)무수천주유소   NaN     제주특별자치도 제주시 노형로 45
# 1           1  운송장비용 주유소업  ㈜새신테크 이호주유소   NaN  제주특별자치도 제주시 일주서로 7629
# 2           2  운송장비용 주유소업     (주)회천주유소   NaN    제주특별자치도 제주시 번영로 937
# 3           3  운송장비용 주유소업       거북이주유소   NaN     제주특별자치도 제주시 서광로 58
# 4           4  운송장비용 주유소업        고산주유소   NaN  제주특별자치도 제주시 한경면 고산로 5
#
#            전화번호          y           x                            place_url  \
# 0  064-748-1515  33.463247  126.451985   http://place.map.kakao.com/7877224
# 1  064-747-0033  33.495206  126.461782   http://place.map.kakao.com/7840344
# 2  064-721-9222  33.475664  126.636630  http://place.map.kakao.com/11284745
# 3  064-743-4777  33.499038  126.502738  http://place.map.kakao.com/11413702
# ...

# %%
# 컬럼 추가

part2['road_address_name'] = np.nan
part2['category_group_name'] = np.nan
part2['category_group_code'] = np.nan
part2['category_name'] = np.nan
part2['기타'] = np.nan

# %%
# 컬럼명 순서변경

part2 = part2[['업종', '상호명', '행정시', 'address', 'road_address_name', '전화번호', 
                   'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade',
              'kakao_review', 'category_group_code', 'category_group_name', 'category_name', '기타']]

print(part2.shape)
print(list(part2.columns))
# Out:
# (8061, 17)
# ['업종', '상호명', '행정시', 'address', 'road_address_name', '전화번호', 'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade', 'kakao_review', 'category_group_code', 'category_group_name', 'category_name', '기타']

# %%
# 업체

print(part3.shape)
print(list(part3.columns))
part3.head()
# Out:
# (9150, 13)
# ['Unnamed: 0', '업종', '상호명', '행정시', 'address', '전화번호', 'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade', 'kakao_review']
#    Unnamed: 0     업종          상호명  행정시  \
# 0        7239  통신판매업       에이치컴퍼니  NaN
# 1        7240  통신판매업       알엔(RN)  NaN
# 2        7241  통신판매업     아이제이(IJ)  NaN
# 3        7242  통신판매업        까사디동문  NaN
# 4        7243  통신판매업  (주) 춘추항공여행사  NaN
#
#                                              address  전화번호          y  \
# 0              제주특별자치도 제주시 절물*길 **-*, *층 ***호 (외도일동)   NaN  33.507000
# 1          제주특별자치도 제주시 애월읍 애납로 ***, 납읍리다가구주택 가동 ***호   NaN        NaN
# 2          제주특별자치도 제주시 애월읍 애납로 ***, 납읍리다가구주택 가동 ***호   NaN        NaN
# 3  제주특별자치도 제주시 동문로*길 *, 동문공설시장, 동문공영주차장 지하*층 A-*호...   NaN  33.512080
# 4                         제주특별자치도 제주시 무근성*길 * (삼도이동)   NaN  33.513683
#
#             x                              place_url  \
# 0  126.540221                                    NaN
# ...

# %%
# 컬럼 추가

part3['road_address_name'] = np.nan
part3['category_group_name'] = np.nan
part3['category_group_code'] = np.nan
part3['category_name'] = np.nan
part3['기타'] = np.nan

# %%
# 컬럼명 순서변경

part3 = part3[['업종', '상호명', '행정시', 'address', 'road_address_name', '전화번호', 
                   'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade',
              'kakao_review', 'category_group_code', 'category_group_name', 'category_name', '기타']]

print(part3.shape)
print(list(part3.columns))
# Out:
# (9150, 17)
# ['업종', '상호명', '행정시', 'address', 'road_address_name', '전화번호', 'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade', 'kakao_review', 'category_group_code', 'category_group_name', 'category_name', '기타']

# %%
# 음식

print(part4.shape)
print(list(part4.columns))
part4.head()
# Out:
# (24986, 14)
# ['Unnamed: 0', '상호명', '업종', '업태', '행정시', 'address', '전화번호', 'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade', 'kakao_review']
#    Unnamed: 0          상호명     업종        업태  행정시  \
# 0           0         카페송키  일반음식점        기타  NaN
# 1           1  그림책방앤카페노란우산  일반음식점        기타  NaN
# 2           2     에릭스에스프레소  일반음식점        기타  NaN
# 3           3     일품순두부한림점  일반음식점        한식  NaN
# 4           4     팔도실비집아라점  일반음식점  식육(숯불구이)  NaN
#
#                                     address 전화번호          y           x  \
# 0           제주특별자치도 제주시 무근성안길 16, 1층 (삼도이동)  NaN  33.515115  126.520197
# 1  제주특별자치도 제주시 애월읍 하광로 515, 104동 102호 (자연숲)  NaN  33.446052  126.430592
# 2                제주특별자치도 제주시 구좌읍 구좌로 77, 1층  NaN  33.521431  126.858893
# 3              제주특별자치도 제주시 한림읍 한림상로 237, 1층  NaN  33.419302  126.267448
# 4        제주특별자치도 제주시 중앙로 581, 에이동 1층 (아라일동)  NaN  33.471416  126.545798
#
#                                place_url  \
# ...

# %%
# 컬럼 추가

part4['road_address_name'] = np.nan
part4['category_group_name'] = np.nan
part4['category_group_code'] = np.nan
part4['category_name'] = np.nan
part4['기타'] = np.nan

# %%
# 컬럼명 순서변경

part4 = part4[['업종', '상호명', '행정시', 'address', 'road_address_name', '전화번호', 
                   'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade',
              'kakao_review', 'category_group_code', 'category_group_name', 'category_name', '기타']]

print(part4.shape)
print(list(part4.columns))
# Out:
# (24986, 17)
# ['업종', '상호명', '행정시', 'address', 'road_address_name', '전화번호', 'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade', 'kakao_review', 'category_group_code', 'category_group_name', 'category_name', '기타']

# %%
# 음식

print(part5.shape)
print(list(part5.columns))
part5.head()
# Out:
# (20399, 14)
# ['Unnamed: 0', '상호명', '업종', '업태', '행정시', 'address', '전화번호', 'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade', 'kakao_review']
#    Unnamed: 0        상호명     업종   업태  행정시  \
# 0        5553    케이트카페&펍  일반음식점  NaN  NaN
# 1        5554      제주푸줏간  일반음식점  NaN  NaN
# 2        5555  노가리앤비어서홍점  일반음식점  NaN  NaN
# 3        5556   하와이안비치카페  일반음식점  NaN  NaN
# 4        5557     가파도봄날에  일반음식점  NaN  NaN
#
#                                          address 전화번호          y           x  \
# 0            제주특별자치도 서귀포시 안덕면 사계로 187-3, 제12동 1층  NaN        NaN         NaN
# 1  제주특별자치도 서귀포시 안덕면 신화역사로 423, 상가동 1층 1102~1104호  NaN  33.310020  126.333069
# 2             제주특별자치도 서귀포시 홍중로 99, 1층 101호 (서홍동)  NaN        NaN         NaN
# 3               제주특별자치도 서귀포시 성산읍 신양로122번길 57, 2층  NaN  33.435170  126.917466
# 4                  제주특별자치도 서귀포시 대정읍 가파로67번길 47-2  NaN  33.169584  126.270427
#
#                                place_url  \
# 0                                    NaN
# ...

# %%
# 컬럼 추가

part5['road_address_name'] = np.nan
part5['category_group_name'] = np.nan
part5['category_group_code'] = np.nan
part5['category_name'] = np.nan
part5['기타'] = np.nan

# %%
# 컬럼명 순서변경

part5 = part5[['업종', '상호명', '행정시', 'address', 'road_address_name', '전화번호', 
                   'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade',
              'kakao_review', 'category_group_code', 'category_group_name', 'category_name', '기타']]

print(part5.shape)
print(list(part5.columns))
# Out:
# (20399, 17)
# ['업종', '상호명', '행정시', 'address', 'road_address_name', '전화번호', 'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade', 'kakao_review', 'category_group_code', 'category_group_name', 'category_name', '기타']

# %%
# 지리

print(part6.shape)
print(list(part6.columns))
part6.head()
# Out:
# (628, 12)
# ['Unnamed: 0', '상호명', '행정시', 'address', 'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade', 'kakao_review', 'kakao_img']
#    Unnamed: 0   상호명  행정시                     address          y           x  \
# 0           0  제주향교  NaN          제주특별자치도 제주시 서문로 47  33.511112  126.515584
# 1           1   연북정  NaN    제주특별자치도 제주시 조천읍 조천리 2690  33.540084  126.636119
# 2           2  대정향교  NaN   제주특별자치도 서귀포시 안덕면 사계리 3126  33.239544  126.288384
# 3           3  정의향교  NaN  제주특별자치도 서귀포시 표선면 성읍리 820-1  33.386797  126.799896
# 4           4   향사당  NaN      제주특별자치도 제주시 삼도1동 970-2  33.512066  126.521619
#
#                              place_url  \
# 0   http://place.map.kakao.com/9937633
# 1   http://place.map.kakao.com/8004690
# 2  http://place.map.kakao.com/14794381
# 3  http://place.map.kakao.com/17807528
# 4  http://place.map.kakao.com/12765233
#
#                                            thumbnail  \
# 0  https://search.pstatic.net/common/?src=http://...
# ...

# %%
# 컬럼 추가

part6['road_address_name'] = np.nan
part6['category_group_name'] = np.nan
part6['category_group_code'] = np.nan
part6['category_name'] = np.nan
part6['기타'] = np.nan

part6['업종'] = np.nan
part6['전화번호'] = np.nan

# %%
# 컬럼명 순서변경

part6= part6[['업종', '상호명', '행정시', 'address', 'road_address_name', '전화번호', 
                   'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade',
              'kakao_review', 'category_group_code', 'category_group_name', 'category_name', '기타']]

print(part6.shape)
print(list(part6.columns))
# Out:
# (628, 17)
# ['업종', '상호명', '행정시', 'address', 'road_address_name', '전화번호', 'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade', 'kakao_review', 'category_group_code', 'category_group_name', 'category_name', '기타']

# %%
final_part = pd.concat([part1, part2, part3, part4, part5, part6])

print(final_part.shape)
print(list(final_part.columns))
final_part.head()
# Out:
# (64967, 17)
# ['업종', '상호명', '행정시', 'address', 'road_address_name', '전화번호', 'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade', 'kakao_review', 'category_group_code', 'category_group_name', 'category_name', '기타']
#     업종       상호명   행정시                    address  road_address_name  \
# 0  NaN   위(WE)호텔  서귀포시  제주특별자치도 서귀포시 1100로 453-95                NaN
# 1  NaN  이에스제주리조트  서귀포시     제주특별자치도 서귀포시 1100로 501                NaN
# 2  NaN   천백 휴양펜션  서귀포시       제주특별자치도 서귀포시 1100로 6                NaN
# 3  NaN     모이라펜션  서귀포시      제주특별자치도 서귀포시 516로 296                NaN
# 4  NaN  빅토르힐 리조트  서귀포시  제주특별자치도 서귀포시 516로277번길 45                NaN
#
#             전화번호          y           x  \
# 0   064-730-1200  33.286197  126.444081
# 1  070-4548-0285  33.289533  126.456066
# 2   064-738-3234  33.251515  126.431988
# 3   064-732-0005  33.279047  126.587183
# 4   064-780-6300        NaN         NaN
#
#                                place_url  \
# ...

# %%
# 누락 데이터 확인

final_part.isnull().sum()
# Out:
# 업종                      2484
# 상호명                        0
# 행정시                    43327
# address                  585
# road_address_name      64967
# 전화번호                   62837
# y                      12878
# x                      12878
# place_url              21847
# thumbnail              26337
# image_link             26337
# kakao_grade            21857
# kakao_review           21892
# category_group_code    64967
# category_group_name    64967
# category_name          64967
# 기타                     64967
# dtype: int64

# %%
# 컬럼별로 중복데이터 여부 확인

final_part['업종'].value_counts()
# Out:
# 일반음식점                      19364
# 통신판매업                      14420
# 한식 음식점업                     9773
# 휴게음식점                       5620
# 비알콜 음료점업                    2679
# 분식 및 김밥 전문점                 1328
# 일반유흥 주점업                    1159
# 기타 주점업                      1127
# 서양식 음식점업                     804
# 제과점업                         756
# 치킨 전문점                       685
# 국내여행업                        598
# 일식 음식점업                      580
# 중식 음식점업                      453
# 일반여행업                        333
# 관광숙박업                        315
# 여행업                          313
# 노래연습장업                       234
# 그외 기타 음식점업                   200
# 운송장비용 주유소업                   194
# 피자, 햄버거, 샌드위치 및 유사 음식점업      193
# 제과점영업                        147
# 문화체육업                        143
# 관광객이용시설업                     139
# 방문판매업                        127
# 호스텔업                         119
# 관광호텔업                        118
# 국외여행업                         62
# ...

# %%
# 컬럼별로 중복데이터 여부 확인

final_part['행정시'].value_counts()
# Out:
# 제주시     14517
# 서귀포시     7123
# Name: 행정시, dtype: int64

# %%
final_part[final_part.address == '<REPLACE>']
# Out:
#           업종           상호명  행정시    address  road_address_name 전화번호          y  \
# 19513  휴게음식점          하논바람  NaN  <REPLACE>                NaN  NaN        NaN
# 19548  휴게음식점           영다방  NaN  <REPLACE>                NaN  NaN  33.220775
# 19579  휴게음식점           레이크  NaN  <REPLACE>                NaN  NaN  33.267486
# 19584  휴게음식점  자연과함께하는행복한쉼터  NaN  <REPLACE>                NaN  NaN        NaN
# 19702  휴게음식점         카페 아라  NaN  <REPLACE>                NaN  NaN  33.233342
# 19746  휴게음식점         맛있는여행  NaN  <REPLACE>                NaN  NaN        NaN
# 19974  휴게음식점    지에스25대정상모점  NaN  <REPLACE>                NaN  NaN  33.223295
# 19977  휴게음식점      (주)지포뮤지엄  NaN  <REPLACE>                NaN  NaN        NaN
# 20076  휴게음식점          피치카토  NaN  <REPLACE>                NaN  NaN  33.327344
# 20097  휴게음식점         모노클제주  NaN  <REPLACE>                NaN  NaN  33.272913
# 20173  휴게음식점         어느멋진날  NaN  <REPLACE>                NaN  NaN  33.268755
# ...

# %%
replace = final_part[final_part.address == '<REPLACE>']
print(replace.shape)
# Out:
# (21, 17)

# %%
# <REPLACE> 값을 NaN으로 수정

final_part = final_part.replace('<REPLACE>', np.NaN)

# %%
final_part[final_part.address == '<REPLACE>']
# Out:
# Empty DataFrame
# Columns: [업종, 상호명, 행정시, address, road_address_name, 전화번호, y, x, place_url, thumbnail, image_link, kakao_grade, kakao_review, category_group_code, category_group_name, category_name, 기타]
# Index: []

# %%
# 완전히 동일한 중복데이터 여부 확인

final_part.duplicated(['상호명', 'address', '전화번호', 'y', 'x']).sum()
# Out:
# 5460

# %%
# 완전히 동일한 중복데이터 여부 확인

final_part.duplicated(['상호명', 'address']).sum()
# Out:
# 6885

# %%
# 완전히 동일한 중복데이터 여부 확인

final_part.duplicated(['상호명', '전화번호']).sum()
# Out:
# 18487

# %%
# 완전히 동일한 중복데이터 여부 확인

final_part.duplicated(['상호명', 'y', 'x']).sum()
# Out:
# 8267

# %%
# 완전히 동일한 중복데이터 여부 확인

final_part.duplicated().sum()
# Out:
# 3844

# %%
# 컬럼인 중복된 행 삭제

final_part = final_part.drop_duplicates(['상호명', 'address'])

# %%
# 컬럼인 중복된 행 삭제

final_part = final_part.drop_duplicates(['상호명', '전화번호'])

# %%
# 컬럼인 중복된 행 삭제

final_part = final_part.drop_duplicates(['상호명', 'y', 'x'])

# %%
# 컬럼인 중복된 행 삭제

final_part = final_part.drop_duplicates(['상호명', 'address', '전화번호', 'y', 'x'])

# %%
# 누락 데이터 확인

final_part.isnull().sum()
# Out:
# 업종                      2093
# 상호명                        0
# 행정시                    34773
# address                  518
# road_address_name      45753
# 전화번호                   43989
# y                      11554
# x                      11554
# place_url              18474
# thumbnail              19769
# image_link             19769
# kakao_grade            18484
# kakao_review           18516
# category_group_code    45753
# category_group_name    45753
# category_name          45753
# 기타                     45753
# dtype: int64

# %%
print(final_part.shape)
print(list(final_part.columns))
# Out:
# (45753, 17)
# ['업종', '상호명', '행정시', 'address', 'road_address_name', '전화번호', 'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade', 'kakao_review', 'category_group_code', 'category_group_name', 'category_name', '기타']

# %%
# 컬럼별로 중복데이터 여부 확인

final_part['행정시'].value_counts()
# Out:
# 제주시     7337
# 서귀포시    3643
# Name: 행정시, dtype: int64

# %%
# '제주시'만 있는 값을을 a로 지정

a = final_part[final_part['address'].str.contains('제주시', na = False)]
print(a.shape)
print(list(a.columns))
# Out:
# (31233, 17)
# ['업종', '상호명', '행정시', 'address', 'road_address_name', '전화번호', 'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade', 'kakao_review', 'category_group_code', 'category_group_name', 'category_name', '기타']

# %%
# 컬럼을 추가하고 '제주시' 값을 추가

a.insert(2,'시','제주시')

# %%
# '서귀포시'만 있는 값을을 b로 지정

b = final_part[final_part['address'].str.contains('서귀포시', na = False)]
print(b.shape)
print(list(b.columns))
# Out:
# (13940, 17)
# ['업종', '상호명', '행정시', 'address', 'road_address_name', '전화번호', 'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade', 'kakao_review', 'category_group_code', 'category_group_name', 'category_name', '기타']

# %%
# 컬럼을 추가하고 '서귀포시' 값을 추가

b.insert(2,'시','서귀포시')

# %%
real_final_part = pd.concat([a, b])

print(real_final_part.shape)
print(list(real_final_part.columns))
real_final_part.head(5)
# Out:
# (45173, 18)
# ['업종', '상호명', '시', '행정시', 'address', 'road_address_name', '전화번호', 'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade', 'kakao_review', 'category_group_code', 'category_group_name', 'category_name', '기타']
#       업종    상호명    시  행정시                    address  road_address_name  \
# 525  NaN  엠버리조트  제주시  제주시  제주특별자치도 제주시 1100로 2671-51                NaN
# 526  NaN    부림장  제주시  제주시          제주특별자치도 제주시 고마로 1                NaN
# 527  NaN      별  제주시  제주시       제주특별자치도 제주시 고마로 10-3                NaN
# 528  NaN     영자  제주시  제주시        제주특별자치도 제주시 고마로 2-4                NaN
# 529  NaN     씨엘  제주시  제주시         제주특별자치도 제주시 고마로 35                NaN
#
#              전화번호          y           x  \
# 525  064-805-8684  33.423695  126.489053
# 526  064-727-8254  33.513897  126.538589
# 527  064-753-3816  33.443339  126.396643
# 528  064-722-6450  33.506066  126.541963
# 529  064-724-8255  33.485976  126.493895
#
#                                  place_url  \
# ...

# %%
# 누락 데이터 확인

real_final_part.isnull().sum()
# Out:
# 업종                      2093
# 상호명                        0
# 시                          0
# 행정시                    34193
# address                    0
# road_address_name      45173
# 전화번호                   43409
# y                      11053
# x                      11053
# place_url              17919
# thumbnail              19503
# image_link             19503
# kakao_grade            17929
# kakao_review           17961
# category_group_code    45173
# category_group_name    45173
# category_name          45173
# 기타                     45173
# dtype: int64

# %%
# 컬럼명 순서변경

real_final_part = real_final_part[['업종', '상호명', '시', 'address', 'road_address_name', '전화번호', 
                   'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade',
              'kakao_review', 'category_group_code', 'category_group_name', 'category_name', '기타']]

print(real_final_part.shape)
print(list(real_final_part.columns))
# Out:
# (45173, 17)
# ['업종', '상호명', '시', 'address', 'road_address_name', '전화번호', 'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade', 'kakao_review', 'category_group_code', 'category_group_name', 'category_name', '기타']

# %%
# 컬럼명 변경

real_final_part.rename(columns = {'시':'행정시'},inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
real_final_part.count()
# Out:
# 업종                     43080
# 상호명                    45173
# 행정시                    45173
# address                45173
# road_address_name          0
# 전화번호                    1764
# y                      34120
# x                      34120
# place_url              27254
# thumbnail              25670
# image_link             25670
# kakao_grade            27244
# kakao_review           27212
# category_group_code        0
# category_group_name        0
# category_name              0
# 기타                         0
# dtype: int64

# %%
# 누락 데이터 확인

real_final_part.isnull().sum()
# Out:
# 업종                      2093
# 상호명                        0
# 행정시                        0
# address                    0
# road_address_name      45173
# 전화번호                   43409
# y                      11053
# x                      11053
# place_url              17919
# thumbnail              19503
# image_link             19503
# kakao_grade            17929
# kakao_review           17961
# category_group_code    45173
# category_group_name    45173
# category_name          45173
# 기타                     45173
# dtype: int64

# %%
real_final_part.to_csv('제주특별자치도_최종_병합.csv', index=False)  # 구분자를 탭으로 하여 저장. 인덱스칼럼은 저장 안함.

# 크롬드라이버 크롤링 End

# %%
print(real_final_part.shape)
print(list(real_final_part.columns))
# Out:
# (45173, 17)
# ['업종', '상호명', '행정시', 'address', 'road_address_name', '전화번호', 'y', 'x', 'place_url', 'thumbnail', 'image_link', 'kakao_grade', 'kakao_review', 'category_group_code', 'category_group_name', 'category_name', '기타']
