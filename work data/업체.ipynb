# %%
# google drive 마운트
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

part = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/지리/제주특별자치도_제주도장소(POI)데이터_20151231.csv', encoding='cp949')

part1 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/제주특별자치도 제주시_주유소현황_20201230.csv', encoding='cp949')
part2 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/제주특별자치도 서귀포시_주유소현황_20210222.csv', encoding='cp949')

part3 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/제주특별자치도 제주시_노래연습장현황_20210813.csv', encoding='cp949')
part4 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/제주특별자치도 서귀포시_노래연습장현황_20210928.csv', encoding='cp949')

part5 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/제주특별자치도 제주시_승마장현황_20210201.csv', encoding='cp949')

part6 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/제주특별자치도 서귀포시_게임업현황_20210929.csv', encoding='cp949')

part7 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/제주특별자치도 제주시_영화상영관현황_20210820.csv', encoding='cp949')
part8 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/제주특별자치도 서귀포시_영화상영관현황_20211001.csv', encoding='cp949')

part9 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/제주특별자치도_교육관련기관현황_20210820.csv', encoding='cp949')
part10 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/제주특별자치도_국제학교현황_20211005.csv', encoding='cp949')
part11 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/제주특별자치도_문화학교현황_20210812.csv', encoding='cp949')

part12 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/제주특별자치도_제주도내 공연장 현황_20211130.csv', encoding='cp949')

part13 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/제주문화예술법인현황.csv', encoding='cp949')

part14 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/통신판매업정보.csv', encoding='cp949')

part15 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/방문판매업정보.csv', encoding='cp949')

part16 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/관광사업체정보.csv', encoding='cp949')

part17 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/여행업정보(통합).csv', encoding='cp949')

# %% [markdown]
# # 제주도장소(POI)

# %%
# 제주특별자치도_제주도장소(POI)데이터

print(part.shape)
print(list(part.columns))
part.head()
# Out:
# (74439, 7)
# ['장소 POI에 대한 ID 구분 번호 체계 ', '위치좌표 X축값 ', '위치좌표 Y축값 ', '구분', '장소명', '소재지', '데이터기준일자']
#    장소 POI에 대한 ID 구분 번호 체계    위치좌표 X축값   위치좌표 Y축값     구분   장소명  \
# 0                        3  126.568803  33.236546  교통시설  동방파제
# 1                        4  126.562554  33.235071  지명관련    새섬
# 2                        5  126.599675  33.230314  지명관련    섶섬
# 3                        6  126.565891  33.226031  지명관련    문섬
# 4                        7  126.516395  33.218414  지명관련    범섬
#
#                       소재지     데이터기준일자
# 0  제주특별자치도 서귀포시 서귀동 758-2  2015-12-31
# 1  제주특별자치도 서귀포시 서귀동 산 3-3  2015-12-31
# 2    제주특별자치도 서귀포시 보목동 산 1  2015-12-31
# 3    제주특별자치도 서귀포시 서귀동 산 4  2015-12-31
# 4    제주특별자치도 서귀포시 법환동 산 2  2015-12-31

# %%
# 컬럼명 변경

part.rename(columns = {'위치좌표 X축값 ':'경도', '위치좌표 Y축값 ':'위도', 
                        '소재지':'도로명주소'},inplace=True)
part.head()
# Out:
#    장소 POI에 대한 ID 구분 번호 체계           경도         위도    구분   장소명  \
# 0                        3  126.568803  33.236546  교통시설  동방파제
# 1                        4  126.562554  33.235071  지명관련    새섬
# 2                        5  126.599675  33.230314  지명관련    섶섬
# 3                        6  126.565891  33.226031  지명관련    문섬
# 4                        7  126.516395  33.218414  지명관련    범섬
#
#                     도로명주소     데이터기준일자
# 0  제주특별자치도 서귀포시 서귀동 758-2  2015-12-31
# 1  제주특별자치도 서귀포시 서귀동 산 3-3  2015-12-31
# 2    제주특별자치도 서귀포시 보목동 산 1  2015-12-31
# 3    제주특별자치도 서귀포시 서귀동 산 4  2015-12-31
# 4    제주특별자치도 서귀포시 법환동 산 2  2015-12-31

# %%
# 컬럼명 순서변경 및 '데이터기준일자' 컬럼 삭제

part= part[['장소명', '구분', '도로명주소', '위도', '경도']]
part.head()
# Out:
#     장소명    구분                   도로명주소         위도          경도
# 0  동방파제  교통시설  제주특별자치도 서귀포시 서귀동 758-2  33.236546  126.568803
# 1    새섬  지명관련  제주특별자치도 서귀포시 서귀동 산 3-3  33.235071  126.562554
# 2    섶섬  지명관련    제주특별자치도 서귀포시 보목동 산 1  33.230314  126.599675
# 3    문섬  지명관련    제주특별자치도 서귀포시 서귀동 산 4  33.226031  126.565891
# 4    범섬  지명관련    제주특별자치도 서귀포시 법환동 산 2  33.218414  126.516395

# %% [markdown]
# # 제주특별자치도 주유소현황

# %%
# 제주특별자치도 제주시_주유소현황

print(part1.shape)
print(list(part1.columns))
part1.head()
# Out:
# (130, 4)
# ['상호', '주소', '연락처', '데이터기준일자']
#              상호                      주소           연락처     데이터기준일자
# 0    (주)무수천주유소      제주특별자치도 제주시 노형로 45   064-748-1515  2020-12-30
# 1  ㈜새신테크 이호주유소   제주특별자치도 제주시 일주서로 7629   064-747-0033  2020-12-30
# 2     (주)회천주유소     제주특별자치도 제주시 번영로 937   064-721-9222  2020-12-30
# 3       거북이주유소      제주특별자치도 제주시 서광로 58   064-743-4777  2020-12-30
# 4        고산주유소   제주특별자치도 제주시 한경면 고산로 5   064-772-2626  2020-12-30

# %%
# 누락 데이터 확인

part1.count()
# Out:
# 상호         130
# 주소         130
# 연락처        130
# 데이터기준일자    130
# dtype: int64

# %%
# 완전히 동일한 중복데이터 여부 확인

part1.duplicated().sum()
# Out:
# 0

# %%
# 제주특별자치도 서귀포시_주유소현황

print(part2.shape)
print(list(part2.columns))
part2.head()
# Out:
# (64, 6)
# ['상호', '연락처', '주소', '위도', '경도', '데이터기준일자']
#            상호           연락처                          주소         위도  \
# 0  성산일출봉농협주유소  064-780-3135  제주특별자치도 서귀포시 성산읍 일주동로 4521  33.425311
# 1     혁신도시주유소  064-739-5233      제주특별자치도 서귀포시 일주동로 9144  33.248262
# 2     안덕하나주유소  064-792-3088    제주특별자치도 서귀포시 안덕면 한창로 182  33.277632
# 3   대정농협무릉주유소  064-792-8201    제주특별자치도 서귀포시 대정읍 서삼중로 66  33.269115
# 4      선반내주유소  064-739-5008      제주특별자치도 서귀포시 일주동로 8780  33.253126
#
#            경도     데이터기준일자
# 0  126.907034  2021-02-22
# 1  126.516141  2021-02-22
# 2  126.359617  2021-02-22
# 3  126.204165  2021-02-22
# 4  126.550851  2021-02-22

# %%
# 누락 데이터 확인

part2.count()
# Out:
# 상호         64
# 연락처        64
# 주소         64
# 위도         64
# 경도         64
# 데이터기준일자    64
# dtype: int64

# %%
# 완전히 동일한 중복데이터 여부 확인

part2.duplicated().sum()
# Out:
# 0

# %%
new_part = pd.concat([part1, part2])

print(new_part.shape)
print(list(new_part.columns))
new_part.head()
# Out:
# (194, 6)
# ['상호', '주소', '연락처', '데이터기준일자', '위도', '경도']
#              상호                      주소           연락처     데이터기준일자  위도  경도
# 0    (주)무수천주유소      제주특별자치도 제주시 노형로 45   064-748-1515  2020-12-30 NaN NaN
# 1  ㈜새신테크 이호주유소   제주특별자치도 제주시 일주서로 7629   064-747-0033  2020-12-30 NaN NaN
# 2     (주)회천주유소     제주특별자치도 제주시 번영로 937   064-721-9222  2020-12-30 NaN NaN
# 3       거북이주유소      제주특별자치도 제주시 서광로 58   064-743-4777  2020-12-30 NaN NaN
# 4        고산주유소   제주특별자치도 제주시 한경면 고산로 5   064-772-2626  2020-12-30 NaN NaN

# %%
# 컬럼명 변경

new_part.rename(columns = {'상호':'상호명', '주소':'도로명주소', '연락처':'전화번호'},inplace=True)
new_part.head()
# Out:
#             상호명                   도로명주소          전화번호     데이터기준일자  위도  경도
# 0    (주)무수천주유소      제주특별자치도 제주시 노형로 45   064-748-1515  2020-12-30 NaN NaN
# 1  ㈜새신테크 이호주유소   제주특별자치도 제주시 일주서로 7629   064-747-0033  2020-12-30 NaN NaN
# 2     (주)회천주유소     제주특별자치도 제주시 번영로 937   064-721-9222  2020-12-30 NaN NaN
# 3       거북이주유소      제주특별자치도 제주시 서광로 58   064-743-4777  2020-12-30 NaN NaN
# 4        고산주유소   제주특별자치도 제주시 한경면 고산로 5   064-772-2626  2020-12-30 NaN NaN

# %%
# 컬럼 추가

new_part['행정시'] = np.nan

# %%
# '업종' 컬럼을 추가하고 '운송장비용 주유소업' 값을 추가

new_part.insert(0,'업종','운송장비용 주유소업')

# %%
# 컬럼명 순서변경

new_part= new_part[['업종', '상호명', '행정시', '도로명주소', '전화번호', '위도', '경도']]
new_part.head()
# Out:
#            업종           상호명  행정시                   도로명주소          전화번호  위도  경도
# 0  운송장비용 주유소업    (주)무수천주유소   NaN     제주특별자치도 제주시 노형로 45   064-748-1515 NaN NaN
# 1  운송장비용 주유소업  ㈜새신테크 이호주유소   NaN  제주특별자치도 제주시 일주서로 7629   064-747-0033 NaN NaN
# 2  운송장비용 주유소업     (주)회천주유소   NaN    제주특별자치도 제주시 번영로 937   064-721-9222 NaN NaN
# 3  운송장비용 주유소업       거북이주유소   NaN     제주특별자치도 제주시 서광로 58   064-743-4777 NaN NaN
# 4  운송장비용 주유소업        고산주유소   NaN  제주특별자치도 제주시 한경면 고산로 5   064-772-2626 NaN NaN

# %%
# 완전히 동일한 중복데이터 여부 확인

new_part.duplicated().sum()
# Out:
# 0

# %%
# 완전히 동일한 중복데이터 여부 확인

new_part.duplicated(['상호명', '도로명주소']).sum()
# Out:
# 0

# %%
# csv 파일 저장

new_part.to_csv('제주특별자치도_주유소현황_병합.csv', encoding='cp949')

# %% [markdown]
# # 제주특별자치도 노래연습장현황

# %%
# 제주특별자치도 제주시_노래연습장현황

print(part3.shape)
print(list(part3.columns))
part3.head()
# Out:
# (234, 6)
# ['업종', '등록일', '상호명', '우편번호', '소재지', '데이터기준일자']
#        업종         등록일       상호명   우편번호                    소재지     데이터기준일자
# 0  노래연습장업  1993-06-14        연인  63081    제주특별자치도 제주시 원노형로 25  2021-08-13
# 1  노래연습장업  1993-10-16  안성 노래연습장  63264   제주특별자치도 제주시 동문로10길 6  2021-08-13
# 2  노래연습장업  1993-10-26        현대  63125  제주특별자치도 제주시 삼무로11길 36  2021-08-13
# 3  노래연습장업  1993-12-21   에코노래연습장  63123  제주특별자치도 제주시 신대로16길 50  2021-08-13
# 4  노래연습장업  1993-12-28       들장미  63168  제주특별자치도 제주시 중앙로14길 28  2021-08-13

# %%
# 누락 데이터 확인

part3.count()
# Out:
# 업종         234
# 등록일        234
# 상호명        234
# 우편번호       234
# 소재지        234
# 데이터기준일자    234
# dtype: int64

# %%
# 완전히 동일한 중복데이터 여부 확인

part3.duplicated().sum()
# Out:
# 0

# %%
# 제주특별자치도 서귀포시_노래연습장현황

print(part4.shape)
print(list(part4.columns))
part4.head()
# Out:
# (85, 7)
# ['등록(신고)일자', '상호명', '소재지', '시설면적(제곱미터)', '위도', '경도', '데이터기준일자']
#      등록(신고)일자                        상호명                           소재지  \
# 0  2018-12-10               k팝스타 코인노래연습장   제주특별자치도 서귀포시 대정읍 글로벌에듀로 370
# 1  2020-11-10                     월드컵노래방      제주특별자치도 서귀포시 월드컵로45번길 40
# 2  2003-10-28                   팬클럽노래연습장  제주특별자치도 서귀포시 남원읍 태위로689번길 10
# 3  2020-07-29       아이존팝 코인노래연습장 액트몬 중문점         제주특별자치도 서귀포시 중문동 2565
# 4  2020-05-15  클럽런더리(CLUB LAUNDRY) 노래연습장  제주특별자치도 서귀포시 성산읍 고성리 297-1번지
#
#    시설면적(제곱미터)         위도          경도     데이터기준일자
# 0       56.30  33.280707  126.278261  2021-09-28
# 1      112.00  33.244614  126.511739  2021-09-28
# 2      168.72  33.280341  126.720042  2021-09-28
# 3      115.80  33.243883  126.421665  2021-09-28
# 4        5.44  33.449858  126.918167  2021-09-28

# %%
# 누락 데이터 확인

part4.count()
# Out:
# 등록(신고)일자      85
# 상호명           85
# 소재지           85
# 시설면적(제곱미터)    85
# 위도            85
# 경도            85
# 데이터기준일자       85
# dtype: int64

# %%
# 완전히 동일한 중복데이터 여부 확인

part4.duplicated().sum()
# Out:
# 0

# %%
new_part2 = pd.concat([part3, part4])

print(new_part2.shape)
print(list(new_part2.columns))
new_part2.head()
# Out:
# (319, 10)
# ['업종', '등록일', '상호명', '우편번호', '소재지', '데이터기준일자', '등록(신고)일자', '시설면적(제곱미터)', '위도', '경도']
#        업종         등록일       상호명     우편번호                    소재지     데이터기준일자  \
# 0  노래연습장업  1993-06-14        연인  63081.0    제주특별자치도 제주시 원노형로 25  2021-08-13
# 1  노래연습장업  1993-10-16  안성 노래연습장  63264.0   제주특별자치도 제주시 동문로10길 6  2021-08-13
# 2  노래연습장업  1993-10-26        현대  63125.0  제주특별자치도 제주시 삼무로11길 36  2021-08-13
# 3  노래연습장업  1993-12-21   에코노래연습장  63123.0  제주특별자치도 제주시 신대로16길 50  2021-08-13
# 4  노래연습장업  1993-12-28       들장미  63168.0  제주특별자치도 제주시 중앙로14길 28  2021-08-13
#
#   등록(신고)일자  시설면적(제곱미터)  위도  경도
# 0      NaN         NaN NaN NaN
# 1      NaN         NaN NaN NaN
# 2      NaN         NaN NaN NaN
# 3      NaN         NaN NaN NaN
# 4      NaN         NaN NaN NaN

# %%
# 컬럼명 변경

new_part2.rename(columns = {'소재지':'도로명주소'},inplace=True)

# %%
# 컬럼 추가

new_part2['행정시'] = np.nan
new_part2['전화번호'] = np.nan

# %%
# 컬럼명 순서변경

new_part2= new_part2[['상호명', '업종', '행정시', '도로명주소', '전화번호', '위도', '경도']]
new_part2.head()
# Out:
#         상호명      업종  행정시                  도로명주소  전화번호  위도  경도
# 0        연인  노래연습장업  NaN    제주특별자치도 제주시 원노형로 25   NaN NaN NaN
# 1  안성 노래연습장  노래연습장업  NaN   제주특별자치도 제주시 동문로10길 6   NaN NaN NaN
# 2        현대  노래연습장업  NaN  제주특별자치도 제주시 삼무로11길 36   NaN NaN NaN
# 3   에코노래연습장  노래연습장업  NaN  제주특별자치도 제주시 신대로16길 50   NaN NaN NaN
# 4       들장미  노래연습장업  NaN  제주특별자치도 제주시 중앙로14길 28   NaN NaN NaN

# %%
# 완전히 동일한 중복데이터 여부 확인

new_part2.duplicated().sum()
# Out:
# 0

# %%
# 완전히 동일한 중복데이터 여부 확인

new_part2.duplicated(['상호명', '도로명주소']).sum()
# Out:
# 0

# %%
# csv 파일 저장

new_part2.to_csv('제주특별자치도_노래연습장현황_병합.csv', encoding='cp949')

# %% [markdown]
# # 제주특별자치도 승마장현황

# %%
# 제주특별자치도 제주시_승마장현황

print(part5.shape)
print(list(part5.columns))
part5.head()
# Out:
# (35, 5)
# ['읍면동', '승마장명', '소재지', '영업구분', '데이터기준일자']
#    읍면동            승마장명                         소재지 영업구분     데이터기준일자
# 0  한림읍          라온더마파크     제주특별자치도 제주시 한림읍 월림7길155  영업중  2021-02-01
# 1  한림읍       힐링팜마사영농조합  제주특별자치도 제주시 한림읍 광산로 395-46  영업중  2021-02-01
# 2  한림읍      홀스홀릭트레이닝센터     제주특별자치도 제주시 한림읍 가린내길 99  영업중  2021-02-01
# 3  애월읍  제주특별자치도말산업협동조합   제주특별자치도 제주시 애월읍 어음13길 180  영업중  2021-02-01
# 4  애월읍          웅지승마센터      제주특별자치도 제주시 애월읍 산록서로81  영업중  2021-02-01

# %%
# 누락 데이터 확인

part5.count()
# Out:
# 읍면동        35
# 승마장명       35
# 소재지        35
# 영업구분       35
# 데이터기준일자    35
# dtype: int64

# %%
# 완전히 동일한 중복데이터 여부 확인

part3.duplicated().sum()
# Out:
# 0

# %%
# 컬럼명 변경

part5.rename(columns = {'승마장명':'상호명', '소재지':'도로명주소'},inplace=True)

# %%
# 컬럼 추가

part5['행정시'] = np.nan
part5['전화번호'] = np.nan
part5['위도'] = np.nan
part5['경도'] = np.nan

# %%
# '업종' 컬럼을 추가하고 '승마장업' 값을 추가

part5.insert(0,'업종','승마장업')

# %%
# 컬럼명 순서변경 및 컬럼 삭제

part5= part5[['업종', '상호명', '행정시', '도로명주소', '전화번호', '위도', '경도']]
print(part5.shape)
part5.head()
# Out:
# (35, 7)
#      업종             상호명  행정시                       도로명주소  전화번호  위도  경도
# 0  승마장업          라온더마파크  NaN     제주특별자치도 제주시 한림읍 월림7길155   NaN NaN NaN
# 1  승마장업       힐링팜마사영농조합  NaN  제주특별자치도 제주시 한림읍 광산로 395-46   NaN NaN NaN
# 2  승마장업      홀스홀릭트레이닝센터  NaN     제주특별자치도 제주시 한림읍 가린내길 99   NaN NaN NaN
# 3  승마장업  제주특별자치도말산업협동조합  NaN   제주특별자치도 제주시 애월읍 어음13길 180   NaN NaN NaN
# 4  승마장업          웅지승마센터  NaN      제주특별자치도 제주시 애월읍 산록서로81   NaN NaN NaN

# %%
# '제주특별자치도_제주도장소(POI)데이터' 에서 서귀포시 승마장 데이터 추출

h_part = part[part['장소명'].str.contains('승마')]
h_part
# Out:
#               장소명      구분                         도로명주소         위도          경도
# 250    트레블러스호텔승마장  레져/스포츠          제주특별자치도 서귀포시 대포동 1-1  33.286064  126.453287
# 632      조랑말타운승마장  레져/스포츠     제주특별자치도 서귀포시 표선면 성읍리 2597  33.407522  126.772856
# 746        어승생승마장  레져/스포츠          제주특별자치도 제주시 노형동 14-1  33.425674  126.490893
# 4371        서광승마장  레져/스포츠     제주특별자치도 서귀포시 안덕면 서광리 산 51  33.302510  126.290938
# 4540        초원승마장  레져/스포츠          제주특별자치도 서귀포시 상예동 150  33.275822  126.396929
# ...           ...     ...                           ...        ...         ...
# 63003    동부승마레저타운  레져/스포츠     제주특별자치도 서귀포시 표선면 성읍리 2873  33.409564  126.770382
# 65243     폴로승마리조트  레져/스포츠      제주특별자치도 제주시 구좌읍 행원리 3266  33.524176  126.780391
# 67111  라온더마파크승마클럽  레져/스포츠      제주특별자치도 제주시 한림읍 월림7길 155  33.355495  126.241804
# 67511   오케이승마장관리동    농공시설  제주특별자치도 서귀포시 표선면 번영로 2350-21  33.415246  126.760857
# 70013   동부승마카트ATV  레져/스포츠     제주특별자치도 서귀포시 표선면 번영로 2454  33.409380  126.770069
#
# [78 rows x 5 columns]

# %%
# 컬럼별로 중복데이터 여부 확인

h_part['구분'].value_counts()
# Out:
# 레져/스포츠        45
# 도로시설          16
# 교통시설          10
# 관광/숙박          3
# 농공시설           2
# 공원/산/동.식물원     1
# 쇼핑/편의          1
# Name: 구분, dtype: int64

# %%
h_part = h_part[h_part.구분 == '레져/스포츠']
h_part.head()
# Out:
#              장소명      구분                      도로명주소         위도          경도
# 250   트레블러스호텔승마장  레져/스포츠       제주특별자치도 서귀포시 대포동 1-1  33.286064  126.453287
# 632     조랑말타운승마장  레져/스포츠  제주특별자치도 서귀포시 표선면 성읍리 2597  33.407522  126.772856
# 746       어승생승마장  레져/스포츠       제주특별자치도 제주시 노형동 14-1  33.425674  126.490893
# 4371       서광승마장  레져/스포츠  제주특별자치도 서귀포시 안덕면 서광리 산 51  33.302510  126.290938
# 4540       초원승마장  레져/스포츠       제주특별자치도 서귀포시 상예동 150  33.275822  126.396929

# %%
h_part = h_part[h_part['도로명주소'].str.contains('서귀포시')]
h_part.head()
# Out:
#              장소명      구분                      도로명주소         위도          경도
# 250   트레블러스호텔승마장  레져/스포츠       제주특별자치도 서귀포시 대포동 1-1  33.286064  126.453287
# 632     조랑말타운승마장  레져/스포츠  제주특별자치도 서귀포시 표선면 성읍리 2597  33.407522  126.772856
# 4371       서광승마장  레져/스포츠  제주특별자치도 서귀포시 안덕면 서광리 산 51  33.302510  126.290938
# 4540       초원승마장  레져/스포츠       제주특별자치도 서귀포시 상예동 150  33.275822  126.396929
# 5708      이어도승마장  레져/스포츠  제주특별자치도 서귀포시 성산읍 수산리 2712  33.428980  126.858136

# %%
# 컬럼명 변경

h_part.rename(columns = {'장소명':'상호명'},inplace=True)
h_part.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#              상호명      구분                      도로명주소         위도          경도
# 250   트레블러스호텔승마장  레져/스포츠       제주특별자치도 서귀포시 대포동 1-1  33.286064  126.453287
# 632     조랑말타운승마장  레져/스포츠  제주특별자치도 서귀포시 표선면 성읍리 2597  33.407522  126.772856
# 4371       서광승마장  레져/스포츠  제주특별자치도 서귀포시 안덕면 서광리 산 51  33.302510  126.290938
# 4540       초원승마장  레져/스포츠       제주특별자치도 서귀포시 상예동 150  33.275822  126.396929
# 5708      이어도승마장  레져/스포츠  제주특별자치도 서귀포시 성산읍 수산리 2712  33.428980  126.858136

# %%
# 컬럼 추가

h_part['전화번호'] = np.nan
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# '업종' 컬럼을 추가하고 '승마장업' 값을 추가

h_part.insert(0,'업종','승마장업')
h_part.insert(1,'행정시','서귀포시')

# %%
# 컬럼명 순서변경 및 컬럼 삭제

h_part = h_part[['상호명', '업종', '행정시', '도로명주소', '전화번호', '위도', '경도']]
print(h_part.shape)
h_part.head()
# Out:
# (23, 7)
#              상호명    업종   행정시                      도로명주소  전화번호         위도  \
# 250   트레블러스호텔승마장  승마장업  서귀포시       제주특별자치도 서귀포시 대포동 1-1   NaN  33.286064
# 632     조랑말타운승마장  승마장업  서귀포시  제주특별자치도 서귀포시 표선면 성읍리 2597   NaN  33.407522
# 4371       서광승마장  승마장업  서귀포시  제주특별자치도 서귀포시 안덕면 서광리 산 51   NaN  33.302510
# 4540       초원승마장  승마장업  서귀포시       제주특별자치도 서귀포시 상예동 150   NaN  33.275822
# 5708      이어도승마장  승마장업  서귀포시  제주특별자치도 서귀포시 성산읍 수산리 2712   NaN  33.428980
#
#               경도
# 250   126.453287
# 632   126.772856
# 4371  126.290938
# 4540  126.396929
# 5708  126.858136

# %%
# 완전히 동일한 중복데이터 여부 확인

h_part.duplicated(['상호명', '도로명주소']).sum()
# Out:
# 0

# %%
part5 = pd.concat([part5, h_part])

print(part5.shape)
print(list(part5.columns))
part5.head()
# Out:
# (58, 7)
# ['업종', '상호명', '행정시', '도로명주소', '전화번호', '위도', '경도']
#      업종             상호명  행정시                       도로명주소  전화번호  위도  경도
# 0  승마장업          라온더마파크  NaN     제주특별자치도 제주시 한림읍 월림7길155   NaN NaN NaN
# 1  승마장업       힐링팜마사영농조합  NaN  제주특별자치도 제주시 한림읍 광산로 395-46   NaN NaN NaN
# 2  승마장업      홀스홀릭트레이닝센터  NaN     제주특별자치도 제주시 한림읍 가린내길 99   NaN NaN NaN
# 3  승마장업  제주특별자치도말산업협동조합  NaN   제주특별자치도 제주시 애월읍 어음13길 180   NaN NaN NaN
# 4  승마장업          웅지승마센터  NaN      제주특별자치도 제주시 애월읍 산록서로81   NaN NaN NaN

# %%
# 완전히 동일한 중복데이터 여부 확인

part5.duplicated(['상호명', '도로명주소']).sum()
# Out:
# 0

# %%
# csv 파일 저장

part5.to_csv('제주특별자치도_승마장현황_병합.csv', encoding='cp949')

# %% [markdown]
# # 제주특별자치도 서귀포시 게임업현황

# %%
# 제주특별자치도 서귀포시_게임업현황

print(part6.shape)
print(list(part6.columns))
part6.head()
# Out:
# (89, 7)
# ['상호', '소재지', '시설면적(㎡)', '업종명', '위도', '경도', '데이터기준일자']
#         상호                           소재지  시설면적(㎡)            업종명         위도  \
# 0      원PC     제주특별자치도 서귀포시 성산읍 고성오조로 16    20.91  인터넷컴퓨터게임시설제공업  33.445204
# 1  테스형PC랜드  제주특별자치도 서귀포시 표선면 표선중앙로80번길 1   122.91  인터넷컴퓨터게임시설제공업  33.326027
# 2   모나코 pc          제주특별자치도 서귀포시 말질로 158   115.70  인터넷컴퓨터게임시설제공업  33.237366
# 3     주공PC       제주특별자치도 서귀포시 중산간동로 8003    23.76  인터넷컴퓨터게임시설제공업  33.264361
# 4    땃따PC방         제주특별자치도 서귀포시 칠십리로 49     57.39  인터넷컴퓨터게임시설제공업  33.240542
#
#            경도     데이터기준일자
# 0  126.913869  2021-09-29
# 1  126.832442  2021-09-29
# 2  126.479739  2021-09-29
# 3  126.561739  2021-09-29
# 4  126.561903  2021-09-29

# %%
# 누락 데이터 확인

part6.count()
# Out:
# 상호         89
# 소재지        89
# 시설면적(㎡)    89
# 업종명        89
# 위도         89
# 경도         89
# 데이터기준일자    89
# dtype: int64

# %%
# 완전히 동일한 중복데이터 여부 확인

part6.duplicated().sum()
# Out:
# 1

# %%
# 중복 행 삭제

part6.drop_duplicates()
# Out:
#          상호                           소재지  시설면적(㎡)            업종명         위도  \
# 0       원PC     제주특별자치도 서귀포시 성산읍 고성오조로 16    20.91  인터넷컴퓨터게임시설제공업  33.445204
# 1   테스형PC랜드  제주특별자치도 서귀포시 표선면 표선중앙로80번길 1   122.91  인터넷컴퓨터게임시설제공업  33.326027
# 2    모나코 pc          제주특별자치도 서귀포시 말질로 158   115.70  인터넷컴퓨터게임시설제공업  33.237366
# 3      주공PC       제주특별자치도 서귀포시 중산간동로 8003    23.76  인터넷컴퓨터게임시설제공업  33.264361
# 4     땃따PC방         제주특별자치도 서귀포시 칠십리로 49     57.39  인터넷컴퓨터게임시설제공업  33.240542
# ..      ...                           ...      ...            ...        ...
# 84     볼트PC           제주특별자치도 서귀포시 대청로 33   307.31      복합유통게임제공업  33.252745
# 85   불새게임랜드           제주특별자치도 서귀포시 중앙로 57   150.05        일반게임제공업  33.249768
# 86    녹원게임장        제주특별자치도 서귀포시 중정로61번길 1   206.04        일반게임제공업  33.248036
# 87    시티게임장       제주특별자치도 서귀포시 중앙로48번길 32   179.45        일반게임제공업  33.249477
# 88   팡팡게임랜드      제주특별자치도 서귀포시 중정로91번길 13    242.00        일반게임제공업  33.249278
#
#             경도     데이터기준일자
# ...

# %%
# 컬럼명 변경

part6.rename(columns = {'상호':'상호명', '소재지':'도로명주소', '업종명':'업종'},inplace=True)

# %%
# 컬럼 추가

part6['행정시'] = np.nan
part6['전화번호'] = np.nan

# %%
# 컬럼명 순서변경 및 컬럼 삭제

part6 = part6[['상호명', '업종', '행정시', '도로명주소', '전화번호', '위도', '경도']]
print(part6.shape)
part6.head()
# Out:
# (89, 7)
#        상호명             업종  행정시                         도로명주소  전화번호         위도  \
# 0      원PC  인터넷컴퓨터게임시설제공업  NaN     제주특별자치도 서귀포시 성산읍 고성오조로 16   NaN  33.445204
# 1  테스형PC랜드  인터넷컴퓨터게임시설제공업  NaN  제주특별자치도 서귀포시 표선면 표선중앙로80번길 1   NaN  33.326027
# 2   모나코 pc  인터넷컴퓨터게임시설제공업  NaN          제주특별자치도 서귀포시 말질로 158   NaN  33.237366
# 3     주공PC  인터넷컴퓨터게임시설제공업  NaN       제주특별자치도 서귀포시 중산간동로 8003   NaN  33.264361
# 4    땃따PC방  인터넷컴퓨터게임시설제공업  NaN         제주특별자치도 서귀포시 칠십리로 49    NaN  33.240542
#
#            경도
# 0  126.913869
# 1  126.832442
# 2  126.479739
# 3  126.561739
# 4  126.561903

# %%
# csv 파일 저장

part6.to_csv('제주특별자치도_서귀포시_게임업현황.csv', encoding='cp949')

# %% [markdown]
# # 제주도특별자치도_영화관현황

# %%
# 제주특별자치도 제주시_영화상영관현황

print(part7.shape)
print(list(part7.columns))
part7.head()
# Out:
# (34, 7)
# ['영화관명', '소재지', '상영관별', '설립연도', '상영관면적', '객석수', '데이터기준일자']
#       영화관명                                        소재지 상영관별    설립연도  상영관면적  \
# 0  메가박스 제주               제주특별자치도 제주시 중앙로14길 18 (삼도이동)   1관  2005.0  348.8
# 1  메가박스 제주  제주특별자치도 제주시 중앙로14길 18, 5층 (삼도이동, 메가박스 제주)   2관  2005.0  170.2
# 2  메가박스 제주  제주특별자치도 제주시 중앙로14길 18, 5층 (삼도이동, 메가박스 제주)   3관  2005.0  117.8
# 3  메가박스 제주  제주특별자치도 제주시 중앙로14길 18, 5층 (삼도이동, 메가박스 제주)   5관  2005.0  132.8
# 4  메가박스 제주  제주특별자치도 제주시 중앙로14길 18, 5층 (삼도이동, 메가박스 제주)   6관  2005.0  120.3
#
#    객석수     데이터기준일자
# 0  340  2021-08-20
# 1  128  2021-08-20
# 2   98  2021-08-20
# 3  110  2021-08-20
# 4   86  2021-08-20

# %%
# 컬럼명 변경

part7.rename(columns = {'영화관명':'상호명', '소재지':'도로명주소'},inplace=True)
part7.head()
# Out:
#        상호명                                      도로명주소 상영관별    설립연도  상영관면적  \
# 0  메가박스 제주               제주특별자치도 제주시 중앙로14길 18 (삼도이동)   1관  2005.0  348.8
# 1  메가박스 제주  제주특별자치도 제주시 중앙로14길 18, 5층 (삼도이동, 메가박스 제주)   2관  2005.0  170.2
# 2  메가박스 제주  제주특별자치도 제주시 중앙로14길 18, 5층 (삼도이동, 메가박스 제주)   3관  2005.0  117.8
# 3  메가박스 제주  제주특별자치도 제주시 중앙로14길 18, 5층 (삼도이동, 메가박스 제주)   5관  2005.0  132.8
# 4  메가박스 제주  제주특별자치도 제주시 중앙로14길 18, 5층 (삼도이동, 메가박스 제주)   6관  2005.0  120.3
#
#    객석수     데이터기준일자
# 0  340  2021-08-20
# 1  128  2021-08-20
# 2   98  2021-08-20
# 3  110  2021-08-20
# 4   86  2021-08-20

# %%
# 컬럼 추가

part7['전화번호'] = np.nan
part7['위도'] = np.nan
part7['경도'] = np.nan

# %%
# '행정시' 컬럼을 추가하고 '제주시' 값을 추가

part7.insert(0,'행정시','제주시')
part7.insert(1,'업종','영화관업')

# %%
# 컬럼명 순서변경

part7 = part7[['상호명', '업종', '행정시', '도로명주소', '전화번호', '위도', '경도']]
print(part7.shape)
part7.head()
# Out:
# (34, 7)
#        상호명    업종  행정시                                      도로명주소  전화번호  위도  경도
# 0  메가박스 제주  영화관업  제주시               제주특별자치도 제주시 중앙로14길 18 (삼도이동)   NaN NaN NaN
# 1  메가박스 제주  영화관업  제주시  제주특별자치도 제주시 중앙로14길 18, 5층 (삼도이동, 메가박스 제주)   NaN NaN NaN
# 2  메가박스 제주  영화관업  제주시  제주특별자치도 제주시 중앙로14길 18, 5층 (삼도이동, 메가박스 제주)   NaN NaN NaN
# 3  메가박스 제주  영화관업  제주시  제주특별자치도 제주시 중앙로14길 18, 5층 (삼도이동, 메가박스 제주)   NaN NaN NaN
# 4  메가박스 제주  영화관업  제주시  제주특별자치도 제주시 중앙로14길 18, 5층 (삼도이동, 메가박스 제주)   NaN NaN NaN

# %%
part7 = part7.drop_duplicates(['도로명주소'])

# %%
print(part7.shape)
part7
# Out:
# (9, 7)
#             상호명    업종  행정시                                      도로명주소  전화번호  \
# 0       메가박스 제주  영화관업  제주시               제주특별자치도 제주시 중앙로14길 18 (삼도이동)   NaN
# 1       메가박스 제주  영화관업  제주시  제주특별자치도 제주시 중앙로14길 18, 5층 (삼도이동, 메가박스 제주)   NaN
# 6       씨지브이 제주  영화관업  제주시                        제주특별자치도 제주시 서광로 288   NaN
# 13     CGV 제주노형  영화관업  제주시                        제주특별자치도 제주시 노형로 407   NaN
# 19  롯데시네마제주 아라점  영화관업  제주시                          제주특별자치도 제주시 구산로 4   NaN
# 25  롯데시네마제주 삼화점  영화관업  제주시                        제주특별자치도 제주시 삼봉로 11    NaN
# 30      제주자동차극장  영화관업  제주시                        제주특별자치도 제주시 도공로 136   NaN
# 31     한림 작은영화관  영화관업  제주시                 제주특별자치도 제주시 한림읍 한림리 887-2    NaN
# 33     영화문화예술센터  영화관업  제주시                        제주특별자치도 제주시 중앙로5길 6   NaN
#
#     위도  경도
# 0  NaN NaN
# 1  NaN NaN
# 6  NaN NaN
# 13 NaN NaN
# 19 NaN NaN
# 25 NaN NaN
# 30 NaN NaN
# 31 NaN NaN
# 33 NaN NaN

# %%
# '상호명'칼럼 값을 '롯데시네마 서귀포'로 편경

part7.loc[(part7.상호명 == '씨지브이 제주'), '상호명'] = 'CGV 제주'
part7.loc[(part7.상호명 == '롯데시네마제주 아라점'), '상호명'] = '롯데시네마 제주 아라점'
part7.loc[(part7.상호명 == '롯데시네마제주 삼화점'), '상호명'] = '롯데시네마 제주 삼화점'

part7.loc[(part7.도로명주소 == '제주특별자치도 제주시 중앙로14길 18 (삼도이동)'), '도로명주소'] = '제주특별자치도 제주시 중앙로14길 18'

# %%
part7 = part7.drop(index=1, axis=0)

# %%
print(part7.shape)
part7
# Out:
# (8, 7)
#              상호명    업종  행정시                       도로명주소  전화번호  위도  경도
# 0        메가박스 제주  영화관업  제주시       제주특별자치도 제주시 중앙로14길 18   NaN NaN NaN
# 6         CGV 제주  영화관업  제주시         제주특별자치도 제주시 서광로 288   NaN NaN NaN
# 13      CGV 제주노형  영화관업  제주시         제주특별자치도 제주시 노형로 407   NaN NaN NaN
# 19  롯데시네마 제주 아라점  영화관업  제주시           제주특별자치도 제주시 구산로 4   NaN NaN NaN
# 25  롯데시네마 제주 삼화점  영화관업  제주시         제주특별자치도 제주시 삼봉로 11    NaN NaN NaN
# 30       제주자동차극장  영화관업  제주시         제주특별자치도 제주시 도공로 136   NaN NaN NaN
# 31      한림 작은영화관  영화관업  제주시  제주특별자치도 제주시 한림읍 한림리 887-2    NaN NaN NaN
# 33      영화문화예술센터  영화관업  제주시         제주특별자치도 제주시 중앙로5길 6   NaN NaN NaN

# %%
# 제주특별자치도 서귀포시_영화상영관현황

print(part8.shape)
print(list(part8.columns))
part8.head()
# Out:
# (6, 7)
# ['등록일자', '상영관명', '상영관소재지(지번)', '상영관소재지(도로명)', '관람정원', '영업상태', '데이터기준일자']
#          등록일자          상영관명               상영관소재지(지번)  \
# 0  2005-12-23  롯데시네마 서귀포 1관  제주특별자치도 서귀포시 법환동 914번지
# 1  2005-12-23   롯데시네마 서귀포2관  제주특별자치도 서귀포시 법환동 914번지
# 2  2005-12-23  롯데시네마 서귀포 3관  제주특별자치도 서귀포시 법환동 914번지
# 3  2005-12-23  롯데시네마 서귀포 5관  제주특별자치도 서귀포시 법환동 914번지
# 4  2005-12-28  롯데시네마 서귀포 7관  제주특별자치도 서귀포시 법환동 914번지
#
#                   상영관소재지(도로명)  관람정원 영업상태     데이터기준일자
# 0  제주특별자치도 서귀포시 월드컵로 31 (법환동)   168  영업중  2021-10-01
# 1  제주특별자치도 서귀포시 월드컵로 31 (법환동)    99  영업중  2021-10-01
# 2  제주특별자치도 서귀포시 월드컵로 31 (법환동)   149  영업중  2021-10-01
# 3  제주특별자치도 서귀포시 월드컵로 31 (법환동)    92  영업중  2021-10-01
# 4  제주특별자치도 서귀포시 월드컵로 31 (법환동)    79  영업중  2021-10-01

# %%
# 컬럼명 변경

part8.rename(columns = {'상영관명':'상호명', '상영관소재지(도로명)':'도로명주소'},inplace=True)
part8.head()
# Out:
#          등록일자           상호명               상영관소재지(지번)  \
# 0  2005-12-23  롯데시네마 서귀포 1관  제주특별자치도 서귀포시 법환동 914번지
# 1  2005-12-23   롯데시네마 서귀포2관  제주특별자치도 서귀포시 법환동 914번지
# 2  2005-12-23  롯데시네마 서귀포 3관  제주특별자치도 서귀포시 법환동 914번지
# 3  2005-12-23  롯데시네마 서귀포 5관  제주특별자치도 서귀포시 법환동 914번지
# 4  2005-12-28  롯데시네마 서귀포 7관  제주특별자치도 서귀포시 법환동 914번지
#
#                         도로명주소  관람정원 영업상태     데이터기준일자
# 0  제주특별자치도 서귀포시 월드컵로 31 (법환동)   168  영업중  2021-10-01
# 1  제주특별자치도 서귀포시 월드컵로 31 (법환동)    99  영업중  2021-10-01
# 2  제주특별자치도 서귀포시 월드컵로 31 (법환동)   149  영업중  2021-10-01
# 3  제주특별자치도 서귀포시 월드컵로 31 (법환동)    92  영업중  2021-10-01
# 4  제주특별자치도 서귀포시 월드컵로 31 (법환동)    79  영업중  2021-10-01

# %%
# 컬럼 추가

part8['전화번호'] = np.nan
part8['위도'] = np.nan
part8['경도'] = np.nan

# %%
# '행정시' 컬럼을 추가하고 '서귀포시' 값을 추가

part8.insert(0,'행정시','서귀포시')
part8.insert(1,'업종','영화관업')

# %%
# 컬럼명 순서변경

part8 = part8[['상호명', '업종', '행정시', '도로명주소', '전화번호', '위도', '경도']]
part8.head()
# Out:
#             상호명    업종   행정시                       도로명주소  전화번호  위도  경도
# 0  롯데시네마 서귀포 1관  영화관업  서귀포시  제주특별자치도 서귀포시 월드컵로 31 (법환동)   NaN NaN NaN
# 1   롯데시네마 서귀포2관  영화관업  서귀포시  제주특별자치도 서귀포시 월드컵로 31 (법환동)   NaN NaN NaN
# 2  롯데시네마 서귀포 3관  영화관업  서귀포시  제주특별자치도 서귀포시 월드컵로 31 (법환동)   NaN NaN NaN
# 3  롯데시네마 서귀포 5관  영화관업  서귀포시  제주특별자치도 서귀포시 월드컵로 31 (법환동)   NaN NaN NaN
# 4  롯데시네마 서귀포 7관  영화관업  서귀포시  제주특별자치도 서귀포시 월드컵로 31 (법환동)   NaN NaN NaN

# %%
# '상호명'칼럼 값을 '롯데시네마 서귀포'로 편경

part8.at[0,'상호명'] = '롯데시네마 서귀포'

# %%
part8.head()
# Out:
#             상호명    업종   행정시                       도로명주소  전화번호  위도  경도
# 0     롯데시네마 서귀포  영화관업  서귀포시  제주특별자치도 서귀포시 월드컵로 31 (법환동)   NaN NaN NaN
# 1   롯데시네마 서귀포2관  영화관업  서귀포시  제주특별자치도 서귀포시 월드컵로 31 (법환동)   NaN NaN NaN
# 2  롯데시네마 서귀포 3관  영화관업  서귀포시  제주특별자치도 서귀포시 월드컵로 31 (법환동)   NaN NaN NaN
# 3  롯데시네마 서귀포 5관  영화관업  서귀포시  제주특별자치도 서귀포시 월드컵로 31 (법환동)   NaN NaN NaN
# 4  롯데시네마 서귀포 7관  영화관업  서귀포시  제주특별자치도 서귀포시 월드컵로 31 (법환동)   NaN NaN NaN

# %%
part8 = part8.loc[[0], :]
part8
# Out:
#          상호명    업종   행정시                       도로명주소  전화번호  위도  경도
# 0  롯데시네마 서귀포  영화관업  서귀포시  제주특별자치도 서귀포시 월드컵로 31 (법환동)   NaN NaN NaN

# %%
new_part3 = pd.concat([part7, part8])

print(new_part3.shape)
print(list(new_part3.columns))
new_part3.head()
# Out:
# (9, 7)
# ['상호명', '업종', '행정시', '도로명주소', '전화번호', '위도', '경도']
#              상호명    업종  행정시                  도로명주소  전화번호  위도  경도
# 0        메가박스 제주  영화관업  제주시  제주특별자치도 제주시 중앙로14길 18   NaN NaN NaN
# 6         CGV 제주  영화관업  제주시    제주특별자치도 제주시 서광로 288   NaN NaN NaN
# 13      CGV 제주노형  영화관업  제주시    제주특별자치도 제주시 노형로 407   NaN NaN NaN
# 19  롯데시네마 제주 아라점  영화관업  제주시      제주특별자치도 제주시 구산로 4   NaN NaN NaN
# 25  롯데시네마 제주 삼화점  영화관업  제주시    제주특별자치도 제주시 삼봉로 11    NaN NaN NaN

# %%
# csv 파일 저장

new_part3.to_csv('제주특별자치도_영화관현황_병합.csv', encoding='cp949')

# %% [markdown]
# # 제주특별자치도 교육관련기관현황

# %%
# 제주특별자치도_교육관련기관현황

print(part9.shape)
print(list(part9.columns))
part9.head()
# Out:
# (32, 6)
# ['구분', '기관명', '소재지', '연락처', '홈페이지', '데이터기준일자']
#              구분           기관명                    소재지           연락처  \
# 0  제주특별자치도인재개발원  제주특별자치도인재개발원  제주특별자치도 제주시 산천단동길 26   064-710-7432
# 1           교육청    제주특별자치도교육청      제주특별자치도 제주시 문연로 5  064-710-0114
# 2           교육청        제주시교육청     제주특별자치도 제주시 남광로 27  064-754-1221
# 3           교육청       서귀포시교육청   제주특별자치도 서귀포시 토평로 43   064-762-4224
# 4    교육원/문화원/단체     제주교육과학연구원  제주특별자치도 제주시 산록북로 421   064-710-0800
#
#                                       홈페이지     데이터기준일자
# 0  http://www.jeju.go.kr/jejuedu/index.htm  2021-08-20
# 1                    http://www.jje.go.kr/  2021-08-20
# 2                   http://www.jjse.go.kr/  2021-08-20
# 3                    http://www.jse.go.kr/  2021-08-20
# 4                  http://www.cisec.or.kr/  2021-08-20

# %%
# 컬럼명 변경

part9.rename(columns = {'기관명':'상호명', '구분':'업종', '소재지':'도로명주소', '연락처':'전화번호'},inplace=True)
part9.head()
# Out:
#              업종           상호명                  도로명주소          전화번호  \
# 0  제주특별자치도인재개발원  제주특별자치도인재개발원  제주특별자치도 제주시 산천단동길 26   064-710-7432
# 1           교육청    제주특별자치도교육청      제주특별자치도 제주시 문연로 5  064-710-0114
# 2           교육청        제주시교육청     제주특별자치도 제주시 남광로 27  064-754-1221
# 3           교육청       서귀포시교육청   제주특별자치도 서귀포시 토평로 43   064-762-4224
# 4    교육원/문화원/단체     제주교육과학연구원  제주특별자치도 제주시 산록북로 421   064-710-0800
#
#                                       홈페이지     데이터기준일자
# 0  http://www.jeju.go.kr/jejuedu/index.htm  2021-08-20
# 1                    http://www.jje.go.kr/  2021-08-20
# 2                   http://www.jjse.go.kr/  2021-08-20
# 3                    http://www.jse.go.kr/  2021-08-20
# 4                  http://www.cisec.or.kr/  2021-08-20

# %%
# 컬럼 추가

part9['행정시'] = np.nan
part9['위도'] = np.nan
part9['경도'] = np.nan

# %%
# 컬럼명 순서변경

part9 = part9[['상호명', '업종', '행정시', '도로명주소', '전화번호', '위도', '경도']]
print(part9.shape)
part9.head()
# Out:
# (32, 7)
#             상호명            업종  행정시                  도로명주소          전화번호  위도  \
# 0  제주특별자치도인재개발원  제주특별자치도인재개발원  NaN  제주특별자치도 제주시 산천단동길 26   064-710-7432 NaN
# 1    제주특별자치도교육청           교육청  NaN      제주특별자치도 제주시 문연로 5  064-710-0114 NaN
# 2        제주시교육청           교육청  NaN     제주특별자치도 제주시 남광로 27  064-754-1221 NaN
# 3       서귀포시교육청           교육청  NaN   제주특별자치도 서귀포시 토평로 43   064-762-4224 NaN
# 4     제주교육과학연구원    교육원/문화원/단체  NaN  제주특별자치도 제주시 산록북로 421   064-710-0800 NaN
#
#    경도
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN

# %%
# 제주특별자치도_국제학교현황

print(part10.shape)
print(list(part10.columns))
part10.head()
# Out:
# (4, 8)
# ['학교명', '위치', '대지면적', '대상', '형태', '상세', '개교일', '데이터기준일자']
#                                                  학교명  \
# 0                 한국국제학교(Korea International School)
# 1  노스런던컬리지게이트스쿨 제주(North LondonCollegiate School ...
# 2                       브랭섬홀아시아(Branksome Hall Asia)
# 3               SJA Jeju(St. Johnsbury Academy Jeju)
#
#                                 위치    대지면적        대상  \
# 0  제주특별자치도 서귀포시 대정읍 글로벌에듀로260번길 34   76125  유치원~12학년
# 1  제주특별자치도 서귀포시 대정읍 글로벌에듀로145번길 33  104385  유치원~13학년
# 2      제주특별자치도 서귀포시 대정읍 글로벌에듀로 234   94955  유치원~12학년
# 3  제주특별자치도 서귀포시 대정읍 글로벌에듀로304번길 10  102171  유치원~12학년
#
#                                                   형태                    상세  \
# 0                         남녀공학+Day & Boarding School  782명(초+중)+480명(고등학교)
# 1                         남녀공학+Day & Boarding School            73학급 1508명
# 2  여학교+Day & Boarding School - Junior Kindergarte...            60학급 1212명
# ...

# %%
# 컬럼명 변경

part10.rename(columns = {'학교명':'상호명', '위치':'도로명주소'},inplace=True)
part10.head()
# Out:
#                                                  상호명  \
# 0                 한국국제학교(Korea International School)
# 1  노스런던컬리지게이트스쿨 제주(North LondonCollegiate School ...
# 2                       브랭섬홀아시아(Branksome Hall Asia)
# 3               SJA Jeju(St. Johnsbury Academy Jeju)
#
#                              도로명주소    대지면적        대상  \
# 0  제주특별자치도 서귀포시 대정읍 글로벌에듀로260번길 34   76125  유치원~12학년
# 1  제주특별자치도 서귀포시 대정읍 글로벌에듀로145번길 33  104385  유치원~13학년
# 2      제주특별자치도 서귀포시 대정읍 글로벌에듀로 234   94955  유치원~12학년
# 3  제주특별자치도 서귀포시 대정읍 글로벌에듀로304번길 10  102171  유치원~12학년
#
#                                                   형태                    상세  \
# 0                         남녀공학+Day & Boarding School  782명(초+중)+480명(고등학교)
# 1                         남녀공학+Day & Boarding School            73학급 1508명
# 2  여학교+Day & Boarding School - Junior Kindergarte...            60학급 1212명
# 3                         남녀공학+Day & Boarding School            68학급+1254명
#
#           개교일     데이터기준일자
# ...

# %%
# 컬럼 추가

part10['전화번호'] = np.nan
part10['위도'] = np.nan
part10['경도'] = np.nan

# %%
part10.insert(0,'행정시','서귀포시')
part10.insert(1,'업종','학교')

# %%
# 컬럼명 순서변경

part10 = part10[['상호명', '업종', '행정시', '도로명주소', '전화번호', '위도', '경도']]
print(part10.shape)
part10.head()
# Out:
# (4, 7)
#                                                  상호명  업종   행정시  \
# 0                 한국국제학교(Korea International School)  학교  서귀포시
# 1  노스런던컬리지게이트스쿨 제주(North LondonCollegiate School ...  학교  서귀포시
# 2                       브랭섬홀아시아(Branksome Hall Asia)  학교  서귀포시
# 3               SJA Jeju(St. Johnsbury Academy Jeju)  학교  서귀포시
#
#                              도로명주소  전화번호  위도  경도
# 0  제주특별자치도 서귀포시 대정읍 글로벌에듀로260번길 34   NaN NaN NaN
# 1  제주특별자치도 서귀포시 대정읍 글로벌에듀로145번길 33   NaN NaN NaN
# 2      제주특별자치도 서귀포시 대정읍 글로벌에듀로 234   NaN NaN NaN
# 3  제주특별자치도 서귀포시 대정읍 글로벌에듀로304번길 10   NaN NaN NaN

# %%
# 제주특별자치도_문화학교현황

print(part11.shape)
print(list(part11.columns))
part11.head()
# Out:
# (14, 4)
# ['구분', '주소', '전화번호', '데이터기준일자']
#              구분                    주소          전화번호     데이터기준일자
# 0     우당도서관문화학교  제주특별자치도 제주시 사라봉동길 30  064-752-4986  2021-08-12
# 1     탐라도서관문화학교    제주특별자치도 제주시 정원로 50  064-742-7395  2021-08-12
# 2  이도2동문화의집문화학교    제주특별자치도 제주시 오복3길 8  064-755-2021  2021-08-12
# 3  일도2동문화의집문화학교    제주특별자치도 제주시 고마로 28  064-722-2302  2021-08-12
# 4     제주문화원문화학교     제주특별자치도 제주시 중앙로 2  064-722-0203  2021-08-12

# %%
# 컬럼명 변경

part11.rename(columns = {'구분':'상호명', '주소':'도로명주소'},inplace=True)
part11.head()
# Out:
#             상호명                 도로명주소          전화번호     데이터기준일자
# 0     우당도서관문화학교  제주특별자치도 제주시 사라봉동길 30  064-752-4986  2021-08-12
# 1     탐라도서관문화학교    제주특별자치도 제주시 정원로 50  064-742-7395  2021-08-12
# 2  이도2동문화의집문화학교    제주특별자치도 제주시 오복3길 8  064-755-2021  2021-08-12
# 3  일도2동문화의집문화학교    제주특별자치도 제주시 고마로 28  064-722-2302  2021-08-12
# 4     제주문화원문화학교     제주특별자치도 제주시 중앙로 2  064-722-0203  2021-08-12

# %%
# 컬럼 추가

part11['행정시'] = np.nan
part11['위도'] = np.nan
part11['경도'] = np.nan

# %%
part11.insert(1,'업종','학교')

# %%
# 컬럼명 순서변경

part11 = part11[['상호명', '업종', '행정시', '도로명주소', '전화번호', '위도', '경도']]
print(part11.shape)
part11.head()
# Out:
# (14, 7)
#             상호명  업종  행정시                 도로명주소          전화번호  위도  경도
# 0     우당도서관문화학교  학교  NaN  제주특별자치도 제주시 사라봉동길 30  064-752-4986 NaN NaN
# 1     탐라도서관문화학교  학교  NaN    제주특별자치도 제주시 정원로 50  064-742-7395 NaN NaN
# 2  이도2동문화의집문화학교  학교  NaN    제주특별자치도 제주시 오복3길 8  064-755-2021 NaN NaN
# 3  일도2동문화의집문화학교  학교  NaN    제주특별자치도 제주시 고마로 28  064-722-2302 NaN NaN
# 4     제주문화원문화학교  학교  NaN     제주특별자치도 제주시 중앙로 2  064-722-0203 NaN NaN

# %%
new_part4 = pd.concat([part9, part10, part11])

print(new_part4.shape)
print(list(new_part4.columns))
new_part4.head()
# Out:
# (50, 7)
# ['상호명', '업종', '행정시', '도로명주소', '전화번호', '위도', '경도']
#             상호명            업종  행정시                  도로명주소          전화번호  위도  \
# 0  제주특별자치도인재개발원  제주특별자치도인재개발원  NaN  제주특별자치도 제주시 산천단동길 26   064-710-7432 NaN
# 1    제주특별자치도교육청           교육청  NaN      제주특별자치도 제주시 문연로 5  064-710-0114 NaN
# 2        제주시교육청           교육청  NaN     제주특별자치도 제주시 남광로 27  064-754-1221 NaN
# 3       서귀포시교육청           교육청  NaN   제주특별자치도 서귀포시 토평로 43   064-762-4224 NaN
# 4     제주교육과학연구원    교육원/문화원/단체  NaN  제주특별자치도 제주시 산록북로 421   064-710-0800 NaN
#
#    경도
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN

# %%
# 완전히 동일한 중복데이터 여부 확인

new_part4.duplicated(['상호명']).sum()
# Out:
# 0

# %%
# csv 파일 저장

new_part4.to_csv('제주특별자치도_교육관련기관현황_병합.csv', encoding='cp949')

# %% [markdown]
# # 제주특별자치도 공연장 현황

# %%
# 제주특별자치도_제주도내 공연장 현황

print(part12.shape)
print(list(part12.columns))
part12.head()
# Out:
# (34, 6)
# ['연번', '공연장명', '소재지', '시설구분', '비 고', '기준일자']
#    연번         공연장명                   소재지 시설구분   비 고        기준일자
# 0   1  제주도문예회관 대극장     제주시 동광로 69 (일도이동)   공공  종합공연  2021-11-30
# 1   2  제주도문예회관 소극장     제주시 동광로 69 (일도이동)   공공  종합공연  2021-11-30
# 2   3      제주해변공연장      제주시 중앙로 2 (삼도이동)   공공  종합공연  2021-11-30
# 3   4         에술극장      제주시 신산로 82(일도이동)   공공  종합공연  2021-11-30
# 4   5   제주대학교아라뮤즈홀  제주시 제주대학로 102((아라일동)   공공  종합공연  2021-11-30

# %%
# 컬럼명 변경

part12.rename(columns = {'공연장명':'상호명', '소재지':'도로명주소'},inplace=True)
part12.head()
# Out:
#    연번          상호명                 도로명주소 시설구분   비 고        기준일자
# 0   1  제주도문예회관 대극장     제주시 동광로 69 (일도이동)   공공  종합공연  2021-11-30
# 1   2  제주도문예회관 소극장     제주시 동광로 69 (일도이동)   공공  종합공연  2021-11-30
# 2   3      제주해변공연장      제주시 중앙로 2 (삼도이동)   공공  종합공연  2021-11-30
# 3   4         에술극장      제주시 신산로 82(일도이동)   공공  종합공연  2021-11-30
# 4   5   제주대학교아라뮤즈홀  제주시 제주대학로 102((아라일동)   공공  종합공연  2021-11-30

# %%
# 컬럼 추가

part12['업종'] = np.nan
part12['행정시'] = np.nan
part12['전화번호'] = np.nan
part12['위도'] = np.nan
part12['경도'] = np.nan

# %%
# 컬럼명 순서변경 및 삭제

part12 = part12[['상호명', '업종', '행정시', '도로명주소', '전화번호', '위도', '경도']]
print(part12.shape)
part12.head()
# Out:
# (34, 7)
#            상호명  업종  행정시                 도로명주소  전화번호  위도  경도
# 0  제주도문예회관 대극장 NaN  NaN     제주시 동광로 69 (일도이동)   NaN NaN NaN
# 1  제주도문예회관 소극장 NaN  NaN     제주시 동광로 69 (일도이동)   NaN NaN NaN
# 2      제주해변공연장 NaN  NaN      제주시 중앙로 2 (삼도이동)   NaN NaN NaN
# 3         에술극장 NaN  NaN      제주시 신산로 82(일도이동)   NaN NaN NaN
# 4   제주대학교아라뮤즈홀 NaN  NaN  제주시 제주대학로 102((아라일동)   NaN NaN NaN

# %%
# csv 파일 저장

part12.to_csv('제주특별자치도_공연장현황_병합.csv', encoding='cp949')

# %% [markdown]
# 제주특별자치도 문화예술법인현황

# %%
# 제주문화예술법인현황

print(part13.shape)
print(list(part13.columns))
part13.head()
# Out:
# (144, 8)
# ['인허가일자', '법인명', '영업상태명', '소재지 지번 주소', '소재지 도로명 주소', '문화체육업종명', '데이터갱신일자', '데이터 기준일']
#       인허가일자                  법인명  영업상태명  \
# 0  20180228     재단법인 제주영상문화산업진흥원  영업/정상
# 1  20161227         사단법인 제주빌레앙상블  영업/정상
# 2  20160404  사단법인 제주특별자치도 시낭송 협회  영업/정상
# 3  20190225          사단법인 사운드브릿지  영업/정상
# 4  20190304          사단법인 사람과사람들  영업/정상
#
#                                  소재지 지번 주소  \
# 0               제주특별자치도 제주시 일도이동 837번지 20호
# 1              제주특별자치도 제주시 일도이동 1030번지 10호
# 2                제주특별자치도 제주시 이도이동 76번지 13호
# 3               제주특별자치도 제주시 노형동 1284번지 11호
# 4  제주특별자치도 제주시 이도이동 1176번지 67호 제주벤처마루 608호
#
#                                   소재지 도로명 주소  문화체육업종명   데이터갱신일자   데이터 기준일
# 0                제주특별자치도 제주시 신산로 82-0 (일도이동)  컨텐츠(재단)  20190619  20211031
# 1          제주특별자치도 제주시 중앙로 491-0, 지하층 (아라이동)   예술(사단)  20200205  20211031
# 2                제주특별자치도 제주시 연신로 87-5 (이도이동)   문화(사단)  20190615  20211031
# ...

# %%
# 컬럼명 변경

part13.rename(columns = {'법인명':'상호명', '소재지 도로명 주소':'도로명주소'},inplace=True)
part13.head()
# Out:
#       인허가일자                  상호명  영업상태명  \
# 0  20180228     재단법인 제주영상문화산업진흥원  영업/정상
# 1  20161227         사단법인 제주빌레앙상블  영업/정상
# 2  20160404  사단법인 제주특별자치도 시낭송 협회  영업/정상
# 3  20190225          사단법인 사운드브릿지  영업/정상
# 4  20190304          사단법인 사람과사람들  영업/정상
#
#                                  소재지 지번 주소  \
# 0               제주특별자치도 제주시 일도이동 837번지 20호
# 1              제주특별자치도 제주시 일도이동 1030번지 10호
# 2                제주특별자치도 제주시 이도이동 76번지 13호
# 3               제주특별자치도 제주시 노형동 1284번지 11호
# 4  제주특별자치도 제주시 이도이동 1176번지 67호 제주벤처마루 608호
#
#                                        도로명주소  문화체육업종명   데이터갱신일자   데이터 기준일
# 0                제주특별자치도 제주시 신산로 82-0 (일도이동)  컨텐츠(재단)  20190619  20211031
# 1          제주특별자치도 제주시 중앙로 491-0, 지하층 (아라이동)   예술(사단)  20200205  20211031
# 2                제주특별자치도 제주시 연신로 87-5 (이도이동)   문화(사단)  20190615  20211031
# 3               제주특별자치도 제주시 정존13길 13-0 (노형동)   예술(사단)  20190615  20211031
# 4  제주특별자치도 제주시 중앙로 217-0, 608호 (이도이동,제주벤처마루)   문화(사단)  20190615  20211031

# %%
# 컬럼 추가

part13['행정시'] = np.nan
part13['전화번호'] = np.nan
part13['위도'] = np.nan
part13['경도'] = np.nan
part13.insert(0,'업종','문화체육업')

# %%
# 컬럼명 순서변경 및 삭제

part13 = part13[['상호명', '업종', '행정시', '도로명주소', '전화번호', '위도', '경도']]
print(part13.shape)
part13.head()
# Out:
# (144, 7)
#                    상호명     업종  행정시                                      도로명주소  \
# 0     재단법인 제주영상문화산업진흥원  문화체육업  NaN                제주특별자치도 제주시 신산로 82-0 (일도이동)
# 1         사단법인 제주빌레앙상블  문화체육업  NaN          제주특별자치도 제주시 중앙로 491-0, 지하층 (아라이동)
# 2  사단법인 제주특별자치도 시낭송 협회  문화체육업  NaN                제주특별자치도 제주시 연신로 87-5 (이도이동)
# 3          사단법인 사운드브릿지  문화체육업  NaN               제주특별자치도 제주시 정존13길 13-0 (노형동)
# 4          사단법인 사람과사람들  문화체육업  NaN  제주특별자치도 제주시 중앙로 217-0, 608호 (이도이동,제주벤처마루)
#
#    전화번호  위도  경도
# 0   NaN NaN NaN
# 1   NaN NaN NaN
# 2   NaN NaN NaN
# 3   NaN NaN NaN
# 4   NaN NaN NaN

# %%
# csv 파일 저장

part13.to_csv('제주특별자치도_문화예술법인현황_병합.csv', encoding='cp949')

# %% [markdown]
# # 제주특별자치도 통신판매업현황

# %%
# 제주특별자치도 통신판매업현황

print(part14.shape)
print(list(part14.columns))
part14.head()
# Out:
# (14633, 14)
# ['사업장명', '업종구분대분류', '인허가일자', '인허가취소일자', '영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자', '재개업일자', '소재지면적', '지번주소', '도로명주소', '도로명우편번호', '데이터갱신일자']
#          사업장명 업종구분대분류     인허가일자  인허가취소일자  영업상태명  폐업일자  휴업시작일자  휴업종료일자  재개업일자  \
# 0       제주싱싱몰   통신판매업  20100706      NaN  영업/정상   NaN     NaN     NaN    NaN
# 1        필리스틴   통신판매업  20120709      NaN  영업/정상   NaN     NaN     NaN    NaN
# 2  주식회사 제주필투어   통신판매업  20181102      NaN  영업/정상   NaN     NaN     NaN    NaN
# 3        엠스테이   통신판매업  20181108      NaN  영업/정상   NaN     NaN     NaN    NaN
# 4        모모농장   통신판매업  20181121      NaN  영업/정상   NaN     NaN     NaN    NaN
#
#    소재지면적                          지번주소                         도로명주소  도로명우편번호  \
# 0    NaN     제주특별자치도 제주시 용담삼동 ***번지 *호   제주특별자치도 제주시 용마로*길 ** (용담삼동)  63151.0
# 1    NaN                           NaN   제주특별자치도 제주시 구좌읍 덕천동길 **, B동  63356.0
# 2    NaN    제주특별자치도 제주시 도두이동 ****번지 *호  제주특별자치도 제주시 오일장중길 *** (도두이동)  63116.0
# ...

# %%
# 컬럼명 변경

part14.rename(columns = {'사업장명':'상호명', '업종구분대분류':'업종', '소재지 도로명 주소':'도로명주소'},inplace=True)
part14.head()
# Out:
#           상호명     업종     인허가일자  인허가취소일자  영업상태명  폐업일자  휴업시작일자  휴업종료일자  재개업일자  \
# 0       제주싱싱몰  통신판매업  20100706      NaN  영업/정상   NaN     NaN     NaN    NaN
# 1        필리스틴  통신판매업  20120709      NaN  영업/정상   NaN     NaN     NaN    NaN
# 2  주식회사 제주필투어  통신판매업  20181102      NaN  영업/정상   NaN     NaN     NaN    NaN
# 3        엠스테이  통신판매업  20181108      NaN  영업/정상   NaN     NaN     NaN    NaN
# 4        모모농장  통신판매업  20181121      NaN  영업/정상   NaN     NaN     NaN    NaN
#
#    소재지면적                          지번주소                         도로명주소  도로명우편번호  \
# 0    NaN     제주특별자치도 제주시 용담삼동 ***번지 *호   제주특별자치도 제주시 용마로*길 ** (용담삼동)  63151.0
# 1    NaN                           NaN   제주특별자치도 제주시 구좌읍 덕천동길 **, B동  63356.0
# 2    NaN    제주특별자치도 제주시 도두이동 ****번지 *호  제주특별자치도 제주시 오일장중길 *** (도두이동)  63116.0
# 3    NaN    제주특별자치도 제주시 구좌읍 하도리 ****번지   제주특별자치도 제주시 구좌읍 해맞이해안로 ****  63362.0
# 4    NaN  제주특별자치도 제주시 한경면 청수리 ***번지 *호       제주특별자치도 제주시 한경면 청수로 ***  63006.0
#
#                데이터갱신일자
# ...

# %%
# 컬럼 추가

part14['행정시'] = np.nan
part14['전화번호'] = np.nan
part14['위도'] = np.nan
part14['경도'] = np.nan

# %%
# 컬럼명 순서변경 및 삭제

part14 = part14[['상호명', '업종', '행정시', '도로명주소', '전화번호', '위도', '경도']]
print(part14.shape)
part14.head()
# Out:
# (14633, 7)
#           상호명     업종  행정시                         도로명주소  전화번호  위도  경도
# 0       제주싱싱몰  통신판매업  NaN   제주특별자치도 제주시 용마로*길 ** (용담삼동)   NaN NaN NaN
# 1        필리스틴  통신판매업  NaN   제주특별자치도 제주시 구좌읍 덕천동길 **, B동   NaN NaN NaN
# 2  주식회사 제주필투어  통신판매업  NaN  제주특별자치도 제주시 오일장중길 *** (도두이동)   NaN NaN NaN
# 3        엠스테이  통신판매업  NaN   제주특별자치도 제주시 구좌읍 해맞이해안로 ****   NaN NaN NaN
# 4        모모농장  통신판매업  NaN       제주특별자치도 제주시 한경면 청수로 ***   NaN NaN NaN

# %%
# 완전히 동일한 중복데이터 여부 확인

part14.duplicated().sum()
# Out:
# 203

# %%
# 완전히 동일한 중복데이터 여부 확인

part14.duplicated(['도로명주소']).sum()
# Out:
# 6226

# %%
part14.duplicated(['상호명']).sum()
# Out:
# 725

# %%
# 컬럼인 중복된 행 삭제

part14 = part14.drop_duplicates(['상호명', '도로명주소'])

# %%
print(part14.shape)
# Out:
# (14430, 7)

# %%
# csv 파일 저장

part14.to_csv('제주특별자치도_통신판매업현황_병합.csv', encoding='cp949')

# %% [markdown]
# # 제주특별자치도 방문판매업현황

# %%
# 제주특별자치도 방문판매업현황

print(part15.shape)
print(list(part15.columns))
part15.head()
# Out:
# (607, 14)
# ['사업장명', '업종구분대분류', '인허가일자', '인허가취소일자', '영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자', '재개업일자', '소재지면적', '지번주소', '도로명주소', '도로명우편번호', '데이터갱신일자']
#                           사업장명 업종구분대분류     인허가일자  인허가취소일자  영업상태명  폐업일자  \
# 0                제주마임 (일도중부지사)   방문판매업  20190121      NaN  영업/정상   NaN
# 1                    제주마임 삼화지사   방문판매업  20190215      NaN  영업/정상   NaN
# 2                    마임 노형서부지사   방문판매업  20190218      NaN  영업/정상   NaN
# 3                     구좌농업협동조합   방문판매업  20190417      NaN  영업/정상   NaN
# 4  주식회사 유니이앤티(UNI E&T Co.Ltd.)   방문판매업  20190402      NaN  영업/정상   NaN
#
#    휴업시작일자  휴업종료일자  재개업일자  소재지면적                                 지번주소  \
# 0     NaN     NaN    NaN    NaN  제주특별자치도 제주시 이도이동 ****번지 전원파크맨션 ***호
# 1     NaN     NaN    NaN    NaN  제주특별자치도 제주시 이도이동 ****번지 전원파크맨션 ***호
# 2     NaN     NaN    NaN    NaN     제주특별자치도 제주시 연동 ****번지 *호 수현빌딩 *층
# 3     NaN     NaN    NaN    NaN        제주특별자치도 제주시 구좌읍 세화리 ****번지 *호
# ...

# %%
# 컬럼명 변경

part15.rename(columns = {'사업장명':'상호명', '업종구분대분류':'업종'},inplace=True)
part15.head()
# Out:
#                            상호명     업종     인허가일자  인허가취소일자  영업상태명  폐업일자  휴업시작일자  \
# 0                제주마임 (일도중부지사)  방문판매업  20190121      NaN  영업/정상   NaN     NaN
# 1                    제주마임 삼화지사  방문판매업  20190215      NaN  영업/정상   NaN     NaN
# 2                    마임 노형서부지사  방문판매업  20190218      NaN  영업/정상   NaN     NaN
# 3                     구좌농업협동조합  방문판매업  20190417      NaN  영업/정상   NaN     NaN
# 4  주식회사 유니이앤티(UNI E&T Co.Ltd.)  방문판매업  20190402      NaN  영업/정상   NaN     NaN
#
#    휴업종료일자  재개업일자  소재지면적                                 지번주소  \
# 0     NaN    NaN    NaN  제주특별자치도 제주시 이도이동 ****번지 전원파크맨션 ***호
# 1     NaN    NaN    NaN  제주특별자치도 제주시 이도이동 ****번지 전원파크맨션 ***호
# 2     NaN    NaN    NaN     제주특별자치도 제주시 연동 ****번지 *호 수현빌딩 *층
# 3     NaN    NaN    NaN        제주특별자치도 제주시 구좌읍 세화리 ****번지 *호
# 4     NaN    NaN    NaN  제주특별자치도 제주시 이도일동 ****번지 *호 올래케이티 *층
#
#                                            도로명주소  도로명우편번호              데이터갱신일자
# ...

# %%
# 컬럼 추가

part15['행정시'] = np.nan
part15['전화번호'] = np.nan
part15['위도'] = np.nan
part15['경도'] = np.nan

# %%
# 컬럼명 순서변경 및 삭제

part15 = part15[['상호명', '업종', '영업상태명', '행정시', '도로명주소', '전화번호', '위도', '경도']]
print(part15.shape)
part15.head()
# Out:
# (607, 8)
#                            상호명     업종  영업상태명  행정시  \
# 0                제주마임 (일도중부지사)  방문판매업  영업/정상  NaN
# 1                    제주마임 삼화지사  방문판매업  영업/정상  NaN
# 2                    마임 노형서부지사  방문판매업  영업/정상  NaN
# 3                     구좌농업협동조합  방문판매업  영업/정상  NaN
# 4  주식회사 유니이앤티(UNI E&T Co.Ltd.)  방문판매업  영업/정상  NaN
#
#                                            도로명주소  전화번호  위도  경도
# 0     제주특별자치도 제주시 신성로**길 **, ***호 (이도이동, 전원파크맨션)   NaN NaN NaN
# 1  제주특별자치도 제주시 신성로**길 **, *층 ***호 (이도이동, 전원파크맨션)   NaN NaN NaN
# 2            제주특별자치도 제주시 일주서로 ****, 수현빌딩 *층 (연동)   NaN NaN NaN
# 3                         제주특별자치도 제주시 구좌읍 구좌로 **   NaN NaN NaN
# 4           제주특별자치도 제주시 전농로 ***, 올래케이티 *층 (이도일동)   NaN NaN NaN

# %%
# 컬럼별로 중복데이터 여부 확인

part15['영업상태명'].value_counts()
# Out:
# 폐업                276
# 취소/말소/만료/정지/중지    177
# 영업/정상             149
# 휴업                  5
# Name: 영업상태명, dtype: int64

# %%
part15 = part15[part15['영업상태명'].str.contains('영업/정상')]
print(part15.shape)
part15.head()
# Out:
# (149, 8)
#                            상호명     업종  영업상태명  행정시  \
# 0                제주마임 (일도중부지사)  방문판매업  영업/정상  NaN
# 1                    제주마임 삼화지사  방문판매업  영업/정상  NaN
# 2                    마임 노형서부지사  방문판매업  영업/정상  NaN
# 3                     구좌농업협동조합  방문판매업  영업/정상  NaN
# 4  주식회사 유니이앤티(UNI E&T Co.Ltd.)  방문판매업  영업/정상  NaN
#
#                                            도로명주소  전화번호  위도  경도
# 0     제주특별자치도 제주시 신성로**길 **, ***호 (이도이동, 전원파크맨션)   NaN NaN NaN
# 1  제주특별자치도 제주시 신성로**길 **, *층 ***호 (이도이동, 전원파크맨션)   NaN NaN NaN
# 2            제주특별자치도 제주시 일주서로 ****, 수현빌딩 *층 (연동)   NaN NaN NaN
# 3                         제주특별자치도 제주시 구좌읍 구좌로 **   NaN NaN NaN
# 4           제주특별자치도 제주시 전농로 ***, 올래케이티 *층 (이도일동)   NaN NaN NaN

# %%
# 컬럼명 순서변경 및 삭제

part15 = part15[['상호명', '업종', '행정시', '도로명주소', '전화번호', '위도', '경도']]
print(part15.shape)
part15.head()
# Out:
# (149, 7)
#                            상호명     업종  행정시  \
# 0                제주마임 (일도중부지사)  방문판매업  NaN
# 1                    제주마임 삼화지사  방문판매업  NaN
# 2                    마임 노형서부지사  방문판매업  NaN
# 3                     구좌농업협동조합  방문판매업  NaN
# 4  주식회사 유니이앤티(UNI E&T Co.Ltd.)  방문판매업  NaN
#
#                                            도로명주소  전화번호  위도  경도
# 0     제주특별자치도 제주시 신성로**길 **, ***호 (이도이동, 전원파크맨션)   NaN NaN NaN
# 1  제주특별자치도 제주시 신성로**길 **, *층 ***호 (이도이동, 전원파크맨션)   NaN NaN NaN
# 2            제주특별자치도 제주시 일주서로 ****, 수현빌딩 *층 (연동)   NaN NaN NaN
# 3                         제주특별자치도 제주시 구좌읍 구좌로 **   NaN NaN NaN
# 4           제주특별자치도 제주시 전농로 ***, 올래케이티 *층 (이도일동)   NaN NaN NaN

# %%
# 완전히 동일한 중복데이터 여부 확인

part15.duplicated().sum()
# Out:
# 0

# %%
# csv 파일 저장

part15.to_csv('제주특별자치도_방문판매업현황_병합.csv', encoding='cp949')

# %% [markdown]
# # 제주특별자치도 관광사업체현황

# %%
# 제주특별자치도 관광사업체현황

print(part16.shape)
print(list(part16.columns))
part16.head()
# Out:
# (989, 16)
# ['사업장명', '업종구분대분류', '업종구분소분류', '인허가일자', '인허가취소일자', '영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자', '재개업일자', '소재지면적', '지번주소', '도로명주소', '도로명우편번호', '부대시설내역', '데이터갱신일자']
#                 사업장명 업종구분대분류   업종구분소분류     인허가일자  인허가취소일자  영업상태명  폐업일자  \
# 0  국제문화스포츠교육원 제주힐링캠프   관광사업자  관광객이용시설업  20121106      NaN  영업/정상   NaN
# 1               이레상사   관광사업자  관광객이용시설업  20121109      NaN  영업/정상   NaN
# 2        정관장제주조현 대리점   관광사업자  관광객이용시설업  20121123      NaN  영업/정상   NaN
# 3        (주)제주미자듀티프리   관광사업자  관광객이용시설업  20121220      NaN  영업/정상   NaN
# 4           유진글로벌(주)   관광사업자  관광객이용시설업  20121231      NaN  영업/정상   NaN
#
#    휴업시작일자  휴업종료일자  재개업일자   소재지면적                       지번주소  \
# 0     NaN     NaN    NaN    0.00   제주특별자치도 서귀포시 성산읍 신산리 ***
# 1     NaN     NaN    NaN  817.00       제주특별자치도 서귀포시 법환동 ***
# 2     NaN     NaN    NaN  475.31  제주특별자치도 제주시 이도이동 **** - *
# 3     NaN     NaN    NaN  292.72   제주특별자치도 제주시 오라이동 *** - *
# 4     NaN     NaN    NaN  328.07  제주특별자치도 제주시 오라삼동 **** - *
#
# ...

# %%
# 컬럼명 변경

part16.rename(columns = {'사업장명':'상호명', '업종구분소분류':'업종'},inplace=True)
part16.head()
# Out:
#                  상호명 업종구분대분류        업종     인허가일자  인허가취소일자  영업상태명  폐업일자  \
# 0  국제문화스포츠교육원 제주힐링캠프   관광사업자  관광객이용시설업  20121106      NaN  영업/정상   NaN
# 1               이레상사   관광사업자  관광객이용시설업  20121109      NaN  영업/정상   NaN
# 2        정관장제주조현 대리점   관광사업자  관광객이용시설업  20121123      NaN  영업/정상   NaN
# 3        (주)제주미자듀티프리   관광사업자  관광객이용시설업  20121220      NaN  영업/정상   NaN
# 4           유진글로벌(주)   관광사업자  관광객이용시설업  20121231      NaN  영업/정상   NaN
#
#    휴업시작일자  휴업종료일자  재개업일자   소재지면적                       지번주소  \
# 0     NaN     NaN    NaN    0.00   제주특별자치도 서귀포시 성산읍 신산리 ***
# 1     NaN     NaN    NaN  817.00       제주특별자치도 서귀포시 법환동 ***
# 2     NaN     NaN    NaN  475.31  제주특별자치도 제주시 이도이동 **** - *
# 3     NaN     NaN    NaN  292.72   제주특별자치도 제주시 오라이동 *** - *
# 4     NaN     NaN    NaN  328.07  제주특별자치도 제주시 오라삼동 **** - *
#
#                           도로명주소  도로명우편번호                        부대시설내역  \
# 0  제주특별자치도 서귀포시 성산읍 독자봉로**번길 **      NaN  차량10면, 공동취사장, 공중화장실, 공중샤워장 등
# ...

# %%
# 컬럼 추가

part16['행정시'] = np.nan
part16['전화번호'] = np.nan
part16['위도'] = np.nan
part16['경도'] = np.nan

# %%
# 컬럼명 순서변경 및 삭제

part16 = part16[['상호명', '업종', '영업상태명', '행정시', '도로명주소', '전화번호', '위도', '경도']]
print(part16.shape)
part16.head()
# Out:
# (989, 8)
#                  상호명        업종  영업상태명  행정시                         도로명주소  \
# 0  국제문화스포츠교육원 제주힐링캠프  관광객이용시설업  영업/정상  NaN  제주특별자치도 서귀포시 성산읍 독자봉로**번길 **
# 1               이레상사  관광객이용시설업  영업/정상  NaN    제주특별자치도 서귀포시 월드컵로 ** (법환동)
# 2        정관장제주조현 대리점  관광객이용시설업  영업/정상  NaN    제주특별자치도 제주시 도남로 *** (이도이동)
# 3        (주)제주미자듀티프리  관광객이용시설업  영업/정상  NaN    제주특별자치도 제주시 아연로 *** (오라이동)
# 4           유진글로벌(주)  관광객이용시설업  영업/정상  NaN    제주특별자치도 제주시 연삼로 *** (오라삼동)
#
#    전화번호  위도  경도
# 0   NaN NaN NaN
# 1   NaN NaN NaN
# 2   NaN NaN NaN
# 3   NaN NaN NaN
# 4   NaN NaN NaN

# %%
# 컬럼별로 중복데이터 여부 확인

part16['영업상태명'].value_counts()
# Out:
# 영업/정상             863
# 폐업                 96
# 취소/말소/만료/정지/중지     17
# 휴업                 13
# Name: 영업상태명, dtype: int64

# %%
part16 = part16[part16['영업상태명'].str.contains('영업/정상')]
print(part16.shape)
part16.head()
# Out:
# (863, 8)
#                  상호명        업종  영업상태명  행정시                         도로명주소  \
# 0  국제문화스포츠교육원 제주힐링캠프  관광객이용시설업  영업/정상  NaN  제주특별자치도 서귀포시 성산읍 독자봉로**번길 **
# 1               이레상사  관광객이용시설업  영업/정상  NaN    제주특별자치도 서귀포시 월드컵로 ** (법환동)
# 2        정관장제주조현 대리점  관광객이용시설업  영업/정상  NaN    제주특별자치도 제주시 도남로 *** (이도이동)
# 3        (주)제주미자듀티프리  관광객이용시설업  영업/정상  NaN    제주특별자치도 제주시 아연로 *** (오라이동)
# 4           유진글로벌(주)  관광객이용시설업  영업/정상  NaN    제주특별자치도 제주시 연삼로 *** (오라삼동)
#
#    전화번호  위도  경도
# 0   NaN NaN NaN
# 1   NaN NaN NaN
# 2   NaN NaN NaN
# 3   NaN NaN NaN
# 4   NaN NaN NaN

# %%
# 컬럼명 순서변경 및 삭제

part16 = part16[['상호명', '업종', '행정시', '도로명주소', '전화번호', '위도', '경도']]
print(part16.shape)
part16.head()
# Out:
# (863, 7)
#                  상호명        업종  행정시                         도로명주소  전화번호  위도  \
# 0  국제문화스포츠교육원 제주힐링캠프  관광객이용시설업  NaN  제주특별자치도 서귀포시 성산읍 독자봉로**번길 **   NaN NaN
# 1               이레상사  관광객이용시설업  NaN    제주특별자치도 서귀포시 월드컵로 ** (법환동)   NaN NaN
# 2        정관장제주조현 대리점  관광객이용시설업  NaN    제주특별자치도 제주시 도남로 *** (이도이동)   NaN NaN
# 3        (주)제주미자듀티프리  관광객이용시설업  NaN    제주특별자치도 제주시 아연로 *** (오라이동)   NaN NaN
# 4           유진글로벌(주)  관광객이용시설업  NaN    제주특별자치도 제주시 연삼로 *** (오라삼동)   NaN NaN
#
#    경도
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN

# %%
# 완전히 동일한 중복데이터 여부 확인

part16.duplicated().sum()
# Out:
# 8

# %%
# 완전히 동일한 중복데이터 여부 확인

part16.duplicated(['도로명주소']).sum()
# Out:
# 289

# %%
# 완전히 동일한 중복데이터 여부 확인

part16.duplicated(['상호명']).sum()
# Out:
# 29

# %%
# 완전히 동일한 중복데이터 여부 확인

part16.duplicated(['상호명', '업종', '도로명주소']).sum()
# Out:
# 8

# %%
# 컬럼인 중복된 행 삭제

part16 = part16.drop_duplicates(['상호명', '업종', '도로명주소'])

# %%
print(part16.shape)
# Out:
# (855, 7)

# %%
# csv 파일 저장

part16.to_csv('제주특별자치도_관광사업체현황_병합.csv', encoding='cp949')

# %% [markdown]
# # 제주특별자치도 여행업현황

# %%
# 제주특별자치도 관광사업체현황

print(part17.shape)
print(list(part17.columns))
part17.head()
# Out:
# (2519, 14)
# ['사업장명', '업종구분대분류', '인허가일자', '인허가취소일자', '영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자', '재개업일자', '소재지면적', '지번주소', '도로명주소', '도로명우편번호', '데이터갱신일자']
#       사업장명 업종구분대분류     인허가일자     인허가취소일자           영업상태명  폐업일자  휴업시작일자  \
# 0    우리여행사   국내여행업  20071211  20110805.0  취소/말소/만료/정지/중지   NaN     NaN
# 1   오케이 투어   국내여행업  20080814  20130321.0  취소/말소/만료/정지/중지   NaN     NaN
# 2   제주드림투어   국내여행업  20090911         NaN  취소/말소/만료/정지/중지   NaN     NaN
# 3  제주힐링(주)   국내여행업  20140630         NaN  취소/말소/만료/정지/중지   NaN     NaN
# 4  (주)제이폰스   국내여행업  20131029         NaN  취소/말소/만료/정지/중지   NaN     NaN
#
#    휴업종료일자  재개업일자  소재지면적                         지번주소  \
# 0     NaN    NaN    NaN    제주특별자치도 서귀포시 서귀동 314-11번지
# 1     NaN    NaN    NaN  제주특별자치도 서귀포시 안덕면 화순리 2020번지
# 2     NaN    NaN    NaN       제주특별자치도 서귀포시 서귀동 673번지
# 3     NaN    NaN    NaN    제주특별자치도 서귀포시 동홍동 1502-8번지
# 4     NaN    NaN    NaN       제주특별자치도 서귀포시 서귀동 673번지
#
# ...

# %%
# 컬럼명 변경

part17.rename(columns = {'사업장명':'상호명', '업종구분대분류':'업종'},inplace=True)
part17.head()
# Out:
#        상호명     업종     인허가일자     인허가취소일자           영업상태명  폐업일자  휴업시작일자  휴업종료일자  \
# 0    우리여행사  국내여행업  20071211  20110805.0  취소/말소/만료/정지/중지   NaN     NaN     NaN
# 1   오케이 투어  국내여행업  20080814  20130321.0  취소/말소/만료/정지/중지   NaN     NaN     NaN
# 2   제주드림투어  국내여행업  20090911         NaN  취소/말소/만료/정지/중지   NaN     NaN     NaN
# 3  제주힐링(주)  국내여행업  20140630         NaN  취소/말소/만료/정지/중지   NaN     NaN     NaN
# 4  (주)제이폰스  국내여행업  20131029         NaN  취소/말소/만료/정지/중지   NaN     NaN     NaN
#
#    재개업일자  소재지면적                         지번주소  \
# 0    NaN    NaN    제주특별자치도 서귀포시 서귀동 314-11번지
# 1    NaN    NaN  제주특별자치도 서귀포시 안덕면 화순리 2020번지
# 2    NaN    NaN       제주특별자치도 서귀포시 서귀동 673번지
# 3    NaN    NaN    제주특별자치도 서귀포시 동홍동 1502-8번지
# 4    NaN    NaN       제주특별자치도 서귀포시 서귀동 673번지
#
#                                         도로명주소  도로명우편번호              데이터갱신일자
# 0              제주특별자치도 서귀포시 태평로353번길 7  (서귀동)      NaN  2018-08-31 23:59:59
# ...

# %%
# 컬럼 추가

part17['행정시'] = np.nan
part17['전화번호'] = np.nan
part17['위도'] = np.nan
part17['경도'] = np.nan

# %%
# 컬럼명 순서변경 및 삭제

part17 = part17[['상호명', '업종', '영업상태명', '행정시', '도로명주소', '전화번호', '위도', '경도']]
print(part17.shape)
part17.head()
# Out:
# (2519, 8)
#        상호명     업종           영업상태명  행정시  \
# 0    우리여행사  국내여행업  취소/말소/만료/정지/중지  NaN
# 1   오케이 투어  국내여행업  취소/말소/만료/정지/중지  NaN
# 2   제주드림투어  국내여행업  취소/말소/만료/정지/중지  NaN
# 3  제주힐링(주)  국내여행업  취소/말소/만료/정지/중지  NaN
# 4  (주)제이폰스  국내여행업  취소/말소/만료/정지/중지  NaN
#
#                                         도로명주소  전화번호  위도  경도
# 0              제주특별자치도 서귀포시 태평로353번길 7  (서귀동)   NaN NaN NaN
# 1                   제주특별자치도 서귀포시 안덕면 산방로 75-9   NaN NaN NaN
# 2                  제주특별자치도 서귀포시 칠십리로 61 (서귀동)   NaN NaN NaN
# 3  제주특별자치도 서귀포시 일주동로 8656, 2층 (동홍동, JDC공인중개사)   NaN NaN NaN
# 4              제주특별자치도 서귀포시 칠십리로 61, 3층 (서귀동)   NaN NaN NaN

# %%
# 컬럼별로 중복데이터 여부 확인

part17['영업상태명'].value_counts()
# Out:
# 폐업                1164
# 영업/정상             1065
# 취소/말소/만료/정지/중지     271
# 휴업                  19
# Name: 영업상태명, dtype: int64

# %%
part17 = part17[part17['영업상태명'].str.contains('영업/정상')]
print(part17.shape)
part17.head()
# Out:
# (1065, 8)
#             상호명     업종  영업상태명  행정시  \
# 1119  (주)제주생태관광  국내여행업  영업/정상  NaN
# 1120    (주)세븐힐스  국내여행업  영업/정상  NaN
# 1121      홀로 제주  국내여행업  영업/정상  NaN
# 1122    웨이랩주식회사  국내여행업  영업/정상  NaN
# 1123     (주)휴엔락  국내여행업  영업/정상  NaN
#
#                                            도로명주소  전화번호  위도  경도
# 1119        제주특별자치도 서귀포시 남원읍 서성로810번길 7, 사려니주식회사   NaN NaN NaN
# 1120  제주특별자치도 서귀포시 중정로 123, 선경오피스텔 6층 606호 (서귀동)   NaN NaN NaN
# 1121                제주특별자치도 서귀포시 중앙로 100-3 (동홍동)   NaN NaN NaN
# 1122                 제주특별자치도 서귀포시 이어도로 777 (강정동)   NaN NaN NaN
# 1123              제주특별자치도 서귀포시 중앙로 111, 2층 (서홍동)   NaN NaN NaN

# %%
# 컬럼명 순서변경 및 삭제

part17 = part17[['상호명', '업종', '행정시', '도로명주소', '전화번호', '위도', '경도']]
print(part17.shape)
part17.head()
# Out:
# (1065, 7)
#             상호명     업종  행정시                                       도로명주소  전화번호  \
# 1119  (주)제주생태관광  국내여행업  NaN        제주특별자치도 서귀포시 남원읍 서성로810번길 7, 사려니주식회사   NaN
# 1120    (주)세븐힐스  국내여행업  NaN  제주특별자치도 서귀포시 중정로 123, 선경오피스텔 6층 606호 (서귀동)   NaN
# 1121      홀로 제주  국내여행업  NaN                제주특별자치도 서귀포시 중앙로 100-3 (동홍동)   NaN
# 1122    웨이랩주식회사  국내여행업  NaN                 제주특별자치도 서귀포시 이어도로 777 (강정동)   NaN
# 1123     (주)휴엔락  국내여행업  NaN              제주특별자치도 서귀포시 중앙로 111, 2층 (서홍동)   NaN
#
#       위도  경도
# 1119 NaN NaN
# 1120 NaN NaN
# 1121 NaN NaN
# 1122 NaN NaN
# 1123 NaN NaN

# %%
# 완전히 동일한 중복데이터 여부 확인

part17.duplicated().sum()
# Out:
# 0

# %%
# csv 파일 저장

part17.to_csv('제주특별자치도_여행업현황_병합.csv', encoding='cp949')

# %% [markdown]
# # 전체 병합

# %%
real_final_part = pd.concat([new_part, new_part2, part5, part6, new_part3 , 
                             new_part4, part13, part14, part15, part16, part17])

print(real_final_part.shape)
print(list(real_final_part.columns))
real_final_part.head()
# Out:
# (17362, 7)
# ['업종', '상호명', '행정시', '도로명주소', '전화번호', '위도', '경도']
#            업종           상호명  행정시                   도로명주소          전화번호  위도  경도
# 0  운송장비용 주유소업    (주)무수천주유소   NaN     제주특별자치도 제주시 노형로 45   064-748-1515 NaN NaN
# 1  운송장비용 주유소업  ㈜새신테크 이호주유소   NaN  제주특별자치도 제주시 일주서로 7629   064-747-0033 NaN NaN
# 2  운송장비용 주유소업     (주)회천주유소   NaN    제주특별자치도 제주시 번영로 937   064-721-9222 NaN NaN
# 3  운송장비용 주유소업       거북이주유소   NaN     제주특별자치도 제주시 서광로 58   064-743-4777 NaN NaN
# 4  운송장비용 주유소업        고산주유소   NaN  제주특별자치도 제주시 한경면 고산로 5   064-772-2626 NaN NaN

# %%
# 완전히 동일한 중복데이터 여부 확인

real_final_part.duplicated().sum()
# Out:
# 2

# %%
# 컬럼인 중복된 행 삭제

real_final_part = real_final_part.drop_duplicates()

# %%
print(real_final_part.shape)
# Out:
# (17360, 7)

# %%
# 완전히 동일한 중복데이터 여부 확인

real_final_part.duplicated(['상호명', '도로명주소']).sum()
# Out:
# 139

# %%
# 컬럼인 중복된 행 삭제

real_final_part = real_final_part.drop_duplicates(['상호명', '도로명주소'])

# %%
print(real_final_part.shape)
# Out:
# (17221, 7)

# %%
# csv 파일 저장

real_final_part.to_csv('제주특별자치도_업체_병합.csv', encoding='cp949')
