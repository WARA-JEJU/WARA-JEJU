# %%
# google drive 마운트
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

part = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/지리/제주특별자치도_제주도장소(POI)데이터_20151231.csv', encoding='cp949')

part1 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/제주특별자치도 제주시_주유소현황_20201230.csv', encoding='cp949')
part2 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/제주특별자치도 서귀포시_주유소현황_20210222.csv', encoding='cp949')

part3 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/제주특별자치도 제주시_노래연습장현황_20210813.csv', encoding='cp949')
part4 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/제주특별자치도 서귀포시_노래연습장현황_20210928.csv', encoding='cp949')

part5 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/제주특별자치도 제주시_승마장현황_20210201.csv', encoding='cp949')

part6 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/제주특별자치도 서귀포시_게임업현황_20210929.csv', encoding='cp949')

part7 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/제주특별자치도 제주시_영화상영관현황_20210820.csv', encoding='cp949')
part8 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/업체/제주특별자치도 서귀포시_영화상영관현황_20211001.csv', encoding='cp949')

# %% [markdown]
# # 제주도장소(POI)

# %%
# 제주특별자치도_제주도장소(POI)데이터

print(part.shape)
print(list(part.columns))
part.head()
# Out:
# (74439, 7)
# ['장소 POI에 대한 ID 구분 번호 체계 ', '위치좌표 X축값 ', '위치좌표 Y축값 ', '구분', '장소명', '소재지', '데이터기준일자']
#    장소 POI에 대한 ID 구분 번호 체계    위치좌표 X축값   위치좌표 Y축값     구분   장소명  \
# 0                        3  126.568803  33.236546  교통시설  동방파제
# 1                        4  126.562554  33.235071  지명관련    새섬
# 2                        5  126.599675  33.230314  지명관련    섶섬
# 3                        6  126.565891  33.226031  지명관련    문섬
# 4                        7  126.516395  33.218414  지명관련    범섬
#
#                       소재지     데이터기준일자
# 0  제주특별자치도 서귀포시 서귀동 758-2  2015-12-31
# 1  제주특별자치도 서귀포시 서귀동 산 3-3  2015-12-31
# 2    제주특별자치도 서귀포시 보목동 산 1  2015-12-31
# 3    제주특별자치도 서귀포시 서귀동 산 4  2015-12-31
# 4    제주특별자치도 서귀포시 법환동 산 2  2015-12-31

# %%
# 컬럼명 변경

part.rename(columns = {'위치좌표 X축값 ':'경도', '위치좌표 Y축값 ':'위도', 
                        '소재지':'도로명주소'},inplace=True)
part.head()
# Out:
#    장소 POI에 대한 ID 구분 번호 체계           경도         위도    구분   장소명  \
# 0                        3  126.568803  33.236546  교통시설  동방파제
# 1                        4  126.562554  33.235071  지명관련    새섬
# 2                        5  126.599675  33.230314  지명관련    섶섬
# 3                        6  126.565891  33.226031  지명관련    문섬
# 4                        7  126.516395  33.218414  지명관련    범섬
#
#                     도로명주소     데이터기준일자
# 0  제주특별자치도 서귀포시 서귀동 758-2  2015-12-31
# 1  제주특별자치도 서귀포시 서귀동 산 3-3  2015-12-31
# 2    제주특별자치도 서귀포시 보목동 산 1  2015-12-31
# 3    제주특별자치도 서귀포시 서귀동 산 4  2015-12-31
# 4    제주특별자치도 서귀포시 법환동 산 2  2015-12-31

# %%
# 컬럼명 순서변경 및 '데이터기준일자' 컬럼 삭제

part= part[['장소명', '구분', '도로명주소', '위도', '경도']]
part.head()
# Out:
#     장소명    구분                   도로명주소         위도          경도
# 0  동방파제  교통시설  제주특별자치도 서귀포시 서귀동 758-2  33.236546  126.568803
# 1    새섬  지명관련  제주특별자치도 서귀포시 서귀동 산 3-3  33.235071  126.562554
# 2    섶섬  지명관련    제주특별자치도 서귀포시 보목동 산 1  33.230314  126.599675
# 3    문섬  지명관련    제주특별자치도 서귀포시 서귀동 산 4  33.226031  126.565891
# 4    범섬  지명관련    제주특별자치도 서귀포시 법환동 산 2  33.218414  126.516395

# %% [markdown]
# # 제주특별자치도 주유소현황

# %%
# 제주특별자치도 제주시_주유소현황

print(part1.shape)
print(list(part1.columns))
part1.head()
# Out:
# (130, 4)
# ['상호', '주소', '연락처', '데이터기준일자']
#              상호                      주소           연락처     데이터기준일자
# 0    (주)무수천주유소      제주특별자치도 제주시 노형로 45   064-748-1515  2020-12-30
# 1  ㈜새신테크 이호주유소   제주특별자치도 제주시 일주서로 7629   064-747-0033  2020-12-30
# 2     (주)회천주유소     제주특별자치도 제주시 번영로 937   064-721-9222  2020-12-30
# 3       거북이주유소      제주특별자치도 제주시 서광로 58   064-743-4777  2020-12-30
# 4        고산주유소   제주특별자치도 제주시 한경면 고산로 5   064-772-2626  2020-12-30

# %%
# 누락 데이터 확인

part1.count()
# Out:
# 상호         130
# 주소         130
# 연락처        130
# 데이터기준일자    130
# dtype: int64

# %%
# 완전히 동일한 중복데이터 여부 확인

part1.duplicated().sum()
# Out:
# 0

# %%
# 제주특별자치도 서귀포시_주유소현황

print(part2.shape)
print(list(part2.columns))
part2.head()
# Out:
# (64, 6)
# ['상호', '연락처', '주소', '위도', '경도', '데이터기준일자']
#            상호           연락처                          주소         위도  \
# 0  성산일출봉농협주유소  064-780-3135  제주특별자치도 서귀포시 성산읍 일주동로 4521  33.425311
# 1     혁신도시주유소  064-739-5233      제주특별자치도 서귀포시 일주동로 9144  33.248262
# 2     안덕하나주유소  064-792-3088    제주특별자치도 서귀포시 안덕면 한창로 182  33.277632
# 3   대정농협무릉주유소  064-792-8201    제주특별자치도 서귀포시 대정읍 서삼중로 66  33.269115
# 4      선반내주유소  064-739-5008      제주특별자치도 서귀포시 일주동로 8780  33.253126
#
#            경도     데이터기준일자
# 0  126.907034  2021-02-22
# 1  126.516141  2021-02-22
# 2  126.359617  2021-02-22
# 3  126.204165  2021-02-22
# 4  126.550851  2021-02-22

# %%
# 누락 데이터 확인

part2.count()
# Out:
# 상호         64
# 연락처        64
# 주소         64
# 위도         64
# 경도         64
# 데이터기준일자    64
# dtype: int64

# %%
# 완전히 동일한 중복데이터 여부 확인

part2.duplicated().sum()
# Out:
# 0

# %%
new_part = pd.concat([part1, part2])

print(new_part.shape)
print(list(new_part.columns))
new_part.head()
# Out:
# (194, 6)
# ['상호', '주소', '연락처', '데이터기준일자', '위도', '경도']
#              상호                      주소           연락처     데이터기준일자  위도  경도
# 0    (주)무수천주유소      제주특별자치도 제주시 노형로 45   064-748-1515  2020-12-30 NaN NaN
# 1  ㈜새신테크 이호주유소   제주특별자치도 제주시 일주서로 7629   064-747-0033  2020-12-30 NaN NaN
# 2     (주)회천주유소     제주특별자치도 제주시 번영로 937   064-721-9222  2020-12-30 NaN NaN
# 3       거북이주유소      제주특별자치도 제주시 서광로 58   064-743-4777  2020-12-30 NaN NaN
# 4        고산주유소   제주특별자치도 제주시 한경면 고산로 5   064-772-2626  2020-12-30 NaN NaN

# %%
# 컬럼명 변경

new_part.rename(columns = {'상호':'상호명', '주소':'도로명주소', '연락처':'전화번호'},inplace=True)
new_part.head()
# Out:
#             상호명                   도로명주소          전화번호     데이터기준일자  위도  경도
# 0    (주)무수천주유소      제주특별자치도 제주시 노형로 45   064-748-1515  2020-12-30 NaN NaN
# 1  ㈜새신테크 이호주유소   제주특별자치도 제주시 일주서로 7629   064-747-0033  2020-12-30 NaN NaN
# 2     (주)회천주유소     제주특별자치도 제주시 번영로 937   064-721-9222  2020-12-30 NaN NaN
# 3       거북이주유소      제주특별자치도 제주시 서광로 58   064-743-4777  2020-12-30 NaN NaN
# 4        고산주유소   제주특별자치도 제주시 한경면 고산로 5   064-772-2626  2020-12-30 NaN NaN

# %%
# 컬럼 추가

new_part['행정시'] = np.nan

# %%
# '업종' 컬럼을 추가하고 '운송장비용 주유소업' 값을 추가

new_part.insert(0,'업종','운송장비용 주유소업')

# %%
# 컬럼명 순서변경

new_part= new_part[['업종', '상호명', '행정시', '도로명주소', '전화번호', '위도', '경도']]
new_part.head()
# Out:
#            업종           상호명  행정시                   도로명주소          전화번호  위도  경도
# 0  운송장비용 주유소업    (주)무수천주유소   NaN     제주특별자치도 제주시 노형로 45   064-748-1515 NaN NaN
# 1  운송장비용 주유소업  ㈜새신테크 이호주유소   NaN  제주특별자치도 제주시 일주서로 7629   064-747-0033 NaN NaN
# 2  운송장비용 주유소업     (주)회천주유소   NaN    제주특별자치도 제주시 번영로 937   064-721-9222 NaN NaN
# 3  운송장비용 주유소업       거북이주유소   NaN     제주특별자치도 제주시 서광로 58   064-743-4777 NaN NaN
# 4  운송장비용 주유소업        고산주유소   NaN  제주특별자치도 제주시 한경면 고산로 5   064-772-2626 NaN NaN

# %%
# 완전히 동일한 중복데이터 여부 확인

new_part.duplicated().sum()
# Out:
# 0

# %%
# 완전히 동일한 중복데이터 여부 확인

new_part.duplicated(['상호명', '도로명주소']).sum()
# Out:
# 0

# %%
# csv 파일 저장

new_part.to_csv('제주특별자치도_주유소현황_병합.csv', encoding='cp949')

# %% [markdown]
# # 제주특별자치도 노래연습장현황

# %%
# 제주특별자치도 제주시_노래연습장현황

print(part3.shape)
print(list(part3.columns))
part3.head()
# Out:
# (234, 6)
# ['업종', '등록일', '상호명', '우편번호', '소재지', '데이터기준일자']
#        업종         등록일       상호명   우편번호                    소재지     데이터기준일자
# 0  노래연습장업  1993-06-14        연인  63081    제주특별자치도 제주시 원노형로 25  2021-08-13
# 1  노래연습장업  1993-10-16  안성 노래연습장  63264   제주특별자치도 제주시 동문로10길 6  2021-08-13
# 2  노래연습장업  1993-10-26        현대  63125  제주특별자치도 제주시 삼무로11길 36  2021-08-13
# 3  노래연습장업  1993-12-21   에코노래연습장  63123  제주특별자치도 제주시 신대로16길 50  2021-08-13
# 4  노래연습장업  1993-12-28       들장미  63168  제주특별자치도 제주시 중앙로14길 28  2021-08-13

# %%
# 누락 데이터 확인

part3.count()
# Out:
# 업종         234
# 등록일        234
# 상호명        234
# 우편번호       234
# 소재지        234
# 데이터기준일자    234
# dtype: int64

# %%
# 완전히 동일한 중복데이터 여부 확인

part3.duplicated().sum()
# Out:
# 0

# %%
# 제주특별자치도 서귀포시_노래연습장현황

print(part4.shape)
print(list(part4.columns))
part4.head()
# Out:
# (85, 7)
# ['등록(신고)일자', '상호명', '소재지', '시설면적(제곱미터)', '위도', '경도', '데이터기준일자']
#      등록(신고)일자                        상호명                           소재지  \
# 0  2018-12-10               k팝스타 코인노래연습장   제주특별자치도 서귀포시 대정읍 글로벌에듀로 370
# 1  2020-11-10                     월드컵노래방      제주특별자치도 서귀포시 월드컵로45번길 40
# 2  2003-10-28                   팬클럽노래연습장  제주특별자치도 서귀포시 남원읍 태위로689번길 10
# 3  2020-07-29       아이존팝 코인노래연습장 액트몬 중문점         제주특별자치도 서귀포시 중문동 2565
# 4  2020-05-15  클럽런더리(CLUB LAUNDRY) 노래연습장  제주특별자치도 서귀포시 성산읍 고성리 297-1번지
#
#    시설면적(제곱미터)         위도          경도     데이터기준일자
# 0       56.30  33.280707  126.278261  2021-09-28
# 1      112.00  33.244614  126.511739  2021-09-28
# 2      168.72  33.280341  126.720042  2021-09-28
# 3      115.80  33.243883  126.421665  2021-09-28
# 4        5.44  33.449858  126.918167  2021-09-28

# %%
# 누락 데이터 확인

part4.count()
# Out:
# 등록(신고)일자      85
# 상호명           85
# 소재지           85
# 시설면적(제곱미터)    85
# 위도            85
# 경도            85
# 데이터기준일자       85
# dtype: int64

# %%
# 완전히 동일한 중복데이터 여부 확인

part4.duplicated().sum()
# Out:
# 0

# %%
new_part2 = pd.concat([part3, part4])

print(new_part2.shape)
print(list(new_part2.columns))
new_part2.head()
# Out:
# (319, 10)
# ['업종', '등록일', '상호명', '우편번호', '소재지', '데이터기준일자', '등록(신고)일자', '시설면적(제곱미터)', '위도', '경도']
#        업종         등록일       상호명     우편번호                    소재지     데이터기준일자  \
# 0  노래연습장업  1993-06-14        연인  63081.0    제주특별자치도 제주시 원노형로 25  2021-08-13
# 1  노래연습장업  1993-10-16  안성 노래연습장  63264.0   제주특별자치도 제주시 동문로10길 6  2021-08-13
# 2  노래연습장업  1993-10-26        현대  63125.0  제주특별자치도 제주시 삼무로11길 36  2021-08-13
# 3  노래연습장업  1993-12-21   에코노래연습장  63123.0  제주특별자치도 제주시 신대로16길 50  2021-08-13
# 4  노래연습장업  1993-12-28       들장미  63168.0  제주특별자치도 제주시 중앙로14길 28  2021-08-13
#
#   등록(신고)일자  시설면적(제곱미터)  위도  경도
# 0      NaN         NaN NaN NaN
# 1      NaN         NaN NaN NaN
# 2      NaN         NaN NaN NaN
# 3      NaN         NaN NaN NaN
# 4      NaN         NaN NaN NaN

# %%
# 컬럼명 변경

new_part2.rename(columns = {'소재지':'도로명주소'},inplace=True)

# %%
# 컬럼 추가

new_part2['행정시'] = np.nan
new_part2['전화번호'] = np.nan

# %%
# 컬럼명 순서변경

new_part2= new_part2[['업종', '상호명', '행정시', '도로명주소', '전화번호', '위도', '경도']]
new_part2.head()
# Out:
#        업종       상호명  행정시                  도로명주소  전화번호  위도  경도
# 0  노래연습장업        연인  NaN    제주특별자치도 제주시 원노형로 25   NaN NaN NaN
# 1  노래연습장업  안성 노래연습장  NaN   제주특별자치도 제주시 동문로10길 6   NaN NaN NaN
# 2  노래연습장업        현대  NaN  제주특별자치도 제주시 삼무로11길 36   NaN NaN NaN
# 3  노래연습장업   에코노래연습장  NaN  제주특별자치도 제주시 신대로16길 50   NaN NaN NaN
# 4  노래연습장업       들장미  NaN  제주특별자치도 제주시 중앙로14길 28   NaN NaN NaN

# %%
# 완전히 동일한 중복데이터 여부 확인

new_part2.duplicated().sum()
# Out:
# 0

# %%
# 완전히 동일한 중복데이터 여부 확인

new_part2.duplicated(['상호명', '도로명주소']).sum()
# Out:
# 0

# %%
# csv 파일 저장

new_part2.to_csv('제주특별자치도_노래연습장현황_병합.csv', encoding='cp949')

# %% [markdown]
# # 제주특별자치도 승마장현황

# %%
# 제주특별자치도 제주시_승마장현황

print(part5.shape)
print(list(part5.columns))
part5.head()
# Out:
# (35, 5)
# ['읍면동', '승마장명', '소재지', '영업구분', '데이터기준일자']
#    읍면동            승마장명                         소재지 영업구분     데이터기준일자
# 0  한림읍          라온더마파크     제주특별자치도 제주시 한림읍 월림7길155  영업중  2021-02-01
# 1  한림읍       힐링팜마사영농조합  제주특별자치도 제주시 한림읍 광산로 395-46  영업중  2021-02-01
# 2  한림읍      홀스홀릭트레이닝센터     제주특별자치도 제주시 한림읍 가린내길 99  영업중  2021-02-01
# 3  애월읍  제주특별자치도말산업협동조합   제주특별자치도 제주시 애월읍 어음13길 180  영업중  2021-02-01
# 4  애월읍          웅지승마센터      제주특별자치도 제주시 애월읍 산록서로81  영업중  2021-02-01

# %%
# 누락 데이터 확인

part5.count()
# Out:
# 읍면동        35
# 승마장명       35
# 소재지        35
# 영업구분       35
# 데이터기준일자    35
# dtype: int64

# %%
# 완전히 동일한 중복데이터 여부 확인

part3.duplicated().sum()
# Out:
# 0

# %%
# 컬럼명 변경

part5.rename(columns = {'승마장명':'상호명', '소재지':'도로명주소'},inplace=True)

# %%
# 컬럼 추가

part5['행정시'] = np.nan
part5['전화번호'] = np.nan
part5['위도'] = np.nan
part5['경도'] = np.nan

# %%
# '업종' 컬럼을 추가하고 '승마장업' 값을 추가

part5.insert(0,'업종','승마장업')

# %%
# 컬럼명 순서변경 및 컬럼 삭제

part5= part5[['업종', '상호명', '행정시', '도로명주소', '전화번호', '위도', '경도']]
print(part5.shape)
part5.head()
# Out:
# (35, 7)
#      업종             상호명  행정시                       도로명주소  전화번호  위도  경도
# 0  승마장업          라온더마파크  NaN     제주특별자치도 제주시 한림읍 월림7길155   NaN NaN NaN
# 1  승마장업       힐링팜마사영농조합  NaN  제주특별자치도 제주시 한림읍 광산로 395-46   NaN NaN NaN
# 2  승마장업      홀스홀릭트레이닝센터  NaN     제주특별자치도 제주시 한림읍 가린내길 99   NaN NaN NaN
# 3  승마장업  제주특별자치도말산업협동조합  NaN   제주특별자치도 제주시 애월읍 어음13길 180   NaN NaN NaN
# 4  승마장업          웅지승마센터  NaN      제주특별자치도 제주시 애월읍 산록서로81   NaN NaN NaN

# %%
# '제주특별자치도_제주도장소(POI)데이터' 에서 서귀포시 승마장 데이터 추출

h_part = part[part['장소명'].str.contains('승마')]
h_part
# Out:
#               장소명      구분                         도로명주소         위도          경도
# 250    트레블러스호텔승마장  레져/스포츠          제주특별자치도 서귀포시 대포동 1-1  33.286064  126.453287
# 632      조랑말타운승마장  레져/스포츠     제주특별자치도 서귀포시 표선면 성읍리 2597  33.407522  126.772856
# 746        어승생승마장  레져/스포츠          제주특별자치도 제주시 노형동 14-1  33.425674  126.490893
# 4371        서광승마장  레져/스포츠     제주특별자치도 서귀포시 안덕면 서광리 산 51  33.302510  126.290938
# 4540        초원승마장  레져/스포츠          제주특별자치도 서귀포시 상예동 150  33.275822  126.396929
# ...           ...     ...                           ...        ...         ...
# 63003    동부승마레저타운  레져/스포츠     제주특별자치도 서귀포시 표선면 성읍리 2873  33.409564  126.770382
# 65243     폴로승마리조트  레져/스포츠      제주특별자치도 제주시 구좌읍 행원리 3266  33.524176  126.780391
# 67111  라온더마파크승마클럽  레져/스포츠      제주특별자치도 제주시 한림읍 월림7길 155  33.355495  126.241804
# 67511   오케이승마장관리동    농공시설  제주특별자치도 서귀포시 표선면 번영로 2350-21  33.415246  126.760857
# 70013   동부승마카트ATV  레져/스포츠     제주특별자치도 서귀포시 표선면 번영로 2454  33.409380  126.770069
#
# [78 rows x 5 columns]

# %%
# 컬럼별로 중복데이터 여부 확인

h_part['구분'].value_counts()
# Out:
# 레져/스포츠        45
# 도로시설          16
# 교통시설          10
# 관광/숙박          3
# 농공시설           2
# 공원/산/동.식물원     1
# 쇼핑/편의          1
# Name: 구분, dtype: int64

# %%
h_part = h_part[h_part.구분 == '레져/스포츠']
h_part.head()
# Out:
#              장소명      구분                      도로명주소         위도          경도
# 250   트레블러스호텔승마장  레져/스포츠       제주특별자치도 서귀포시 대포동 1-1  33.286064  126.453287
# 632     조랑말타운승마장  레져/스포츠  제주특별자치도 서귀포시 표선면 성읍리 2597  33.407522  126.772856
# 746       어승생승마장  레져/스포츠       제주특별자치도 제주시 노형동 14-1  33.425674  126.490893
# 4371       서광승마장  레져/스포츠  제주특별자치도 서귀포시 안덕면 서광리 산 51  33.302510  126.290938
# 4540       초원승마장  레져/스포츠       제주특별자치도 서귀포시 상예동 150  33.275822  126.396929

# %%
h_part = h_part[h_part['도로명주소'].str.contains('서귀포시')]
h_part.head()
# Out:
#              장소명      구분                      도로명주소         위도          경도
# 250   트레블러스호텔승마장  레져/스포츠       제주특별자치도 서귀포시 대포동 1-1  33.286064  126.453287
# 632     조랑말타운승마장  레져/스포츠  제주특별자치도 서귀포시 표선면 성읍리 2597  33.407522  126.772856
# 4371       서광승마장  레져/스포츠  제주특별자치도 서귀포시 안덕면 서광리 산 51  33.302510  126.290938
# 4540       초원승마장  레져/스포츠       제주특별자치도 서귀포시 상예동 150  33.275822  126.396929
# 5708      이어도승마장  레져/스포츠  제주특별자치도 서귀포시 성산읍 수산리 2712  33.428980  126.858136

# %%
# 컬럼명 변경

h_part.rename(columns = {'장소명':'상호명'},inplace=True)
h_part.head()
# Out:
#              상호명      구분                      도로명주소         위도          경도
# 250   트레블러스호텔승마장  레져/스포츠       제주특별자치도 서귀포시 대포동 1-1  33.286064  126.453287
# 632     조랑말타운승마장  레져/스포츠  제주특별자치도 서귀포시 표선면 성읍리 2597  33.407522  126.772856
# 4371       서광승마장  레져/스포츠  제주특별자치도 서귀포시 안덕면 서광리 산 51  33.302510  126.290938
# 4540       초원승마장  레져/스포츠       제주특별자치도 서귀포시 상예동 150  33.275822  126.396929
# 5708      이어도승마장  레져/스포츠  제주특별자치도 서귀포시 성산읍 수산리 2712  33.428980  126.858136

# %%
# 컬럼 추가

h_part['전화번호'] = np.nan

# %%
# '업종' 컬럼을 추가하고 '승마장업' 값을 추가

h_part.insert(0,'업종','승마장업')
h_part.insert(1,'행정시','서귀포시')

# %%
# 컬럼명 순서변경 및 컬럼 삭제

h_part = h_part[['업종', '상호명', '행정시', '도로명주소', '전화번호', '위도', '경도']]
print(h_part.shape)
h_part.head()
# Out:
# (23, 7)
#         업종         상호명   행정시                      도로명주소  전화번호         위도  \
# 250   승마장업  트레블러스호텔승마장  서귀포시       제주특별자치도 서귀포시 대포동 1-1   NaN  33.286064
# 632   승마장업    조랑말타운승마장  서귀포시  제주특별자치도 서귀포시 표선면 성읍리 2597   NaN  33.407522
# 4371  승마장업       서광승마장  서귀포시  제주특별자치도 서귀포시 안덕면 서광리 산 51   NaN  33.302510
# 4540  승마장업       초원승마장  서귀포시       제주특별자치도 서귀포시 상예동 150   NaN  33.275822
# 5708  승마장업      이어도승마장  서귀포시  제주특별자치도 서귀포시 성산읍 수산리 2712   NaN  33.428980
#
#               경도
# 250   126.453287
# 632   126.772856
# 4371  126.290938
# 4540  126.396929
# 5708  126.858136

# %%
# 완전히 동일한 중복데이터 여부 확인

h_part.duplicated(['상호명', '도로명주소']).sum()
# Out:
# 0

# %%
part5 = pd.concat([part5, h_part])

print(part5.shape)
print(list(part5.columns))
part5.head()
# Out:
# (58, 7)
# ['업종', '상호명', '행정시', '도로명주소', '전화번호', '위도', '경도']
#      업종             상호명  행정시                       도로명주소  전화번호  위도  경도
# 0  승마장업          라온더마파크  NaN     제주특별자치도 제주시 한림읍 월림7길155   NaN NaN NaN
# 1  승마장업       힐링팜마사영농조합  NaN  제주특별자치도 제주시 한림읍 광산로 395-46   NaN NaN NaN
# 2  승마장업      홀스홀릭트레이닝센터  NaN     제주특별자치도 제주시 한림읍 가린내길 99   NaN NaN NaN
# 3  승마장업  제주특별자치도말산업협동조합  NaN   제주특별자치도 제주시 애월읍 어음13길 180   NaN NaN NaN
# 4  승마장업          웅지승마센터  NaN      제주특별자치도 제주시 애월읍 산록서로81   NaN NaN NaN

# %%
# 완전히 동일한 중복데이터 여부 확인

part5.duplicated(['상호명', '도로명주소']).sum()
# Out:
# 0

# %%
# csv 파일 저장

part5.to_csv('제주특별자치도_승마장현황_병합.csv', encoding='cp949')

# %% [markdown]
# # 제주특별자치도_게임업현황

# %%
# 제주특별자치도 서귀포시_게임업현황

print(part6.shape)
print(list(part6.columns))
part6.head()
# Out:
# (89, 7)
# ['상호', '소재지', '시설면적(㎡)', '업종명', '위도', '경도', '데이터기준일자']
#         상호                           소재지  시설면적(㎡)            업종명         위도  \
# 0      원PC     제주특별자치도 서귀포시 성산읍 고성오조로 16    20.91  인터넷컴퓨터게임시설제공업  33.445204
# 1  테스형PC랜드  제주특별자치도 서귀포시 표선면 표선중앙로80번길 1   122.91  인터넷컴퓨터게임시설제공업  33.326027
# 2   모나코 pc          제주특별자치도 서귀포시 말질로 158   115.70  인터넷컴퓨터게임시설제공업  33.237366
# 3     주공PC       제주특별자치도 서귀포시 중산간동로 8003    23.76  인터넷컴퓨터게임시설제공업  33.264361
# 4    땃따PC방         제주특별자치도 서귀포시 칠십리로 49     57.39  인터넷컴퓨터게임시설제공업  33.240542
#
#            경도     데이터기준일자
# 0  126.913869  2021-09-29
# 1  126.832442  2021-09-29
# 2  126.479739  2021-09-29
# 3  126.561739  2021-09-29
# 4  126.561903  2021-09-29

# %%
# 누락 데이터 확인

part6.count()
# Out:
# 상호         89
# 소재지        89
# 시설면적(㎡)    89
# 업종명        89
# 위도         89
# 경도         89
# 데이터기준일자    89
# dtype: int64

# %%
# 완전히 동일한 중복데이터 여부 확인

part6.duplicated().sum()
# Out:
# 1

# %%
# 중복 행 삭제

part6.drop_duplicates()
# Out:
#          상호                           소재지  시설면적(㎡)            업종명         위도  \
# 0       원PC     제주특별자치도 서귀포시 성산읍 고성오조로 16    20.91  인터넷컴퓨터게임시설제공업  33.445204
# 1   테스형PC랜드  제주특별자치도 서귀포시 표선면 표선중앙로80번길 1   122.91  인터넷컴퓨터게임시설제공업  33.326027
# 2    모나코 pc          제주특별자치도 서귀포시 말질로 158   115.70  인터넷컴퓨터게임시설제공업  33.237366
# 3      주공PC       제주특별자치도 서귀포시 중산간동로 8003    23.76  인터넷컴퓨터게임시설제공업  33.264361
# 4     땃따PC방         제주특별자치도 서귀포시 칠십리로 49     57.39  인터넷컴퓨터게임시설제공업  33.240542
# ..      ...                           ...      ...            ...        ...
# 84     볼트PC           제주특별자치도 서귀포시 대청로 33   307.31      복합유통게임제공업  33.252745
# 85   불새게임랜드           제주특별자치도 서귀포시 중앙로 57   150.05        일반게임제공업  33.249768
# 86    녹원게임장        제주특별자치도 서귀포시 중정로61번길 1   206.04        일반게임제공업  33.248036
# 87    시티게임장       제주특별자치도 서귀포시 중앙로48번길 32   179.45        일반게임제공업  33.249477
# 88   팡팡게임랜드      제주특별자치도 서귀포시 중정로91번길 13    242.00        일반게임제공업  33.249278
#
#             경도     데이터기준일자
# ...

# %%
# 컬럼명 변경

part6.rename(columns = {'상호':'상호명', '소재지':'도로명주소', '업종명':'업종'},inplace=True)

# %%
# 컬럼 추가

part6['행정시'] = np.nan
part6['전화번호'] = np.nan

# %%
# 컬럼명 순서변경 및 컬럼 삭제

part6 = part6[['업종', '상호명', '행정시', '도로명주소', '전화번호', '위도', '경도']]
print(part6.shape)
part6.head()
# Out:
# (89, 7)
#               업종      상호명  행정시                         도로명주소  전화번호         위도  \
# 0  인터넷컴퓨터게임시설제공업      원PC  NaN     제주특별자치도 서귀포시 성산읍 고성오조로 16   NaN  33.445204
# 1  인터넷컴퓨터게임시설제공업  테스형PC랜드  NaN  제주특별자치도 서귀포시 표선면 표선중앙로80번길 1   NaN  33.326027
# 2  인터넷컴퓨터게임시설제공업   모나코 pc  NaN          제주특별자치도 서귀포시 말질로 158   NaN  33.237366
# 3  인터넷컴퓨터게임시설제공업     주공PC  NaN       제주특별자치도 서귀포시 중산간동로 8003   NaN  33.264361
# 4  인터넷컴퓨터게임시설제공업    땃따PC방  NaN         제주특별자치도 서귀포시 칠십리로 49    NaN  33.240542
#
#            경도
# 0  126.913869
# 1  126.832442
# 2  126.479739
# 3  126.561739
# 4  126.561903
