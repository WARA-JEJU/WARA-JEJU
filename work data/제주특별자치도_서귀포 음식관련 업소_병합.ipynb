# %%
# google drive 마운트
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
  
part1 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/음식/제주특별자치도_서귀포시_휴게음식점현황_20210406.csv', encoding='cp949')
part2 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/음식/제주특별자치도_서귀포시_일반음식점현황_20210406.csv', encoding='cp949')
part3 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/음식/제주특별자치도_서귀포시_제과점현황_20210405.csv', encoding='cp949')
part4 = pd.read_csv('/content/drive/MyDrive/국민대학원/졸업프로젝트/데이터/1순위/음식/제주특별자치도 서귀포시_칠십리음식특화거리업소현황_20210930.csv', encoding='cp949')

# %%
# part1 = 제주특별자치도_서귀포시_휴게음식점현황

print(part1.shape)
print(list(part1.columns))
part1.head()
# Out:
# (1197, 4)
# ['업종명', '업소명', '소재지(도로명)', '소재지(지번)']
#      업종명    업소명                           소재지(도로명)  \
# 0  휴게음식점   중앙다방          제주특별자치도 서귀포시 대정읍 하모상가로 31
# 1  휴게음식점    돌다방          제주특별자치도 서귀포시 동문로 70 (서귀동)
# 2  휴게음식점   우성다방  제주특별자치도 서귀포시 중정로91번길 15, 2층 (서귀동)
# 3  휴게음식점   수궁다방          제주특별자치도 서귀포시 대정읍 하모항구로 78
# 4  휴게음식점  해당화다방      제주특별자치도 서귀포시 동문로 60, 2층 (서귀동)
#
#                         소재지(지번)
# 0   제주특별자치도 서귀포시 대정읍 하모리 930-5
# 1      제주특별자치도 서귀포시 서귀동 256-38
# 2      제주특별자치도 서귀포시 서귀동 272-18
# 3  제주특별자치도 서귀포시 대정읍 하모리 938-17
# 4      제주특별자치도 서귀포시 서귀동 256-25

# %%
# part2 = 제주특별자치도_서귀포시_일반음식점현황

print(part2.shape)
print(list(part2.columns))
part2.head()
# Out:
# (4630, 4)
# ['업종명', '업소명', '소재지(도로명)', '소재지(지번)']
#      업종명       업소명                        소재지(도로명)  \
# 0  일반음식점  주식회사부두식당       제주특별자치도 서귀포시 대정읍 하모항구로 62
# 1  일반음식점     동유암식당        제주특별자치도 서귀포시 성산읍 동류암로 44
# 2  일반음식점   사계우리음식점        제주특별자치도 서귀포시 안덕면 산방로 367
# 3  일반음식점      현대식당       제주특별자치도 서귀포시 성산읍 성산등용로 96
# 4  일반음식점       나루터  제주특별자치도 서귀포시 천제연로188번길 6 (중문동)
#
#                        소재지(지번)
# 0  제주특별자치도 서귀포시 대정읍 하모리 770-9
# 1  제주특별자치도 서귀포시 성산읍 고성리 315-3
# 2   제주특별자치도 서귀포시 안덕면 사계리 2672
# 3  제주특별자치도 서귀포시 성산읍 성산리 360-2
# 4     제주특별자치도 서귀포시 중문동 2120-8

# %% [markdown]
# # part1 = 제주특별자치도_서귀포시_휴게음식점현황

# %%
# '소재지(지번)' 컬럼 삭제

part1 = part1.drop(['소재지(지번)'], axis=1)
part1.head()
# Out:
#      업종명    업소명                           소재지(도로명)
# 0  휴게음식점   중앙다방          제주특별자치도 서귀포시 대정읍 하모상가로 31
# 1  휴게음식점    돌다방          제주특별자치도 서귀포시 동문로 70 (서귀동)
# 2  휴게음식점   우성다방  제주특별자치도 서귀포시 중정로91번길 15, 2층 (서귀동)
# 3  휴게음식점   수궁다방          제주특별자치도 서귀포시 대정읍 하모항구로 78
# 4  휴게음식점  해당화다방      제주특별자치도 서귀포시 동문로 60, 2층 (서귀동)

# %%
# '소재지(도로명)'을 '도로명주소'로 변경

part1.rename(columns = {'소재지(도로명)':'도로명주소'},inplace=True)
part1.head()
# Out:
#      업종명    업소명                              도로명주소
# 0  휴게음식점   중앙다방          제주특별자치도 서귀포시 대정읍 하모상가로 31
# 1  휴게음식점    돌다방          제주특별자치도 서귀포시 동문로 70 (서귀동)
# 2  휴게음식점   우성다방  제주특별자치도 서귀포시 중정로91번길 15, 2층 (서귀동)
# 3  휴게음식점   수궁다방          제주특별자치도 서귀포시 대정읍 하모항구로 78
# 4  휴게음식점  해당화다방      제주특별자치도 서귀포시 동문로 60, 2층 (서귀동)

# %%
# 누락 데이터 확인

part1.count()
# Out:
# 업종명      1197
# 업소명      1197
# 도로명주소    1197
# dtype: int64

# %%
# 누락 데이터 확인

part1.isnull().sum()
# Out:
# 업종명      0
# 업소명      0
# 도로명주소    0
# dtype: int64

# %%
# 컬럼별로 중복데이터 여부 확인

part1['업소명'].value_counts()
# Out:
# 베스킨라빈스          2
# 귀빈다방            2
# 중앙다방            1
# 왕대왓             1
# 알쉐돈             1
#                ..
# 캐롤              1
# 세븐일레븐서귀포신흥점     1
# 찜질방매점           1
# 에코소랑꼬라지오꿈앤카페    1
# 세븐일레븐표선점        1
# Name: 업소명, Length: 1195, dtype: int64

# %%
# 중복 발생

part1[part1.업소명 == '베스킨라빈스']
# Out:
#        업종명     업소명                           도로명주소
# 23   휴게음식점  베스킨라빈스       제주특별자치도 서귀포시 중정로 60 (서귀동)
# 158  휴게음식점  베스킨라빈스  제주특별자치도 서귀포시 일주동로 8674-1 (동홍동)

# %%
# 중복 발생

part1[part1.업소명 == '귀빈다방']
# Out:
#       업종명   업소명                     도로명주소
# 14  휴게음식점  귀빈다방  제주특별자치도 서귀포시 남원읍 태위로 689
# 35  휴게음식점  귀빈다방  제주특별자치도 서귀포시 정방로 6 (서귀동)

# %%
# 컬럼별로 중복데이터 여부 확인

part1['도로명주소'].value_counts()
# Out:
# <REPLACE>                               21
# 제주특별자치도 서귀포시 일주동로 9209 (법환동)             4
# 제주특별자치도 서귀포시 안덕면 사계남로216번길 24-9          3
# 제주특별자치도 서귀포시 안덕면 신화역사로304번길 38, 지하1층     3
# 제주특별자치도 서귀포시 중문관광로 224 (중문동)             3
#                                         ..
# 제주특별자치도 서귀포시 대청로 39, 2층 202호 (강정동)       1
# 제주특별자치도 서귀포시 남성중로 131 (서홍동)              1
# 제주특별자치도 서귀포시 대정읍 글로벌에듀로 382, 1층          1
# 제주특별자치도 서귀포시 중문로 29-1, 1층 (중문동)          1
# 제주특별자치도 서귀포시 표선면 표선동서로 192, 1층           1
# Name: 도로명주소, Length: 1138, dtype: int64

# %%
# 중복 발생

part1[part1.도로명주소 == '<REPLACE>']
# Out:
#         업종명           업소명      도로명주소
# 80    휴게음식점          하논바람  <REPLACE>
# 115   휴게음식점           영다방  <REPLACE>
# 146   휴게음식점           레이크  <REPLACE>
# 151   휴게음식점  자연과함께하는행복한쉼터  <REPLACE>
# 269   휴게음식점         카페 아라  <REPLACE>
# 313   휴게음식점         맛있는여행  <REPLACE>
# 541   휴게음식점    지에스25대정상모점  <REPLACE>
# 544   휴게음식점      (주)지포뮤지엄  <REPLACE>
# 643   휴게음식점          피치카토  <REPLACE>
# 664   휴게음식점         모노클제주  <REPLACE>
# 740   휴게음식점         어느멋진날  <REPLACE>
# 805   휴게음식점           왕대왓  <REPLACE>
# 1067  휴게음식점        하례로379  <REPLACE>
# 1079  휴게음식점         서성로포차  <REPLACE>
# 1090  휴게음식점         밭담샾카페  <REPLACE>
# 1098  휴게음식점    세븐일레븐서귀포본점  <REPLACE>
# 1108  휴게음식점        색달푸드트럭  <REPLACE>
# 1124  휴게음식점       진모살푸드트럭  <REPLACE>
# 1165  휴게음식점         케이원분식  <REPLACE>
# 1181  휴게음식점         솔오름쉼터  <REPLACE>
# 1190  휴게음식점           쌀소년  <REPLACE>

# %%
# '업소명' NaN값 개수 계산

part1['도로명주소'].isnull().sum().sum()
# Out:
# 0

# %%
# 중복 발생
# 한 도로명주소에 여러 업소가 있을 수 있다고 판단해서 중복 삭제 안함

part1[part1.도로명주소 == '제주특별자치도 서귀포시 일주동로 9209 (법환동)']
# Out:
#        업종명             업소명                         도로명주소
# 83   휴게음식점        이디야커피전문점  제주특별자치도 서귀포시 일주동로 9209 (법환동)
# 84   휴게음식점  (주)이마트서귀포점조리식품  제주특별자치도 서귀포시 일주동로 9209 (법환동)
# 85   휴게음식점   (주)이마트서귀포점회코너  제주특별자치도 서귀포시 일주동로 9209 (법환동)
# 105  휴게음식점         (주)보승식품  제주특별자치도 서귀포시 일주동로 9209 (법환동)

# %%
# 중복 발생
# 한 도로명주소에 여러 업소가 있을 수 있다고 판단해서 중복 삭제 안함

part1[part1.도로명주소 == '제주특별자치도 서귀포시 안덕면 사계남로216번길 24-9']
# Out:
#        업종명          업소명                            도로명주소
# 204  휴게음식점         효재마트  제주특별자치도 서귀포시 안덕면 사계남로216번길 24-9
# 305  휴게음식점  산방산캐릭터아이스크림  제주특별자치도 서귀포시 안덕면 사계남로216번길 24-9
# 330  휴게음식점    산방산용머리휴게소  제주특별자치도 서귀포시 안덕면 사계남로216번길 24-9

# %%
# 중복 발생
# 한 도로명주소에 여러 업소가 있을 수 있다고 판단해서 중복 삭제 안함

part1[part1.도로명주소 == '제주특별자치도 서귀포시 중문관광로 224 (중문동)']
# Out:
#        업종명          업소명                         도로명주소
# 122  휴게음식점  던킨도너츠제주컨벤션점  제주특별자치도 서귀포시 중문관광로 224 (중문동)
# 179  휴게음식점    세븐일레븐ICC점  제주특별자치도 서귀포시 중문관광로 224 (중문동)
# 334  휴게음식점      델리지아 미니  제주특별자치도 서귀포시 중문관광로 224 (중문동)

# %% [markdown]
# # part2 = 제주특별자치도_서귀포시_일반음식점현황

# %%
# part2 = 제주특별자치도_서귀포시_일반음식점현황

print(part2.shape)
print(list(part2.columns))
part2.head()
# Out:
# (4630, 4)
# ['업종명', '업소명', '소재지(도로명)', '소재지(지번)']
#      업종명       업소명                        소재지(도로명)  \
# 0  일반음식점  주식회사부두식당       제주특별자치도 서귀포시 대정읍 하모항구로 62
# 1  일반음식점     동유암식당        제주특별자치도 서귀포시 성산읍 동류암로 44
# 2  일반음식점   사계우리음식점        제주특별자치도 서귀포시 안덕면 산방로 367
# 3  일반음식점      현대식당       제주특별자치도 서귀포시 성산읍 성산등용로 96
# 4  일반음식점       나루터  제주특별자치도 서귀포시 천제연로188번길 6 (중문동)
#
#                        소재지(지번)
# 0  제주특별자치도 서귀포시 대정읍 하모리 770-9
# 1  제주특별자치도 서귀포시 성산읍 고성리 315-3
# 2   제주특별자치도 서귀포시 안덕면 사계리 2672
# 3  제주특별자치도 서귀포시 성산읍 성산리 360-2
# 4     제주특별자치도 서귀포시 중문동 2120-8

# %%
# '소재지(지번)' 컬럼 삭제

part2 = part2.drop(['소재지(지번)'], axis=1)
part2.head()
# Out:
#      업종명       업소명                        소재지(도로명)
# 0  일반음식점  주식회사부두식당       제주특별자치도 서귀포시 대정읍 하모항구로 62
# 1  일반음식점     동유암식당        제주특별자치도 서귀포시 성산읍 동류암로 44
# 2  일반음식점   사계우리음식점        제주특별자치도 서귀포시 안덕면 산방로 367
# 3  일반음식점      현대식당       제주특별자치도 서귀포시 성산읍 성산등용로 96
# 4  일반음식점       나루터  제주특별자치도 서귀포시 천제연로188번길 6 (중문동)

# %%
# '소재지(도로명)'을 '도로명주소'로 변경

part2.rename(columns = {'소재지(도로명)':'도로명주소'},inplace=True)
part2.head()
# Out:
#      업종명       업소명                           도로명주소
# 0  일반음식점  주식회사부두식당       제주특별자치도 서귀포시 대정읍 하모항구로 62
# 1  일반음식점     동유암식당        제주특별자치도 서귀포시 성산읍 동류암로 44
# 2  일반음식점   사계우리음식점        제주특별자치도 서귀포시 안덕면 산방로 367
# 3  일반음식점      현대식당       제주특별자치도 서귀포시 성산읍 성산등용로 96
# 4  일반음식점       나루터  제주특별자치도 서귀포시 천제연로188번길 6 (중문동)

# %%
# 누락 데이터 확인

part1.count()
# Out:
# 업종명      1197
# 업소명      1197
# 도로명주소    1197
# dtype: int64

# %%
# 누락 데이터 확인

part1.isnull().sum()
# Out:
# 업종명      0
# 업소명      0
# 도로명주소    0
# dtype: int64

# %%
# '업소명' NaN값 개수 계산

part1['업소명'].isnull().sum().sum()
# Out:
# 0

# %%
# '소재지' NaN값 개수 계산

part1['도로명주소'].isnull().sum().sum()
# Out:
# 0

# %%
# 컬럼별로 중복데이터 여부 확인

part2['업소명'].value_counts()
# Out:
# 우성식당          2
# 한라식당          2
# 충남식당          2
# 밝은방           1
# 하나식당          1
#              ..
# 난타5000모슬포점    1
# 늘푸른식당         1
# 제주섭지회관        1
# 해피포차          1
# 제주흑돈시백돈면      1
# Name: 업소명, Length: 4627, dtype: int64

# %%
# 중복 발생

part2[part2.업소명 == '우성식당']
# Out:
#        업종명   업소명                         도로명주소
# 313  일반음식점  우성식당  제주특별자치도 서귀포시 대정읍 영서중로19번길 14
# 815  일반음식점  우성식당   제주특별자치도 서귀포시 색달중앙로 77 (색달동)

# %%
# 중복 발생

part2[part2.업소명 == '한라식당']
# Out:
#        업종명   업소명                      도로명주소
# 43   일반음식점  한라식당  제주특별자치도 서귀포시 성산읍 성산중앙로 32
# 296  일반음식점  한라식당                        NaN

# %%
# 중복 발생

part2[part2.업소명 == '충남식당']
# Out:
#        업종명   업소명                        도로명주소
# 6    일반음식점  충남식당  제주특별자치도 서귀포시 성산읍 성산등용로 94-1
# 951  일반음식점  충남식당   제주특별자치도 서귀포시 솔동산로 26 (서귀동)

# %%
# 컬럼별로 중복데이터 여부 확인

part2['도로명주소'].value_counts()
# Out:
# 제주특별자치도 서귀포시 안덕면 신화역사로304번길 38, 지하1층    11
# 제주특별자치도 서귀포시 표선면 민속해안로 537              10
# 제주특별자치도 서귀포시 토평서로11번길 150 (동홍동)          8
# 제주특별자치도 서귀포시 중문관광로72번길 75 (색달동)          8
# 제주특별자치도 서귀포시 중문관광로72번길 35 (색달동)          6
#                                         ..
# 제주특별자치도 서귀포시 성산읍 고성오조로 98-3              1
# 제주특별자치도 서귀포시 태평로120번길 36 (호근동)           1
# 제주특별자치도 서귀포시 남원읍 일주동로 6863               1
# 제주특별자치도 서귀포시 중앙로54번길 35, 8호 (서귀동)        1
# 제주특별자치도 서귀포시 안덕면 중산간서로 1769, 제2동         1
# Name: 도로명주소, Length: 4125, dtype: int64

# %%
# 중복 발생
# 한 도로명주소에 여러 업소가 있을 수 있다고 판단해서 중복 삭제 안함

part2[part2.도로명주소 == '제주특별자치도 서귀포시 안덕면 신화역사로304번길 38, 지하1층']
# Out:
#         업종명                    업소명                                 도로명주소
# 3188  일반음식점  랜딩라운지(Landing Lounge)  제주특별자치도 서귀포시 안덕면 신화역사로304번길 38, 지하1층
# 3243  일반음식점              고래라면신화월드점  제주특별자치도 서귀포시 안덕면 신화역사로304번길 38, 지하1층
# 3244  일반음식점              자니로켓신화월드점  제주특별자치도 서귀포시 안덕면 신화역사로304번길 38, 지하1층
# 3245  일반음식점             윤경양식당신화월드점  제주특별자치도 서귀포시 안덕면 신화역사로304번길 38, 지하1층
# 3246  일반음식점                 화니소반제주  제주특별자치도 서귀포시 안덕면 신화역사로304번길 38, 지하1층
# 3247  일반음식점               데블스도어제주점  제주특별자치도 서귀포시 안덕면 신화역사로304번길 38, 지하1층
# 3293  일반음식점      르쉬느아 (Le Chinois)  제주특별자치도 서귀포시 안덕면 신화역사로304번길 38, 지하1층
# 3294  일반음식점         제주선 (Jejuseon)  제주특별자치도 서귀포시 안덕면 신화역사로304번길 38, 지하1층
# 3300  일반음식점           다만프레르제주신화월드점  제주특별자치도 서귀포시 안덕면 신화역사로304번길 38, 지하1층
# 3315  일반음식점         엠라운지(M Lounge)  제주특별자치도 서귀포시 안덕면 신화역사로304번길 38, 지하1층
# 3568  일반음식점          데판야(Teppanya)  제주특별자치도 서귀포시 안덕면 신화역사로304번길 38, 지하1층

# %%
# 중복 발생
# 한 도로명주소에 여러 업소가 있을 수 있다고 판단해서 중복 삭제 안함

part2[part2.도로명주소 == '제주특별자치도 서귀포시 표선면 민속해안로 537']
# Out:
#         업종명      업소명                       도로명주소
# 899   일반음식점      하노루  제주특별자치도 서귀포시 표선면 민속해안로 537
# 900   일반음식점       이디  제주특별자치도 서귀포시 표선면 민속해안로 537
# 901   일반음식점    테라스가든  제주특별자치도 서귀포시 표선면 민속해안로 537
# 914   일반음식점    그랜드볼륨  제주특별자치도 서귀포시 표선면 민속해안로 537
# 1184  일반음식점      섬모라  제주특별자치도 서귀포시 표선면 민속해안로 537
# 1185  일반음식점    나인티나인  제주특별자치도 서귀포시 표선면 민속해안로 537
# 1186  일반음식점  아너스지라운지  제주특별자치도 서귀포시 표선면 민속해안로 537
# 1228  일반음식점       오름  제주특별자치도 서귀포시 표선면 민속해안로 537
# 1779  일반음식점  해비치글라스바  제주특별자치도 서귀포시 표선면 민속해안로 537
# 2011  일반음식점  해비치 다랑쉬  제주특별자치도 서귀포시 표선면 민속해안로 537

# %%
# 중복 발생
# 한 도로명주소에 여러 업소가 있을 수 있다고 판단해서 중복 삭제 안함

part2[part2.도로명주소 == '제주특별자치도 서귀포시 토평서로11번길 150 (동홍동)']
# Out:
#         업종명       업소명                            도로명주소
# 1635  일반음식점   오일장장터식당  제주특별자치도 서귀포시 토평서로11번길 150 (동홍동)
# 1636  일반음식점   오일장본전식당  제주특별자치도 서귀포시 토평서로11번길 150 (동홍동)
# 1637  일반음식점     무진장식당  제주특별자치도 서귀포시 토평서로11번길 150 (동홍동)
# 1638  일반음식점  오일장어머니식당  제주특별자치도 서귀포시 토평서로11번길 150 (동홍동)
# 1639  일반음식점  오일장왕십리식당  제주특별자치도 서귀포시 토평서로11번길 150 (동홍동)
# 1640  일반음식점      풍년식당  제주특별자치도 서귀포시 토평서로11번길 150 (동홍동)
# 1641  일반음식점     일번지식당  제주특별자치도 서귀포시 토평서로11번길 150 (동홍동)
# 1643  일반음식점   오일장맛나식당  제주특별자치도 서귀포시 토평서로11번길 150 (동홍동)

# %%
# 중복 발생
# 한 도로명주소에 여러 업소가 있을 수 있다고 판단해서 중복 삭제 안함

part2[part2.도로명주소 == '제주특별자치도 서귀포시 중문관광로72번길 75 (색달동)']
# Out:
#         업종명                  업소명                            도로명주소
# 130   일반음식점           호텔신라제주호텔천지  제주특별자치도 서귀포시 중문관광로72번길 75 (색달동)
# 131   일반음식점           호텔신라제주호텔일출  제주특별자치도 서귀포시 중문관광로72번길 75 (색달동)
# 132   일반음식점                 더파크뷰  제주특별자치도 서귀포시 중문관광로72번길 75 (색달동)
# 504   일반음식점              제주신라풀가든  제주특별자치도 서귀포시 중문관광로72번길 75 (색달동)
# 1645  일반음식점                 한라연회  제주특별자치도 서귀포시 중문관광로72번길 75 (색달동)
# 1894  일반음식점              제주신라 바당  제주특별자치도 서귀포시 중문관광로72번길 75 (색달동)
# 1943  일반음식점           제주신라글램핑&캠핑  제주특별자치도 서귀포시 중문관광로72번길 75 (색달동)
# 2622  일반음식점  풀사이드바(Poolside Bar)  제주특별자치도 서귀포시 중문관광로72번길 75 (색달동)

# %%
# 중복 발생
# 한 도로명주소에 여러 업소가 있을 수 있다고 판단해서 중복 삭제 안함

part2[part2.도로명주소 == '제주특별자치도 서귀포시 중문관광로72번길 35 (색달동)']
# Out:
#        업종명      업소명                            도로명주소
# 626  일반음식점    더캔버스둘  제주특별자치도 서귀포시 중문관광로72번길 35 (색달동)
# 627  일반음식점     더캔버스  제주특별자치도 서귀포시 중문관광로72번길 35 (색달동)
# 628  일반음식점   더캔버스하나  제주특별자치도 서귀포시 중문관광로72번길 35 (색달동)
# 629  일반음식점  롯데호텔연회장  제주특별자치도 서귀포시 중문관광로72번길 35 (색달동)
# 640  일반음식점    풍차라운지  제주특별자치도 서귀포시 중문관광로72번길 35 (색달동)
# 641  일반음식점     페닌슐라  제주특별자치도 서귀포시 중문관광로72번길 35 (색달동)

# %%
# 'NaN'값의 총 개수 계산

total_nan_values = part2.isnull().sum().sum()
print ('결측값 : ',total_nan_values)
# Out:
# 결측값 :  46

# %%
# '업소명' NaN값 개수 계산

part2['업소명'].isnull().sum().sum()
# Out:
# 0

# %%
# '도로명주소' NaN값 개수 계산

part2['도로명주소'].isnull().sum().sum()
# Out:
# 46

# %% [markdown]
# # Part1 + part2 병합

# %%
new_part = pd.concat([part1, part2])

# %%
print(new_part.shape)
print(list(new_part.columns))
new_part.head()
# Out:
# (5827, 3)
# ['업종명', '업소명', '도로명주소']
#      업종명    업소명                              도로명주소
# 0  휴게음식점   중앙다방          제주특별자치도 서귀포시 대정읍 하모상가로 31
# 1  휴게음식점    돌다방          제주특별자치도 서귀포시 동문로 70 (서귀동)
# 2  휴게음식점   우성다방  제주특별자치도 서귀포시 중정로91번길 15, 2층 (서귀동)
# 3  휴게음식점   수궁다방          제주특별자치도 서귀포시 대정읍 하모항구로 78
# 4  휴게음식점  해당화다방      제주특별자치도 서귀포시 동문로 60, 2층 (서귀동)

# %%
# 누락 데이터 확인

new_part.count()
# Out:
# 업종명      5827
# 업소명      5827
# 도로명주소    5781
# dtype: int64

# %%
# 누락 데이터 확인

new_part.isnull().sum()
# Out:
# 업종명       0
# 업소명       0
# 도로명주소    46
# dtype: int64

# %%
# 완전히 동일한 중복데이터 여부 확인

new_part.duplicated().sum()
# Out:
# 0

# %%
# 완전히 동일한 중복데이터 여부 확인

new_part.duplicated(['업종명', '업소명', '도로명주소']).sum()
# Out:
# 0

# %% [markdown]
# # part3 = 제주특별자치도_서귀포시_제과점현황

# %%
# part3 = 제주특별자치도_서귀포시_제과점현황

print(part3.shape)
print(list(part3.columns))
part3.head()
# Out:
# (147, 7)
# ['업종명', '업소명', '소재지(도로명)', '소재지(지번)', '위도', '경도', '데이터기준일자']
#      업종명        업소명                          소재지(도로명)  \
# 0  제과점영업     오뚜기제과점          제주특별자치도 서귀포시 남원읍 태위로 129
# 1  제과점영업        동문당        제주특별자치도 서귀포시 중정로 103 (서귀동)
# 2  제과점영업       정옥빵집     제주특별자치도 서귀포시 중앙로48번길 18 (서귀동)
# 3  제과점영업       동명찐빵  제주특별자치도 서귀포시 홍중로27번길 25, 1층(서홍동)
# 4  제과점영업  서귀포칼호텔제과점       제주특별자치도 서귀포시 칠십리로 242 (토평동)
#
#                         소재지(지번)         위도          경도     데이터기준일자
# 0  제주특별자치도 서귀포시 남원읍 위미리 2850번지   33.275070  126.661258  2021-04-05
# 1   제주특별자치도 서귀포시 서귀동 256번지 38호   33.248767  126.567381  2021-04-05
# 2    제주특별자치도 서귀포시 서귀동 275번지 1호   33.249169  126.563542  2021-04-05
# 3        제주특별자치도 서귀포시 서홍동 442-5  33.253242  126.557794  2021-04-05
# 4    제주특별자치도 서귀포시 토평동 486번지 3호   33.246002  126.581012  2021-04-05

# %%
# '소재지(지번)', '데이터기준일자' 컬럼 삭제

part3 = part3.drop(['소재지(지번)', '데이터기준일자'], axis=1)
part3.head()
# Out:
#      업종명        업소명                          소재지(도로명)         위도          경도
# 0  제과점영업     오뚜기제과점          제주특별자치도 서귀포시 남원읍 태위로 129  33.275070  126.661258
# 1  제과점영업        동문당        제주특별자치도 서귀포시 중정로 103 (서귀동)  33.248767  126.567381
# 2  제과점영업       정옥빵집     제주특별자치도 서귀포시 중앙로48번길 18 (서귀동)  33.249169  126.563542
# 3  제과점영업       동명찐빵  제주특별자치도 서귀포시 홍중로27번길 25, 1층(서홍동)  33.253242  126.557794
# 4  제과점영업  서귀포칼호텔제과점       제주특별자치도 서귀포시 칠십리로 242 (토평동)  33.246002  126.581012

# %%
# '소재지(도로명)'을 '도로명주소'로 변경

part3.rename(columns = {'소재지(도로명)':'도로명주소'},inplace=True)
part3.head()
# Out:
#      업종명        업소명                             도로명주소         위도          경도
# 0  제과점영업     오뚜기제과점          제주특별자치도 서귀포시 남원읍 태위로 129  33.275070  126.661258
# 1  제과점영업        동문당        제주특별자치도 서귀포시 중정로 103 (서귀동)  33.248767  126.567381
# 2  제과점영업       정옥빵집     제주특별자치도 서귀포시 중앙로48번길 18 (서귀동)  33.249169  126.563542
# 3  제과점영업       동명찐빵  제주특별자치도 서귀포시 홍중로27번길 25, 1층(서홍동)  33.253242  126.557794
# 4  제과점영업  서귀포칼호텔제과점       제주특별자치도 서귀포시 칠십리로 242 (토평동)  33.246002  126.581012

# %%
# 누락 데이터 확인

part3.count()
# Out:
# 업종명      147
# 업소명      147
# 도로명주소    145
# 위도       145
# 경도       145
# dtype: int64

# %%
# 누락 데이터 확인

part3.isnull().sum()
# Out:
# 업종명      0
# 업소명      0
# 도로명주소    2
# 위도       2
# 경도       2
# dtype: int64

# %%
# 완전히 동일한 중복데이터 여부 확인

part3.duplicated().sum()
# Out:
# 0

# %%
# 완전히 동일한 중복데이터 여부 확인

part3.duplicated(['업종명', '업소명', '도로명주소', '위도', '경도']).sum()
# Out:
# 0

# %%
# 컬럼별로 중복데이터 여부 확인

part3['업소명'].value_counts()
# Out:
# 오뚜기제과점          1
# 초승달지대           1
# 월드베이커리          1
# 델리팜2            1
# 다미안             1
#                ..
# 뚜레쥬르 중문점        1
# 파리바게뜨서귀포월드컵점    1
# 제일성심담3호점        1
# 빵돌이와 빵순이        1
# 휴일로             1
# Name: 업소명, Length: 147, dtype: int64

# %%
# 컬럼별로 중복데이터 여부 확인

part3['도로명주소'].value_counts()
# Out:
# 제주특별자치도 서귀포시 안덕면 산록남로 863                      6
# 제주특별자치도 서귀포시 성산읍 섭지코지로 107                     3
# 제주특별자치도 서귀포시 대정읍 칠전로 434                       2
# 제주특별자치도 서귀포시 중앙로 180 (동홍동)                     2
# 제주특별자치도 서귀포시 일주동로 9217, 서귀포시외버스터미널 1층 (법환동)    2
#                                               ..
# 제주특별자치도 서귀포시 중문관광로 154-17 (색달동)                1
# 제주특별자치도 서귀포시 표선면 표선중앙로 89                      1
# 제주특별자치도 서귀포시 남원읍 태위로 662                       1
# 제주특별자치도 서귀포시 홍중로 99, 1층 102호(서홍동)              1
# 제주특별자치도 서귀포시 안덕면 난드르로 49-65, 가동                1
# Name: 도로명주소, Length: 135, dtype: int64

# %% [markdown]
# # part4 = 제주특별자치도 서귀포시_칠십리음식특화거리업소현황

# %%
# part4 = 제주특별자치도 서귀포시_칠십리음식특화거리업소현황

print(part4.shape)
print(list(part4.columns))
part4.head()
# Out:
# (25, 7)
# ['업소명', '주소', '전화', '비고', '위도', '경도', '데이터기준일자']
#        업소명                     주소            전화           비고         위도  \
# 0  삼무뚝배기갈치  제주특별자치도 서귀포시 칠십리로 119  064-733-2360  구이. 조림. 뚝배기  33.242680
# 1     동해미락  제주특별자치도 서귀포시 칠십리로 133  064-733-5921  생선회. 구이. 조림  33.243669
# 2   어판장회센터   제주특별자치도 서귀포시 칠십리로 53  064-763-1189  생선회. 구이. 조림  33.240250
# 3     영빈횟집  제주특별자치도 서귀포시 칠십리로 129  064-732-3488  생선회. 구이. 조림  33.243278
# 4    해궁해장국  제주특별자치도 서귀포시 칠십리로 115           NaN          해장국  33.242423
#
#            경도     데이터기준일자
# 0  126.567226  2021-09-30
# 1  126.568225  2021-09-30
# 2  126.562049  2021-09-30
# 3  126.567867  2021-09-30
# 4  126.566704  2021-09-30

# %%
# '비고', '데이터기준일자' 컬럼 삭제

part4 = part4.drop(['비고', '데이터기준일자'], axis=1)
part4.head()
# Out:
#        업소명                     주소            전화         위도          경도
# 0  삼무뚝배기갈치  제주특별자치도 서귀포시 칠십리로 119  064-733-2360  33.242680  126.567226
# 1     동해미락  제주특별자치도 서귀포시 칠십리로 133  064-733-5921  33.243669  126.568225
# 2   어판장회센터   제주특별자치도 서귀포시 칠십리로 53  064-763-1189  33.240250  126.562049
# 3     영빈횟집  제주특별자치도 서귀포시 칠십리로 129  064-732-3488  33.243278  126.567867
# 4    해궁해장국  제주특별자치도 서귀포시 칠십리로 115           NaN  33.242423  126.566704

# %%
# '주소'를 '도로명주소'로 변경

part4.rename(columns = {'주소':'도로명주소', '전화':'연락처'},inplace=True)
part4.head()
# Out:
#        업소명                  도로명주소           연락처         위도          경도
# 0  삼무뚝배기갈치  제주특별자치도 서귀포시 칠십리로 119  064-733-2360  33.242680  126.567226
# 1     동해미락  제주특별자치도 서귀포시 칠십리로 133  064-733-5921  33.243669  126.568225
# 2   어판장회센터   제주특별자치도 서귀포시 칠십리로 53  064-763-1189  33.240250  126.562049
# 3     영빈횟집  제주특별자치도 서귀포시 칠십리로 129  064-732-3488  33.243278  126.567867
# 4    해궁해장국  제주특별자치도 서귀포시 칠십리로 115           NaN  33.242423  126.566704

# %%
# 누락 데이터 확인

part4.count()
# Out:
# 업소명      25
# 도로명주소    25
# 연락처      24
# 위도       25
# 경도       25
# dtype: int64

# %%
# 누락 데이터 확인

part4.isnull().sum()
# Out:
# 업소명      0
# 도로명주소    0
# 연락처      1
# 위도       0
# 경도       0
# dtype: int64

# %%
# 완전히 동일한 중복데이터 여부 확인

part4.duplicated().sum()
# Out:
# 0

# %%
# 완전히 동일한 중복데이터 여부 확인

part4.duplicated(['업소명', '도로명주소', '위도', '경도']).sum()
# Out:
# 0

# %% [markdown]
# # Part3 + part4 병합

# %%
a_part = pd.concat([part3, part4])

# %%
print(a_part.shape)
print(list(a_part.columns))
a_part.head()
# Out:
# (172, 6)
# ['업종명', '업소명', '도로명주소', '위도', '경도', '연락처']
#      업종명        업소명                             도로명주소         위도          경도  \
# 0  제과점영업     오뚜기제과점          제주특별자치도 서귀포시 남원읍 태위로 129  33.275070  126.661258
# 1  제과점영업        동문당        제주특별자치도 서귀포시 중정로 103 (서귀동)  33.248767  126.567381
# 2  제과점영업       정옥빵집     제주특별자치도 서귀포시 중앙로48번길 18 (서귀동)  33.249169  126.563542
# 3  제과점영업       동명찐빵  제주특별자치도 서귀포시 홍중로27번길 25, 1층(서홍동)  33.253242  126.557794
# 4  제과점영업  서귀포칼호텔제과점       제주특별자치도 서귀포시 칠십리로 242 (토평동)  33.246002  126.581012
#
#    연락처
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
# 완전히 동일한 중복데이터 여부 확인

a_part.duplicated().sum()
# Out:
# 0

# %%
# 완전히 동일한 중복데이터 여부 확인

a_part.duplicated(['업소명', '도로명주소', '위도', '경도']).sum()
# Out:
# 0

# %% [markdown]
# # new_part + a_part 병합

# %%
# new_part = 제주특별자치도_서귀포시_휴게음식점현황 + 제주특별자치도_서귀포시_일반음식점현황
# a_part = 제주특별자치도_서귀포시_제과점현황 + 제주특별자치도 서귀포시_칠십리음식특화거리업소현황

final_part = pd.concat([new_part, a_part])

# %%
print(final_part.shape)
print(list(final_part.columns))
final_part.head()
# Out:
# (5999, 6)
# ['업종명', '업소명', '도로명주소', '위도', '경도', '연락처']
#      업종명    업소명                              도로명주소  위도  경도  연락처
# 0  휴게음식점   중앙다방          제주특별자치도 서귀포시 대정읍 하모상가로 31 NaN NaN  NaN
# 1  휴게음식점    돌다방          제주특별자치도 서귀포시 동문로 70 (서귀동) NaN NaN  NaN
# 2  휴게음식점   우성다방  제주특별자치도 서귀포시 중정로91번길 15, 2층 (서귀동) NaN NaN  NaN
# 3  휴게음식점   수궁다방          제주특별자치도 서귀포시 대정읍 하모항구로 78 NaN NaN  NaN
# 4  휴게음식점  해당화다방      제주특별자치도 서귀포시 동문로 60, 2층 (서귀동) NaN NaN  NaN

# %%
# 컬럼 순서 변경

final_part = final_part[['업종명', '업소명', '도로명주소', '연락처', '위도', '경도']]
final_part
# Out:
#       업종명       업소명                              도로명주소           연락처  \
# 0   휴게음식점      중앙다방          제주특별자치도 서귀포시 대정읍 하모상가로 31           NaN
# 1   휴게음식점       돌다방          제주특별자치도 서귀포시 동문로 70 (서귀동)           NaN
# 2   휴게음식점      우성다방  제주특별자치도 서귀포시 중정로91번길 15, 2층 (서귀동)           NaN
# 3   휴게음식점      수궁다방          제주특별자치도 서귀포시 대정읍 하모항구로 78           NaN
# 4   휴게음식점     해당화다방      제주특별자치도 서귀포시 동문로 60, 2층 (서귀동)           NaN
# ..    ...       ...                                ...           ...
# 20    NaN   제주할망뚝배기               제주특별자치도 서귀포시 칠십리로 92  064-733-9934
# 21    NaN       나운터               제주특별자치도 서귀포시 칠십리로 42  064-763-2237
# 22    NaN     항구음식점             제주특별자치도 서귀포시 칠십리로 40-4  064-762-3565
# 23    NaN  서귀포회수산마트             제주특별자치도 서귀포시 칠십리로 38-1  064-733-8280
# 24    NaN      땡큐베리               제주특별자치도 서귀포시 칠십리로 97  064-732-0932
#
#            위도          경도
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# ...

# %%
# 4개의 csv 파일인 공통 항목을 가지고 완전히 동일한 중복데이터 여부 확인 

final_part.duplicated(['업소명', '도로명주소']).sum()
# Out:
# 9

# %%
# '업소명', '소재지' 컬럼인 중복된 행 삭제

final_part.drop_duplicates(['업소명', '도로명주소'])
# Out:
#       업종명       업소명                              도로명주소           연락처  \
# 0   휴게음식점      중앙다방          제주특별자치도 서귀포시 대정읍 하모상가로 31           NaN
# 1   휴게음식점       돌다방          제주특별자치도 서귀포시 동문로 70 (서귀동)           NaN
# 2   휴게음식점      우성다방  제주특별자치도 서귀포시 중정로91번길 15, 2층 (서귀동)           NaN
# 3   휴게음식점      수궁다방          제주특별자치도 서귀포시 대정읍 하모항구로 78           NaN
# 4   휴게음식점     해당화다방      제주특별자치도 서귀포시 동문로 60, 2층 (서귀동)           NaN
# ..    ...       ...                                ...           ...
# 20    NaN   제주할망뚝배기               제주특별자치도 서귀포시 칠십리로 92  064-733-9934
# 21    NaN       나운터               제주특별자치도 서귀포시 칠십리로 42  064-763-2237
# 22    NaN     항구음식점             제주특별자치도 서귀포시 칠십리로 40-4  064-762-3565
# 23    NaN  서귀포회수산마트             제주특별자치도 서귀포시 칠십리로 38-1  064-733-8280
# 24    NaN      땡큐베리               제주특별자치도 서귀포시 칠십리로 97  064-732-0932
#
#            위도          경도
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# ...

# %%
# 컬럼명 변경

final_part.rename(columns = {'업종명':'업종', '연락처':'전화번호'},inplace=True)
final_part.head()
# Out:
#       업종    업소명                              도로명주소 전화번호  위도  경도
# 0  휴게음식점   중앙다방          제주특별자치도 서귀포시 대정읍 하모상가로 31  NaN NaN NaN
# 1  휴게음식점    돌다방          제주특별자치도 서귀포시 동문로 70 (서귀동)  NaN NaN NaN
# 2  휴게음식점   우성다방  제주특별자치도 서귀포시 중정로91번길 15, 2층 (서귀동)  NaN NaN NaN
# 3  휴게음식점   수궁다방          제주특별자치도 서귀포시 대정읍 하모항구로 78  NaN NaN NaN
# 4  휴게음식점  해당화다방      제주특별자치도 서귀포시 동문로 60, 2층 (서귀동)  NaN NaN NaN

# %%
# 컬럼 추가

final_part['행정시'] = np.nan
final_part.head()
# Out:
#       업종    업소명                              도로명주소 전화번호  위도  경도  행정시
# 0  휴게음식점   중앙다방          제주특별자치도 서귀포시 대정읍 하모상가로 31  NaN NaN NaN  NaN
# 1  휴게음식점    돌다방          제주특별자치도 서귀포시 동문로 70 (서귀동)  NaN NaN NaN  NaN
# 2  휴게음식점   우성다방  제주특별자치도 서귀포시 중정로91번길 15, 2층 (서귀동)  NaN NaN NaN  NaN
# 3  휴게음식점   수궁다방          제주특별자치도 서귀포시 대정읍 하모항구로 78  NaN NaN NaN  NaN
# 4  휴게음식점  해당화다방      제주특별자치도 서귀포시 동문로 60, 2층 (서귀동)  NaN NaN NaN  NaN

# %%
# 컬럼 추가

final_part['업태'] = np.nan
final_part.head()
# Out:
#       업종    업소명                              도로명주소 전화번호  위도  경도  행정시  업태
# 0  휴게음식점   중앙다방          제주특별자치도 서귀포시 대정읍 하모상가로 31  NaN NaN NaN  NaN NaN
# 1  휴게음식점    돌다방          제주특별자치도 서귀포시 동문로 70 (서귀동)  NaN NaN NaN  NaN NaN
# 2  휴게음식점   우성다방  제주특별자치도 서귀포시 중정로91번길 15, 2층 (서귀동)  NaN NaN NaN  NaN NaN
# 3  휴게음식점   수궁다방          제주특별자치도 서귀포시 대정읍 하모항구로 78  NaN NaN NaN  NaN NaN
# 4  휴게음식점  해당화다방      제주특별자치도 서귀포시 동문로 60, 2층 (서귀동)  NaN NaN NaN  NaN NaN

# %%
# 컬럼 순서 변경

final_part = final_part[['업소명', '업종', '업태', '행정시', '도로명주소', '전화번호', '위도', '경도']]
final_part
# Out:
#          업소명     업종  업태  행정시                              도로명주소          전화번호  \
# 0       중앙다방  휴게음식점 NaN  NaN          제주특별자치도 서귀포시 대정읍 하모상가로 31           NaN
# 1        돌다방  휴게음식점 NaN  NaN          제주특별자치도 서귀포시 동문로 70 (서귀동)           NaN
# 2       우성다방  휴게음식점 NaN  NaN  제주특별자치도 서귀포시 중정로91번길 15, 2층 (서귀동)           NaN
# 3       수궁다방  휴게음식점 NaN  NaN          제주특별자치도 서귀포시 대정읍 하모항구로 78           NaN
# 4      해당화다방  휴게음식점 NaN  NaN      제주특별자치도 서귀포시 동문로 60, 2층 (서귀동)           NaN
# ..       ...    ...  ..  ...                                ...           ...
# 20   제주할망뚝배기    NaN NaN  NaN               제주특별자치도 서귀포시 칠십리로 92  064-733-9934
# 21       나운터    NaN NaN  NaN               제주특별자치도 서귀포시 칠십리로 42  064-763-2237
# 22     항구음식점    NaN NaN  NaN             제주특별자치도 서귀포시 칠십리로 40-4  064-762-3565
# 23  서귀포회수산마트    NaN NaN  NaN             제주특별자치도 서귀포시 칠십리로 38-1  064-733-8280
# 24      땡큐베리    NaN NaN  NaN               제주특별자치도 서귀포시 칠십리로 97  064-732-0932
#
#            위도          경도
# ...

# %%
# csv 파일 저장

final_part.to_csv('제주특별자치도_서귀포 음식관련 업소_병합.csv', encoding='cp949')
